# %%
# !pip install pygame==2.0.0.dev4
# !python --version
# !pip install -U ray 
# !pip install ray[rllib]
# !pip install ray[tune]
import os
os.environ['SDL_VIDEODRIVER']='dummy'
# Out:
# Requirement already satisfied: pygame==2.0.0.dev4 in /usr/local/lib/python3.6/dist-packages (2.0.0.dev4)
# Python 3.6.9
# Requirement already up-to-date: ray in /usr/local/lib/python3.6/dist-packages (0.8.4)
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.6/dist-packages (from ray) (3.0.12)
# Requirement already satisfied, skipping upgrade: numpy>=1.16 in /usr/local/lib/python3.6/dist-packages (from ray) (1.18.3)
# Requirement already satisfied, skipping upgrade: google in /usr/local/lib/python3.6/dist-packages (from ray) (2.0.3)
# Requirement already satisfied, skipping upgrade: colorama in /usr/local/lib/python3.6/dist-packages (from ray) (0.4.3)
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from ray) (3.10.0)
# Requirement already satisfied, skipping upgrade: grpcio in /usr/local/lib/python3.6/dist-packages (from ray) (1.28.1)
# Requirement already satisfied, skipping upgrade: py-spy>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from ray) (0.3.3)
# Requirement already satisfied, skipping upgrade: aiohttp in /usr/local/lib/python3.6/dist-packages (from ray) (3.6.2)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from ray) (3.13)
# Requirement already satisfied, skipping upgrade: redis>=3.3.2 in /usr/local/lib/python3.6/dist-packages (from ray) (3.4.1)
# Requirement already satisfied, skipping upgrade: click in /usr/local/lib/python3.6/dist-packages (from ray) (7.1.1)
# Requirement already satisfied, skipping upgrade: jsonschema in /usr/local/lib/python3.6/dist-packages (from ray) (2.6.0)
# Requirement already satisfied, skipping upgrade: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from google->ray) (4.6.3)
# Requirement already satisfied, skipping upgrade: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->ray) (1.12.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->ray) (46.1.3)
# Requirement already satisfied, skipping upgrade: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (3.0.1)
# Requirement already satisfied, skipping upgrade: multidict<5.0,>=4.5 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (4.7.5)
# Requirement already satisfied, skipping upgrade: idna-ssl>=1.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (1.1.0)
# Requirement already satisfied, skipping upgrade: chardet<4.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (3.0.4)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.5; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (3.6.6)
# Requirement already satisfied, skipping upgrade: yarl<2.0,>=1.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (1.4.2)
# Requirement already satisfied, skipping upgrade: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (19.3.0)
# Requirement already satisfied, skipping upgrade: idna>=2.0 in /usr/local/lib/python3.6/dist-packages (from idna-ssl>=1.0; python_version < "3.7"->aiohttp->ray) (2.8)
# Requirement already satisfied: ray[rllib] in /usr/local/lib/python3.6/dist-packages (0.8.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.0.12)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.10.0)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (0.3.3)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (1.28.1)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (1.18.3)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (0.4.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (2.6.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (7.1.1)
# Requirement already satisfied: google in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (2.0.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.13)
# Requirement already satisfied: redis>=3.3.2 in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.4.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.6.2)
# Requirement already satisfied: lz4; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.0.2)
# Requirement already satisfied: scipy; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (1.4.1)
# Requirement already satisfied: opencv-python-headless; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (4.2.0.34)
# Requirement already satisfied: atari-py; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (0.2.6)
# Requirement already satisfied: tensorboardX; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (2.0)
# Requirement already satisfied: dm-tree; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (0.1.4)
# Requirement already satisfied: gym[atari]; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (0.17.1)
# Requirement already satisfied: tabulate; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (0.8.7)
# Requirement already satisfied: pandas; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (1.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->ray[rllib]) (46.1.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->ray[rllib]) (1.12.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from google->ray[rllib]) (4.6.3)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[rllib]) (3.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[rllib]) (1.4.2)
# Requirement already satisfied: idna-ssl>=1.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[rllib]) (1.1.0)
# Requirement already satisfied: multidict<5.0,>=4.5 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[rllib]) (4.7.5)
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[rllib]) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[rllib]) (19.3.0)
# Requirement already satisfied: typing-extensions>=3.6.5; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[rllib]) (3.6.6)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (1.5.0)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (1.3.0)
# Requirement already satisfied: Pillow; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (7.0.0)
# Requirement already satisfied: opencv-python; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (4.1.2.30)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas; extra == "rllib"->ray[rllib]) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas; extra == "rllib"->ray[rllib]) (2018.9)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.6/dist-packages (from yarl<2.0,>=1.0->aiohttp->ray[rllib]) (2.8)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[atari]; extra == "rllib"->ray[rllib]) (0.16.0)
# Requirement already satisfied: ray[tune] in /usr/local/lib/python3.6/dist-packages (0.8.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (3.13)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (1.28.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (3.6.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (2.6.0)
# Requirement already satisfied: redis>=3.3.2 in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (3.4.1)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (0.3.3)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (7.1.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (0.4.3)
# Requirement already satisfied: google in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (2.0.3)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (1.18.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (3.0.12)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (3.10.0)
# Requirement already satisfied: tensorboardX; extra == "tune" in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (2.0)
# Requirement already satisfied: pandas; extra == "tune" in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (1.0.3)
# Requirement already satisfied: tabulate; extra == "tune" in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (0.8.7)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from grpcio->ray[tune]) (1.12.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[tune]) (3.0.1)
# Requirement already satisfied: idna-ssl>=1.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[tune]) (1.1.0)
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[tune]) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.6.5; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[tune]) (3.6.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[tune]) (19.3.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[tune]) (1.4.2)
# Requirement already satisfied: multidict<5.0,>=4.5 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[tune]) (4.7.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from google->ray[tune]) (4.6.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->ray[tune]) (46.1.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas; extra == "tune"->ray[tune]) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas; extra == "tune"->ray[tune]) (2.8.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.6/dist-packages (from idna-ssl>=1.0; python_version < "3.7"->aiohttp->ray[tune]) (2.8)

# %%
import gym, ray
from ray.tune.registry import register_env
from ray.rllib.env.multi_agent_env import MultiAgentEnv
import gym
import numpy as np
from gym import spaces
from gym.envs.registration import EnvSpec
import pygame, math, sys, time
from pygame.locals import *
import pygame.camera
import matplotlib.pyplot as plt






class CarSprite(pygame.sprite.Sprite):
    MAX_FORWARD_SPEED = 10
    MAX_REVERSE_SPEED = 0
    ACCELERATION = 2
    TURN_SPEED = 10
    checkpoint=0
    cur_policy = 1
    ready = False

    def __init__(self, image, position):
        pygame.sprite.Sprite.__init__(self)
        self.src_image = pygame.image.load(image)
        self.image = pygame.image.load(image)
        self.position = position
        self.speed = self.direction = 0
        self.k_left = self.k_right = self.k_down = self.k_up = 0
        x, y = (self.position)
        self.rect = self.image.get_rect()
        #self.rect = pygame.Rect(x, y, 30, 30)
        self.rect.center = self.position
        self.steps = 0
        

    
    def update(self, deltat):
        #SIMULATION
        #print(str(self.k_up) + " " + str(self.k_down) + " " +  str(self.k_right) + " " +  str(self.k_left))
        self.speed += (self.k_up + self.k_down)
        if self.speed > self.MAX_FORWARD_SPEED:
            self.speed = self.MAX_FORWARD_SPEED
        if self.speed < -self.MAX_REVERSE_SPEED:
            self.speed = -self.MAX_REVERSE_SPEED
        self.direction += (self.k_right + self.k_left)
        x, y = (self.position)
        rad = self.direction * math.pi / 180
        velocity_x = -self.speed*math.sin(rad)
        velocity_y = -self.speed*math.cos(rad)
        self.steps += 1
        x += velocity_x
        y += velocity_y
        x_c = x
        y_c = y
        self.position = (x, y)

        self.image = pygame.transform.rotate(self.src_image, self.direction)
        self.rect = self.image.get_rect()
        self.rect.center = self.position
        #pygame.draw.rect(screen, (255, 255, 0), self.rect, width=2)



class SensorSprite(pygame.sprite.Sprite):
    xpos = 0
    ypos = 0
    xnew = 0
    ynew = 0
    obj = None

    def __init__(self, x_pos, y_pos, obj):
        self.xpos = x_pos
        self.ypos = y_pos
        self.xnew = obj.rect.centerx + x_pos
        self.ynew = obj.rect.centery + y_pos
        self.obj = obj
        pygame.sprite.Sprite.__init__(self)
        if obj.rect.centerx < self.xnew and y_pos > 0:
            #left, top, width, height
            self.rect = pygame.Rect(obj.rect.centerx, obj.rect.centery, x_pos, y_pos)

        elif obj.rect.centerx > self.xnew and y_pos > 0:
             self.rect = pygame.Rect(self.xnew, obj.rect.centery, abs(x_pos), y_pos)

        elif obj.rect.centerx < self.xnew and y_pos < 0:
            self.rect = pygame.Rect(obj.rect.centerx, self.ynew, x_pos, abs(y_pos))

        else:
            self.rect = pygame.Rect(self.xnew, self.ynew, abs(x_pos), abs(y_pos))
        #self.rect = pygame.draw.line(screen,(255,0,0),(obj.rect.centerx, obj.rect.centery), (self.xnew, obj.rect.centery + y_pos), width=5)
    def update(self):

        rad = -self.obj.direction * math.pi / 180
        s = math.sin(rad);
        c = math.cos(rad);
        x = self.obj.rect.centerx
        y = self.obj.rect.centery

        xnew = c*(self.xpos) - s *(self.ypos) + x
        ynew = s*(self.xpos) + c *(self.ypos) + y

        if x < xnew and y < ynew:
            #left, top, width, height
            self.rect = pygame.Rect(x , y, abs(x - xnew), abs(y - ynew))

        elif x > xnew and y < ynew:
             self.rect = pygame.Rect(xnew , y, abs(x - xnew), abs(y - ynew))

        elif x < xnew and y > ynew:
            self.rect = pygame.Rect(x , ynew, abs(x - xnew), abs(y - ynew))

        else:
            self.rect = pygame.Rect(xnew , ynew, abs(x - xnew), abs(y - ynew))

        #self.rect = pygame.draw.line(screen,(255, 0, 0),(x, y),(xnew, ynew), width=2)




class PadSprite(pygame.sprite.Sprite):
    normal = None
    #hit = pygame.image.load('collision.png')
    def __init__(self, position, image):
        self.image = pygame.image.load(image)
  
        super(PadSprite, self).__init__()
        if image.startswith('pad_vert'):
          self.rect = pygame.Rect(0, 0, 15, 50)
        else:
          self.rect = pygame.Rect(0, 0, 50, 15)
        self.rect.center = position
    def update(self, hit_list):
        if self in hit_list: 
            #self.image = self.hit
            self.position = (50, 50)
        else: self.image = self.normal


class CheckPointSprite(pygame.sprite.Sprite):
    def __init__(self, left, top, width, height, val):
        super(CheckPointSprite, self).__init__()
        self.rect = pygame.Rect(left, top, width, height)
        self.val = val




# environment for all agents in the multiagent world
# currently code assumes that no agents will be created/destroyed at runtime!
class MultiCarEnv2(gym.Env, MultiAgentEnv):
    metadata = {
        'render.modes' : ['human', 'console']
    }

    UP = 0
    DOWN = 1




    def __init__(self):
        super(MultiCarEnv2, self).__init__()

        pygame.init()
        self.screen = pygame.display.set_mode((1024, 800))
        self.screen.fill([128, 128, 128])
        pygame.display.update()


        def drawCirclePad(xc, yc, x, y, pads):
            pads.append(PadSprite((xc + x, yc + y),'pad_sq.png'))
            pads.append(PadSprite((xc - x, yc + y),'pad_sq.png'))
            pads.append(PadSprite((xc + x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc - x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc + y, yc + x),'pad_sq.png'))
            pads.append(PadSprite((xc - y, yc + x),'pad_sq.png'))
            pads.append(PadSprite((xc + y, yc - x),'pad_sq.png'))
            pads.append(PadSprite((xc - y, yc - x),'pad_sq.png'))


        def circleBres(xc, yc, r, pad):

            x = 0
            y = r; 
            d = 3 - 2 * r 
            drawCirclePad(xc, yc, x, y, pad)
            while y >= x:
                  
                x += 1

                if d > 0:
                    y -= 1
                    d = d + 4 * (x - y) + 10; 
                
                else:
                    d = d + 4 * x + 6; 
                drawCirclePad(xc, yc, x, y, pad)

        pads1 = []
        pads2 = []  

        circleBres(400, 400, 375, pads1)
        circleBres(400, 400, 300, pads2)

        self.pad_group1 = pygame.sprite.RenderPlain(*pads1)
        self.pad_group2 = pygame.sprite.RenderPlain(*pads2)

        car = CarSprite('car.png', (60, 400))
        car2 = CarSprite('car.png', (110, 230))
        car3 = CarSprite('car.png', (215, 115))
        car4 = CarSprite('car.png', (380, 55))
        car5 = CarSprite('car.png', (565, 115))
        car6 = CarSprite('car.png', (690, 240))
        car7 = CarSprite('car.png', (740, 390))
        car8 = CarSprite('car.png', (690, 540))
        car9 = CarSprite('car.png', (565, 665))
        car10 = CarSprite('car.png', (390, 740))
        car11 = CarSprite('car.png', (215, 665))
        car12 = CarSprite('car.png', (115, 540))

        self.cars = [car, car2, car3, car4, car5, car6, car7, car8, car9, car10, car11, car12]

        self.car_group = pygame.sprite.RenderPlain(*self.cars)
        def addSensor(car, sensors):
            sensors.append(SensorSprite(0, -250, car))
            sensors.append(SensorSprite(200, -230, car))
            sensors.append(SensorSprite(-200, -230, car))
            sensors.append(SensorSprite(250, 0, car))
            sensors.append(SensorSprite(-250, 0, car))
            sensors.append(SensorSprite(0, 250, car))
            sensors.append(SensorSprite(200, 230, car))
            sensors.append(SensorSprite(-200, 230, car))

        self.sensors = []

        for c in self.cars:
            curr = []
            addSensor(c, curr)
            self.sensors.append(curr)

        self.sensor_group = []
        for sensor in self.sensors:
          self.sensor_group.append(pygame.sprite.RenderPlain(*sensor))

        self.checkpoints = [CheckPointSprite(25, 350, 150, 150, 1), 
               CheckPointSprite(75, 200, 150, 150, 2),
               CheckPointSprite(175, 75, 150, 150, 3),
               CheckPointSprite(350, 25, 150, 150, 4),
               CheckPointSprite(525, 75, 150, 150, 5), 
               CheckPointSprite(650, 200, 150, 150, 6),
               CheckPointSprite(700, 350, 150, 150, 7),
               CheckPointSprite(350, 25, 150, 150, 8),

               CheckPointSprite(75, 500, 150, 150, 13),
               CheckPointSprite(175, 625, 150, 150, 12),
               CheckPointSprite(350, 700, 150, 150, 11),

               CheckPointSprite(525, 625, 150, 150, 9), 
               CheckPointSprite(650, 500, 150, 150, 10),

               ]
        self.check_group = pygame.sprite.RenderPlain(*self.checkpoints)
    
        self.time = 0

        #accelerate, decelerate, nothing
        self.action_space = spaces.Discrete(3)
        #distance to another object, average velocity of other cars, own velocity
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf,
                                        shape=(10,), dtype=np.float32)

        self.wait = 3
        self.step_count = 0

        

    def step(self, action_n):
        self.step_count += 1

        obs_d = {}
        reward_d = {}
        done_d =  {
            "car_0": False,
            #"car_6": False,    
            "__all__": False,  # the env is not done
        }

        info_d = {
            "car_0":{},
            #"car_6":{}  
        }




        obs_n = []
        reward_n = []


        clock = pygame.time.Clock()
        #deltat = clock.tick(30)
        deltat = 30
        self.time += deltat
        # set and perform action for each agent
        i = 0
        idx = [0]
        for key, val in action_n.items():
            cur_action = val
            if cur_action == self.DOWN:
                self.cars[idx[i]].k_down = -1
            else:
                self.cars[idx[i]].k_down = 0
            if cur_action == self.UP:
                self.cars[idx[i]].k_up = 0.5
            else: 
                self.cars[idx[i]].k_up = 0
            i += 1

        i = 0
        for car in self.cars:
            

            if self.step_count >= 20 and self.step_count < 60 and i == 5:
                car.speed -= 0.25

            other_cars = self.cars[:]
            other_cars.remove(car)
            other_cars_g = pygame.sprite.Group(other_cars)


            # find the cars in range
            car_near = pygame.sprite.groupcollide(self.sensor_group[i].sprites()[0:3], other_cars_g, False, False, collided = None)
        

            rect_list = []
            car_list = []

            # find the nearest car
            for key, value in car_near.items():
                for val in value:
                    car_list.append(val)
                    newrect = val.rect.clip(key.rect)
                    rect_list.append(newrect)
            # find nearest distance to other car
            mindist = 1000
            minCar = None
            k = 0
            for rec in rect_list:
                dist = math.sqrt((rec.centerx - car.rect.centerx) ** 2 + (rec.centery - car.rect.centery) ** 2)
                if dist < mindist:
                    mindist = dist
                    minCar = car_list[k]
                k += 1

            accel = 0
            
            if i != 0:
                if mindist < 75:
                    accel = -(car.speed/2)
                else:
                    if minCar == None  or car.speed < minCar.speed:
                        accel = 0.1
                car.speed += accel
            else: 
                if mindist < 75:         
                  accel = -(car.speed/2)
                  car.k_down = 0
                  car.k_up = 0
                car.speed += accel
              


            collisions_pad1 = pygame.sprite.spritecollide(car, self.pad_group1, False, collided = None)
            collisions_pad2 = pygame.sprite.spritecollide(car, self.pad_group2, False, collided = None)

            x = car.rect.centerx
            y = car.rect.centery

            theta = (400 - x)/(math.sqrt((x - 400)**2 + (y-400)**2))
            if y > 400:
                #print("here")
                car.direction = (math.degrees(math.acos(theta)) % 360)
            else: 
                car.direction = -math.degrees(math.acos(theta) % 360)

            if len(collisions_pad1) != 0:
                car.direction -= 10
            elif len(collisions_pad2) != 0: 
                car.direction += 10

            i += 1
        
        self.car_group.update(deltat)
        for s in self.sensor_group:
          s.update()

        
        

        avg_speed = 0
        for c in self.cars:
            avg_speed += c.speed
        avg_speed /= len(self.cars)

        # record observation for each agent
        j = 0
        for car in self.cars:
            j += 1
            if j != 1: 
              continue
            current_obs = np.zeros(10)
            current_reward = 0
            closest_obj = 1000

            other_cars = self.cars[:]
            other_cars.remove(car)
            other_car_group = pygame.sprite.Group(other_cars)
            #print(other_cars)

            if car.steps == 500:
              done_d['__all__'] = True

            for i in range(0, len(self.sensors[j-1])):
                cur_sensor = self.sensors[j-1][i]
                
                #pad_near = pygame.sprite.spritecollide(cur_sensor, self.pad_group1, False, collided = None)
                #pad_near2 = pygame.sprite.spritecollide(cur_sensor, self.pad_group2, False, collided = None)
                car_near = pygame.sprite.spritecollide(cur_sensor, other_car_group, False, collided = None)
                nearest_dist = 400
                rect_list = []
                # use clip rect function
                for other_car in car_near:
                    newrect = other_car.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for rec in rect_list:
                    cur_dist = math.sqrt((rec.centerx - car.rect.centerx) ** 2 + (rec.centery - car.rect.centery) ** 2)
                    if  cur_dist < nearest_dist:
                        nearest_dist = cur_dist
                current_obs[i] = nearest_dist
                if nearest_dist < closest_obj:
                    closest_obj = nearest_dist
            
            
            current_obs[8] = car.speed
            current_obs[9] = avg_speed

            car_collide = pygame.sprite.spritecollide(car, other_car_group, False, collided = None)
            if len(car_collide) != 0:
                print(car_collide)
                print(car.position)
                for s in self.sensors[2]:
                  print(str(s.xnew) + " " + str(s.ynew))
                print("here " + str(self.step_count) + " " + str(avg_speed))
                done_d['__all__'] = True

            current_reward += avg_speed

            obs_n.append(current_obs)
            reward_n.append(current_reward)
       
        obs_d = {
            "car_0": obs_n[0],
            #"car_6": obs_n[1]
        }
        reward_d = {
            "car_0": reward_n[0],
            #"car_6": reward_n[1]
        }

        if done_d["__all__"] == True:
            print(avg_speed)
            print('Done')


        return obs_d, reward_d, done_d, info_d

    def reset(self):
       
        # record observations for each agent
        obs_n = []

        self.step_count = 0

        

        car = CarSprite('car.png', (60, 400))
        car2 = CarSprite('car.png', (110, 230))
        car3 = CarSprite('car.png', (215, 115))
        car4 = CarSprite('car.png', (380, 55))
        car5 = CarSprite('car.png', (565, 115))
        car6 = CarSprite('car.png', (690, 240))
        car7 = CarSprite('car.png', (740, 390))
        car8 = CarSprite('car.png', (690, 540))
        car9 = CarSprite('car.png', (565, 665))
        car10 = CarSprite('car.png', (390, 740))
        car11 = CarSprite('car.png', (215, 665))
        car12 = CarSprite('car.png', (115, 540))

        self.cars = [car, car2, car3, car4, car5, car6, car7, car8, car9, car10, car11, car12]

        self.car_group = pygame.sprite.RenderPlain(*self.cars)
        def addSensor(car, sensors):
            sensors.append(SensorSprite(0, -250, car))
            sensors.append(SensorSprite(200, -230, car))
            sensors.append(SensorSprite(-200, -230, car))
            sensors.append(SensorSprite(250, 0, car))
            sensors.append(SensorSprite(-250, 0, car))
            sensors.append(SensorSprite(0, 250, car))
            sensors.append(SensorSprite(200, 230, car))
            sensors.append(SensorSprite(-200, 230, car))

        self.sensors = []

        for c in self.cars:
            curr = []
            addSensor(c, curr)
            self.sensors.append(curr)

        self.sensor_group = []
        for sensor in self.sensors:
          self.sensor_group.append(pygame.sprite.RenderPlain(*sensor))

        for c in self.cars:
          c.speed = 10

         # record observation for each agent
        j = 0
        for car in self.cars:
            j += 1
            if j != 1:
              continue
            current_obs = np.zeros(10)
            current_reward = 0
            closest_obj = 500

            other_cars = self.cars[:]
            other_cars.remove(car)
            other_car_group = pygame.sprite.Group(other_cars)

            for i in range(0, len(self.sensors[j-1])):
                cur_sensor = self.sensors[j-1][i]
                
                #pad_near = pygame.sprite.spritecollide(cur_sensor, self.pad_group1, False, collided = None)
                #pad_near2 = pygame.sprite.spritecollide(cur_sensor, self.pad_group2, False, collided = None)
                car_near = pygame.sprite.spritecollide(cur_sensor, other_car_group, False, collided = None)
                nearest_dist = 400
                rect_list = []
                # use clip rect function
                for other_car in car_near:
                    newrect = other_car.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for rec in rect_list:
                    cur_dist = math.sqrt((rec.centerx - car.rect.centerx) ** 2 + (rec.centery - car.rect.centery) ** 2)
                    if  cur_dist < nearest_dist:
                        nearest_dist = cur_dist
                current_obs[i] = nearest_dist
                if nearest_dist < closest_obj:
                    closest_obj = nearest_dist
            
            current_obs[8] = 10
            current_obs[9] = 10

            obs_n.append(current_obs)

        obs_d = {
            "car_0": obs_n[0],
            #"car_6": obs_n[1],


        }

        return obs_d


    # render environment
    def render(self, mode='human'):

        self.screen.fill([128, 128, 128])
        self.pad_group.draw(self.screen)
        self.car_group.draw(self.screen)
        pygame.display.update()
        file_num = file_num + 1
        image = cam.get_image()
        # Save every frame
        filename = "Snaps/%04d.png" % file_num
        pygame.image.save(image, filename)
        #pygame.display.flip()

# %%
# environment for all agents in the multiagent world
# currently code assumes that no agents will be created/destroyed at runtime!
class MultiCarEnv4(gym.Env, MultiAgentEnv):
    metadata = {
        'render.modes' : ['human', 'console']
    }

    UP = 0
    DOWN = 1




    def __init__(self):
        super(MultiCarEnv4, self).__init__()

        pygame.init()
        self.screen = pygame.display.set_mode((1024, 800))
        self.screen.fill([128, 128, 128])
        pygame.display.update()


        def drawCirclePad(xc, yc, x, y, pads):
            pads.append(PadSprite((xc + x, yc + y),'pad_sq.png'))
            #pads.append(PadSprite((xc - x, yc + y),'pad_sq.png'))
            pads.append(PadSprite((xc + x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc - x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc + y, yc + x),'pad_sq.png'))
            #pads.append(PadSprite((xc - y, yc + x),'pad_sq.png'))
            pads.append(PadSprite((xc + y, yc - x),'pad_sq.png'))
            pads.append(PadSprite((xc - y, yc - x),'pad_sq.png'))

        def drawCirclePad2(xc, yc, x, y, pads):
            pads.append(PadSprite((xc + x, yc + y),'pad_sq.png'))
            pads.append(PadSprite((xc - x, yc + y),'pad_sq.png'))
            #pads.append(PadSprite((xc + x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc - x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc + y, yc + x),'pad_sq.png'))
            pads.append(PadSprite((xc - y, yc + x),'pad_sq.png'))
            #pads.append(PadSprite((xc + y, yc - x),'pad_sq.png'))
            pads.append(PadSprite((xc - y, yc - x),'pad_sq.png'))

        def drawCirclePad3(xc, yc, x, y, pads):
            pads.append(PadSprite((xc + x, yc + y),'pad_sq.png'))
            pads.append(PadSprite((xc - x, yc + y),'pad_sq.png'))
            pads.append(PadSprite((xc + x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc - x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc + y, yc + x),'pad_sq.png'))
            pads.append(PadSprite((xc - y, yc + x),'pad_sq.png'))
            pads.append(PadSprite((xc + y, yc - x),'pad_sq.png'))
            pads.append(PadSprite((xc - y, yc - x),'pad_sq.png'))


        def circleBres(xc, yc, r, pad, flag):

            x = 0
            y = r; 
            d = 3 - 2 * r 
            if flag == 1:
                drawCirclePad(xc, yc, x, y, pad)
            elif flag == 2:
                drawCirclePad2(xc, yc, x, y, pad)
            else:
                drawCirclePad3(xc, yc, x, y, pad)

            while y >= x:
                  
                x += 1

                if d > 0:
                    y -= 1
                    d = d + 4 * (x - y) + 10; 
                
                else:
                    d = d + 4 * x + 6; 
                if flag == 1:
                    drawCirclePad(xc, yc, x, y, pad)
                elif flag == 2:
                    drawCirclePad2(xc, yc, x, y, pad)
                else:
                    drawCirclePad3(xc, yc, x, y, pad)




        pads1 = []
        pads2 = []  

        circleBres(700, 220, 200, pads1, 1)
        circleBres(370, 550, 200, pads1, 2)
        circleBres(700, 220, 130, pads2, 1)
        circleBres(370, 550, 130, pads2, 2)


        #left horiz
        for i in range(370, 490):
            pads1.append(PadSprite((i, 350), 'pad_sq.png'))

        for i in range(370, 490):
            pads1.append(PadSprite((i, 420), 'pad_sq.png'))
        #right horiz
        for i in range(580, 700):
            pads1.append(PadSprite((i, 350), 'pad_sq.png'))

        for i in range(580, 700):
            pads1.append(PadSprite((i, 420), 'pad_sq.png'))
        #top vert
        for i in range(220, 350):
            pads1.append(PadSprite((500, i), 'pad_sq.png'))
        #bot vert
        for i in range(420, 550):
            pads1.append(PadSprite((570, i), 'pad_sq.png'))

        for i in range(420, 550):
            pads1.append(PadSprite((500, i), 'pad_sq.png'))

        for i in range(220, 350):
            pads1.append(PadSprite((570, i), 'pad_sq.png'))


        self.pad_group1 = pygame.sprite.RenderPlain(*pads1)
        self.pad_group2 = pygame.sprite.RenderPlain(*pads2)



        self.checkpoints = [CheckPointSprite(500, 200, 75, 30, 1), 
                      CheckPointSprite(650, 350, 30, 75, 2),
                      CheckPointSprite(340, 350, 30, 75, 3),
                      CheckPointSprite(500, 490, 75, 30, 4),
                      CheckPointSprite(500, 350, 100, 100, 5)
                      ]
        self.check_group = pygame.sprite.RenderPlain(*self.checkpoints)


        car10 = CarSprite('car.png', (530, 200))
        car2 = CarSprite('car.png', (590, 100))
        car3 = CarSprite('car.png', (700, 50))
        car4 = CarSprite('car.png', (810, 100))
        car5 = CarSprite('car.png', (865, 200))
        car6 = CarSprite('car.png', (830, 320))
        car7 = CarSprite('car.png', (700, 385))
        car7.cur_policy = 2
        car7.direction = 90
        car8 = CarSprite('car.png', (550, 385))
        car8.cur_policy = 2
        car8.direction = 90
        car9 = CarSprite('car.png', (400, 385))
        car9.cur_policy = 2
        car9.direction = 90
        car = CarSprite('car.png', (250, 450))
        car.cur_policy = 3
        #car = CarSprite('car.png', (200, 560))
        #car.cur_policy = 3
        self.cars = [car, car2, car3, car4, car5, car6, car7, car8, car9, car10]
        self.car_group = pygame.sprite.RenderPlain(*self.cars)


        def addSensor(car, sensors):
            sensors.append(SensorSprite(0, -250, car))
            sensors.append(SensorSprite(200, -230, car))
            sensors.append(SensorSprite(-200, -230, car))
            sensors.append(SensorSprite(250, 0, car))
            sensors.append(SensorSprite(-250, 0, car))
            sensors.append(SensorSprite(0, 250, car))
            sensors.append(SensorSprite(200, 230, car))
            sensors.append(SensorSprite(-200, 230, car))
            

        self.sensors = []
        


        for c in self.cars:
            curr = []
            addSensor(c, curr)
            self.sensors.append(curr)

        self.sensor_group = []
        for sensor in self.sensors:
            self.sensor_group.append(pygame.sprite.RenderPlain(*sensor))
    
        self.time = 0

        #accelerate, decelerate, nothing
        self.action_space = spaces.Discrete(3)
        #distance to another object, average velocity of other cars, own velocity
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf,
                                        shape=(10,), dtype=np.float32)

        self.wait = 3
        self.step_count = 0

        self.q = []
        self.delay = 0

        

    def step(self, action_n):
        self.step_count += 1
        self.delay += 1

        obs_d = {}
        reward_d = {}
        done_d =  {
            "car_0": False,      
            "__all__": False,  # the env is not done
        }

        info_d = {
            "car_0":{},
        }




        obs_n = []
        reward_n = []


        clock = pygame.time.Clock()
        #deltat = clock.tick(30)
        deltat = 30
        self.time += deltat
        # set and perform action for each agent
        i = 0
        idx = [0]
        for key, val in action_n.items():
            cur_action = val
            if cur_action == self.DOWN:
                self.cars[idx[i]].k_down = -1
            else:
                self.cars[idx[i]].k_down = 0
            if cur_action == self.UP:
                self.cars[idx[i]].k_up = 0.5
            else: 
                self.cars[idx[i]].k_up = 0
            i += 1

        if len(self.q) > 0 and (self.delay >= 35):
            temp = self.q.pop(0)
            temp.ready = True
            self.delay = 0

        i = 0
        for car in self.cars:

            other_cars = self.cars[:]
            other_cars.remove(car)
            other_cars_g = pygame.sprite.Group(other_cars)

            collisions_pad1 = pygame.sprite.spritecollide(car, self.pad_group1, False, collided = None)
            collisions_pad2 = pygame.sprite.spritecollide(car, self.pad_group2, False, collided = None)

            checks = pygame.sprite.spritecollide(car, self.check_group, False, collided = None)
            if len(checks) != 0 and checks[0].val != 5:
                car.cur_policy = checks[0].val


            #find the cars in range
            car_near = pygame.sprite.groupcollide(self.sensor_group[i].sprites()[0:3], other_cars_g, False, False, collided = None)
            #print(car_near)
            rect_list = []
            car_list = []
            #find the nearest car
            for key, value in car_near.items():
                for val in value:
                    car_list.append(val)
                    newrect = val.rect.clip(key.rect)
                    rect_list.append(newrect)
            #find nearest distance to other car
            mindist = 1000
            minCar = None
            k = 0
            for rec in rect_list:
                dist = math.sqrt((rec.centerx - car.rect.centerx) ** 2 + (rec.centery - car.rect.centery) ** 2)
                if dist < mindist:
                    mindist = dist
                    minCar = car_list[k]
                k += 1
            accel = 0


            #find car in front 
            car_front = pygame.sprite.spritecollide(self.sensor_group[i].sprites()[0], other_cars_g, False, collided = None)
            minFrontDist = 1000 
            minFrontCar = None
            front_rec_list = []
            for f in car_front:
                newrect = f.rect.clip(self.sensor_group[i].sprites()[0].rect)
                front_rec_list.append(newrect)
            k = 0
            for rec in front_rec_list:
                dist = math.sqrt((rec.centerx - car.rect.centerx) ** 2 + (rec.centery - car.rect.centery) ** 2)
                if dist < minFrontDist:
                    minFrontDist = dist
                    minFrontCar = car_front[k]
                k += 1





            if i != 0:
              if car.ready == True and (minFrontCar == None or car.speed < minFrontCar.speed):
                  if minFrontCar != None and 0.2 > minFrontCar.speed - car.speed:
                      accel = minFrontCar.speed - car.speed
                  else:
                      accel = 0.2
                  if len(checks) == 0:
                      car.ready = False
              elif mindist < 75:
                  if len(checks) > 0 and checks[0].val == 5 and car not in self.q: 
                      # queue to go
                      self.q.append(car)
                  accel = -(car.speed/2)
              else:
                  if minCar == None  or car.speed < minCar.speed:
                      #print("here" + " " + str(i) + str(minCar))
                      if minCar != None and 0.2 > minCar.speed - car.speed:
                          accel = minCar.speed - car.speed
                      else:
                          accel = 0.2
              car.speed += accel
            else:
               if car.ready == True and (minFrontCar == None or car.speed < minFrontCar.speed):
                  if len(checks) == 0:
                      car.ready = False
               elif mindist < 75:
                  if len(checks) > 0 and checks[0].val == 5 and car not in self.q: 
                      # queue to go
                      self.q.append(car)
                  accel = -(car.speed/2)
                  car.k_down = 0
                  car.k_up = 0  
                  car.speed += accel    


            x = car.rect.centerx
            y = car.rect.centery

            if car.cur_policy == 1:
                theta = (700 - x)/(math.sqrt((x - 700)**2 + (y-220)**2))
                if y > 220:
                    car.direction = (math.degrees(math.acos(theta)) % 360)
                else: 
                    car.direction = -math.degrees(math.acos(theta) % 360)
                if len(collisions_pad1) != 0:
                    car.direction -= 10
                elif len(collisions_pad2) != 0: 
                    car.direction += 10
            elif car.cur_policy == 3:
                theta = (370 - x)/(math.sqrt((x - 370)**2 + (y-550)**2))
                if y > 550:
                    car.direction = (math.degrees(math.acos(theta)) % 360) + 180 
                else: 
                    car.direction = -math.degrees(math.acos(theta) % 360) + 180
                if len(collisions_pad1) != 0:
                    car.direction += 10
                elif len(collisions_pad2) != 0: 
                    car.direction -= 10
            elif car.cur_policy == 2:
                car.direction = 90
            elif car.cur_policy == 4:
                car.direction = 0


            i += 1
        
        self.car_group.update(deltat)
        for s in self.sensor_group:
          s.update()

        if self.step_count == 1000:
          done_d['__all__'] = True
        

        avg_speed = 0
        for c in self.cars:
            avg_speed += c.speed
        avg_speed /= len(self.cars)
        #print(str(avg_speed) + " " + str(self.cars[0].cur_policy) + " " + str(self.cars[0].position))

        # record observation for each agent
        j = 0
        for car in self.cars:
            if j != 0: 
              continue
            current_obs = np.zeros(10)
            current_reward = 0
            closest_obj = 1000

            other_cars = self.cars[:]
            other_cars.remove(car)
            other_car_group = pygame.sprite.Group(other_cars)
            #print(other_cars)

            for i in range(0, len(self.sensors[j])):
                cur_sensor = self.sensors[j][i]
                
                #pad_near = pygame.sprite.spritecollide(cur_sensor, self.pad_group1, False, collided = None)
                #pad_near2 = pygame.sprite.spritecollide(cur_sensor, self.pad_group2, False, collided = None)
                car_near = pygame.sprite.spritecollide(cur_sensor, other_car_group, False, collided = None)
                nearest_dist = 400
                rect_list = []
                # use clip rect function
                '''for pad in pad_near:
                    newrect = pad.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for pad in pad_near2:
                    newrect = pad.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)'''
                for other_car in car_near:
                    newrect = other_car.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for rec in rect_list:
                    cur_dist = math.sqrt((rec.centerx - car.rect.centerx) ** 2 + (rec.centery - car.rect.centery) ** 2)
                    if  cur_dist < nearest_dist:
                        nearest_dist = cur_dist
                current_obs[i] = nearest_dist
            
            
            current_obs[8] = car.speed
            current_obs[9] = avg_speed

            car_collide = pygame.sprite.spritecollide(car, other_car_group, False, collided = None)
            '''if len(car_collide) != 0:
                #print(car_collide)
                #print(car.position)
                #print("here " + str(self.step_count) + " " + str(avg_speed))
                done_d['__all__'] = True'''

            current_reward += avg_speed

            obs_n.append(current_obs)
            reward_n.append(current_reward)
            j += 1
       
        obs_d = {
            "car_0": obs_n[0],
        }
        reward_d = {
            "car_0": reward_n[0],
        }
        

        if done_d["__all__"] == True:
            print(avg_speed)
            print('Done')


        return obs_d, reward_d, done_d, info_d

    def reset(self):

        self.delay = 0
        self.q = []
       
        # record observations for each agent
        obs_n = []

        self.step_count = 0

        for c in self.cars:
          c.speed = 0

        car10 = CarSprite('car.png', (530, 200))
        car2 = CarSprite('car.png', (590, 100))
        car3 = CarSprite('car.png', (700, 50))
        car4 = CarSprite('car.png', (810, 100))
        car5 = CarSprite('car.png', (865, 200))
        car6 = CarSprite('car.png', (830, 320))
        car7 = CarSprite('car.png', (700, 385))
        car7.cur_policy = 2
        car7.direction = 90
        car8 = CarSprite('car.png', (550, 385))
        car8.cur_policy = 2
        car8.direction = 90
        car9 = CarSprite('car.png', (400, 385))
        car9.cur_policy = 2
        car9.direction = 90
        car = CarSprite('car.png', (250, 450))
        car.cur_policy = 3
        #car = CarSprite('car.png', (200, 560))
        #car.cur_policy = 3
        self.cars = [car, car2, car3, car4, car5, car6, car7, car8, car9, car10]
        self.car_group = pygame.sprite.RenderPlain(*self.cars)


        def addSensor(car, sensors):
            sensors.append(SensorSprite(0, -250, car))
            sensors.append(SensorSprite(200, -230, car))
            sensors.append(SensorSprite(-200, -230, car))
            sensors.append(SensorSprite(250, 0, car))
            sensors.append(SensorSprite(-250, 0, car))
            sensors.append(SensorSprite(0, 250, car))
            sensors.append(SensorSprite(200, 230, car))
            sensors.append(SensorSprite(-200, 230, car))
            

        self.sensors = []
        


        for c in self.cars:
            curr = []
            addSensor(c, curr)
            self.sensors.append(curr)

        self.sensor_group = []
        for sensor in self.sensors:
            self.sensor_group.append(pygame.sprite.RenderPlain(*sensor))
        

        self.car_group.update(30)   
        for s in self.sensor_group:     
            s.update() 


         # record observation for each agent
        j = 0
        for car in self.cars:
            if j != 0:
              continue
            current_obs = np.zeros(10)
            current_reward = 0
            closest_obj = 500

            other_cars = self.cars[:]
            other_cars.remove(car)
            other_car_group = pygame.sprite.Group(other_cars)
            #print(other_cars)

            for i in range(0, len(self.sensors[j])):
                cur_sensor = self.sensors[j][i]
                
                #pad_near = pygame.sprite.spritecollide(cur_sensor, self.pad_group1, False, collided = None)
                #pad_near2 = pygame.sprite.spritecollide(cur_sensor, self.pad_group2, False, collided = None)
                car_near = pygame.sprite.spritecollide(cur_sensor, other_car_group, False, collided = None)
                nearest_dist = 400
                rect_list = []
                # use clip rect function
                '''for pad in pad_near:
                    newrect = pad.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for pad in pad_near2:
                    newrect = pad.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)'''
                for other_car in car_near:
                    newrect = other_car.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for rec in rect_list:
                    cur_dist = math.sqrt((rec.centerx - car.rect.centerx) ** 2 + (rec.centery - car.rect.centery) ** 2)
                    if  cur_dist < nearest_dist:
                        nearest_dist = cur_dist
                current_obs[i] = nearest_dist
            
            current_obs[8] = 0
            current_obs[9] = 0
            


   

            obs_n.append(current_obs)
            j += 1

        obs_d = {
            "car_0": obs_n[0],

        }

        return obs_d


    # render environment
    def render(self, mode='human'):

        self.screen.fill([128, 128, 128])
        self.pad_group.draw(self.screen)
        self.car_group.draw(self.screen)
        pygame.display.update()
        file_num = file_num + 1
        image = cam.get_image()
        # Save every frame
        filename = "Snaps/%04d.png" % file_num
        pygame.image.save(image, filename)
        #pygame.display.flip()

# %%
import random
from ray.rllib.agents.pg.pg import PGTrainer
from ray.rllib.agents.ppo.ppo import PPOTrainer
from ray.rllib.agents.dqn.dqn import DQNTrainer
from ray import tune

ray.init()

num_episodes = 0
cur_reward = 0
final_rewards = []
final_checkpoints =[]


register_env("multienv", lambda config: MultiCarEnv2())
register_env("multienv2", lambda config: MultiCarEnv4())

trainer = DQNTrainer(env="multienv", config={"timesteps_per_iteration": 1000, "gamma":.99,  "exploration_config": {
        # The Exploration class to use.
        "type": "EpsilonGreedy",
        # Config for the Exploration class' constructor:
        "initial_epsilon": 1.0,
        "final_epsilon": 0.05,
        "epsilon_timesteps": 10000,  # Timesteps over which to anneal epsilon.
    },})
i = 0
while i < 75:
    t_dict = trainer.train()
    print(t_dict)
    rewards = t_dict['hist_stats']['episode_reward']
    ep_lens = t_dict['hist_stats']['episode_lengths']
    ep_total = t_dict['episodes_this_iter']
    for j in range(ep_total):
      num_episodes += 1
    for j in range(ep_total):
      final_rewards.append(rewards[j] / 500)

    i += 1



moving_average = []
curr_total = 0
for i in range(len(final_rewards)):
  if i < 9:
    moving_average.append(0)
    curr_total += final_rewards[i]
  else:
    curr_total += final_rewards[i]
    moving_average.append(curr_total/10)
    curr_total -= final_rewards[i-9]
  
  

check_point = trainer.save()

trainer2 = DQNTrainer(env="multienv2", config={"timesteps_per_iteration": 2000, "gamma":.99,  "exploration_config": {
        # The Exploration class to use.
        "type": "EpsilonGreedy",
        # Config for the Exploration class' constructor:
        "initial_epsilon": 1.0,
        "final_epsilon": 0.05,
        "epsilon_timesteps": 10000,  # Timesteps over which to anneal epsilon.
    },})
trainer2.restore(check_point)

print(len(final_rewards))
print(num_episodes)
plt.style.use('seaborn-darkgrid')
plt.plot(final_rewards, label="reward")
plt.plot(moving_average, label="avg last 10 episodes")
plt.legend(loc='lower right')
plt.xlabel('Episode Count')
plt.ylabel('Reward (Average Velocity)')
plt.title('2 Agent Circle Track PPO Training')
plt.show()


num_episodes = 0
cur_reward = 0
final_rewards2 = []


i = 0
while i < 75:
    t_dict = trainer2.train()
    print(t_dict)
    rewards = t_dict['hist_stats']['episode_reward']
    ep_lens = t_dict['hist_stats']['episode_lengths']
    ep_total = t_dict['episodes_this_iter']
    for j in range(ep_total):
      num_episodes += 1
    for j in range(ep_total):
      final_rewards2.append(rewards[j] / 1000)

    i += 1



moving_average2 = []
curr_total = 0
for i in range(len(final_rewards2)):
  if i < 9:
    moving_average2.append(0)
    curr_total += final_rewards2[i]
  else:
    curr_total += final_rewards2[i]
    moving_average2.append(curr_total/10)
    curr_total -= final_rewards2[i-9]
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Install gputil for GPU system monitoring.
# 0.2749076759782367
# Done
# You are trying to log an invalid value (ray/tune/info/exploration_infos=[{'cur_epsilon': 1.0}]) via TBXLogger!
# 0.36940467258541704
# Done
# {'episode_reward_max': 1220.6364578783957, 'episode_reward_min': 995.0551388276447, 'episode_reward_mean': 1107.8457983530202, 'episode_len_mean': 500.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [995.0551388276447, 1220.6364578783957], 'episode_lengths': [500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 5.527874092002968, 'mean_processing_ms': 0.374140915694413, 'mean_inference_ms': 1.8768634472217236}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 1.0}], 'num_target_updates': 1, 'num_steps_trained': 0, 'num_steps_sampled': 1000, 'sample_time_ms': 32.194, 'replay_time_ms': 0.0, 'grad_time_ms': 0.0, 'update_time_ms': 0.004, 'opt_peak_throughput': 0.0, 'opt_samples': 0.0, 'learner': {}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 1000, 'episodes_total': 2, 'training_iteration': 1, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-26_23-57-12', 'timestamp': 1587945432, 'time_this_iter_s': 8.079528570175171, 'time_total_s': 8.079528570175171, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shuffle_buffer_size': 0, 'output': None, 'output_compress_columns': ['obs', 'new_obs'], 'output_max_file_size': 67108864, 'multiagent': {'policies': {}, 'policy_mapping_fn': None, 'policies_to_train': None}, 'num_atoms': 1, 'v_min': -10.0, 'v_max':  ...
# 0.15848329419093246
# Done
# 0.9720621748847146
# Done
# {'episode_reward_max': 1324.6056988892224, 'episode_reward_min': 995.0551388276447, 'episode_reward_mean': 1140.1712676251934, 'episode_len_mean': 500.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [1020.3877749055112, 1324.6056988892224, 995.0551388276447, 1220.6364578783957], 'episode_lengths': [500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 5.535607181602476, 'mean_processing_ms': 0.3345013700957026, 'mean_inference_ms': 1.837815412942191}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 1.0}], 'num_target_updates': 3, 'num_steps_trained': 8000, 'num_steps_sampled': 2000, 'sample_time_ms': 30.695, 'replay_time_ms': 1.632, 'grad_time_ms': 8.111, 'update_time_ms': 0.004, 'opt_peak_throughput': 3945.41, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 7.874509, 'min_q': 4.863265, 'max_q': 19.590925, 'mean_td_error': -0.5919096, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 2000, 'episodes_total': 4, 'training_iteration': 2, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-26_23-57-22', 'timestamp': 1587945442, 'time_this_iter_s': 10.419678926467896, 'time_total_s': 18.499207496643066, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shuffle_buffer_size': 0, 'output' ...
# 1.1518736884088623
# Done
# 2.6265515301359543
# Done
# {'episode_reward_max': 1797.2964553807344, 'episode_reward_min': 995.0551388276447, 'episode_reward_mean': 1318.3213765854387, 'episode_len_mean': 500.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [1797.2964553807344, 1551.946733631124, 995.0551388276447, 1220.6364578783957, 1020.3877749055112, 1324.6056988892224], 'episode_lengths': [500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 5.534842085126807, 'mean_processing_ms': 0.3129817217454428, 'mean_inference_ms': 1.8229320617768687}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.905}], 'num_target_updates': 5, 'num_steps_trained': 16000, 'num_steps_sampled': 3000, 'sample_time_ms': 30.608, 'replay_time_ms': 1.562, 'grad_time_ms': 7.689, 'update_time_ms': 0.004, 'opt_peak_throughput': 4161.725, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 12.778434, 'min_q': 6.4787145, 'max_q': 35.354942, 'mean_td_error': -0.21921422, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 3000, 'episodes_total': 6, 'training_iteration': 3, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-26_23-57-33', 'timestamp': 1587945453, 'time_this_iter_s': 10.299051761627197, 'time_total_s': 28.798259258270264, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postp ...
# 2.551363340623078
# Done
# 1.975910224398082
# Done
# {'episode_reward_max': 1943.8815260727872, 'episode_reward_min': 995.0551388276447, 'episode_reward_mean': 1422.6546516660583, 'episode_len_mean': 500.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [1943.8815260727872, 1527.4274277430457, 995.0551388276447, 1220.6364578783957, 1020.3877749055112, 1324.6056988892224, 1797.2964553807344, 1551.946733631124], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 5.535252092407804, 'mean_processing_ms': 0.29910388499949614, 'mean_inference_ms': 1.8154760304313535}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.81}], 'num_target_updates': 7, 'num_steps_trained': 24000, 'num_steps_sampled': 4000, 'sample_time_ms': 31.074, 'replay_time_ms': 1.551, 'grad_time_ms': 8.25, 'update_time_ms': 0.004, 'opt_peak_throughput': 3878.565, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 17.80556, 'min_q': 9.649616, 'max_q': 56.494087, 'mean_td_error': -0.39456463, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 4000, 'episodes_total': 8, 'training_iteration': 4, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-26_23-57-43', 'timestamp': 1587945463, 'time_this_iter_s': 10.212729692459106, 'time_total_s': 39.01098895072937, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampl ...
# 0.583248519897461
# Done
# 0.014584054743375837
# Done
# {'episode_reward_max': 2190.9933876867344, 'episode_reward_min': 995.0551388276447, 'episode_reward_mean': 1500.6128237617954, 'episode_len_mean': 500.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [1433.8976366027543, 2190.9933876867344, 995.0551388276447, 1220.6364578783957, 1020.3877749055112, 1324.6056988892224, 1797.2964553807344, 1551.946733631124, 1943.8815260727872, 1527.4274277430457], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 5.533302518839048, 'mean_processing_ms': 0.28906022571143053, 'mean_inference_ms': 1.8093239678056243}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.715}], 'num_target_updates': 9, 'num_steps_trained': 32000, 'num_steps_sampled': 5000, 'sample_time_ms': 31.055, 'replay_time_ms': 1.609, 'grad_time_ms': 8.259, 'update_time_ms': 0.004, 'opt_peak_throughput': 3874.433, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 24.388447, 'min_q': 10.159933, 'max_q': 76.45827, 'mean_td_error': -0.43663323, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 5000, 'episodes_total': 10, 'training_iteration': 5, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-26_23-57-53', 'timestamp': 1587945473, 'time_this_iter_s': 10.225976467132568, 'time_total_s': 49.23696541786194, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0 ...
# 1.4833498559135478
# Done
# 6.166667461395266
# Done
# {'episode_reward_max': 2317.97631823629, 'episode_reward_min': 995.0551388276447, 'episode_reward_mean': 1603.3921754196824, 'episode_len_mean': 500.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [1916.6015491819448, 2317.97631823629, 995.0551388276447, 1220.6364578783957, 1020.3877749055112, 1324.6056988892224, 1797.2964553807344, 1551.946733631124, 1943.8815260727872, 1527.4274277430457, 1433.8976366027543, 2190.9933876867344], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 5.5314188645291695, 'mean_processing_ms': 0.2812949938262084, 'mean_inference_ms': 1.8037057399515835}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.62}], 'num_target_updates': 11, 'num_steps_trained': 40000, 'num_steps_sampled': 6000, 'sample_time_ms': 30.708, 'replay_time_ms': 1.696, 'grad_time_ms': 8.213, 'update_time_ms': 0.004, 'opt_peak_throughput': 3896.366, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 34.475586, 'min_q': 17.221447, 'max_q': 85.33531, 'mean_td_error': 0.27970982, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 6000, 'episodes_total': 12, 'training_iteration': 6, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-26_23-58-03', 'timestamp': 1587945483, 'time_this_iter_s': 10.050593852996826, 'time_total_s': 59.287559270858765, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'o ...
# 5.768750397364296
# Done
# 4.562500198682343
# Done
# {'episode_reward_max': 2588.939062069611, 'episode_reward_min': 995.0551388276447, 'episode_reward_mean': 1721.5364644664364, 'episode_len_mean': 500.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [2271.865335424306, 2588.939062069611, 995.0551388276447, 1220.6364578783957, 1020.3877749055112, 1324.6056988892224, 1797.2964553807344, 1551.946733631124, 1943.8815260727872, 1527.4274277430457, 1433.8976366027543, 2190.9933876867344, 1916.6015491819448, 2317.97631823629], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 5.528137986416128, 'mean_processing_ms': 0.27478303958966904, 'mean_inference_ms': 1.7996134624455447}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.525}], 'num_target_updates': 13, 'num_steps_trained': 48000, 'num_steps_sampled': 7000, 'sample_time_ms': 29.414, 'replay_time_ms': 1.553, 'grad_time_ms': 7.322, 'update_time_ms': 0.004, 'opt_peak_throughput': 4370.603, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 40.680084, 'min_q': 19.852476, 'max_q': 78.82763, 'mean_td_error': -2.2007008, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 7000, 'episodes_total': 14, 'training_iteration': 7, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-26_23-58-13', 'timestamp': 1587945493, 'time_this_iter_s': 9.934942483901978, 'time_total_s': 69.22250175476074, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker ...
# 6.154941672086711
# Done
# 5.346402231852212
# Done
# {'episode_reward_max': 2671.5634551555586, 'episode_reward_min': 995.0551388276447, 'episode_reward_mean': 1818.1430351394474, 'episode_len_mean': 500.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [2671.5634551555586, 2317.2146045454956, 995.0551388276447, 1220.6364578783957, 1020.3877749055112, 1324.6056988892224, 1797.2964553807344, 1551.946733631124, 1943.8815260727872, 1527.4274277430457, 1433.8976366027543, 2190.9933876867344, 1916.6015491819448, 2317.97631823629, 2271.865335424306, 2588.939062069611], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 5.524821648930275, 'mean_processing_ms': 0.26943098671043786, 'mean_inference_ms': 1.7949147388355917}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.43}], 'num_target_updates': 15, 'num_steps_trained': 56000, 'num_steps_sampled': 8000, 'sample_time_ms': 30.112, 'replay_time_ms': 1.556, 'grad_time_ms': 7.52, 'update_time_ms': 0.004, 'opt_peak_throughput': 4255.571, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 53.422882, 'min_q': 31.748281, 'max_q': 126.69311, 'mean_td_error': -2.027454, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 8000, 'episodes_total': 16, 'training_iteration': 8, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-26_23-58-23', 'timestamp': 1587945503, 'time_this_iter_s': 10.093101978302002, 'time_total_s': 79.31560373306274, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num ...
# 5.437500011928627
# Done
# 4.392549648135923
# Done
# {'episode_reward_max': 3000.0383218201155, 'episode_reward_min': 995.0551388276447, 'episode_reward_mean': 1898.1905551012544, 'episode_len_mean': 500.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [2077.1031077713005, 3000.0383218201155, 995.0551388276447, 1220.6364578783957, 1020.3877749055112, 1324.6056988892224, 1797.2964553807344, 1551.946733631124, 1943.8815260727872, 1527.4274277430457, 1433.8976366027543, 2190.9933876867344, 1916.6015491819448, 2317.97631823629, 2271.865335424306, 2588.939062069611, 2671.5634551555586, 2317.2146045454956], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 5.5219436864450655, 'mean_processing_ms': 0.26509037805910285, 'mean_inference_ms': 1.7915017321349065}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.335}], 'num_target_updates': 17, 'num_steps_trained': 64000, 'num_steps_sampled': 9000, 'sample_time_ms': 30.97, 'replay_time_ms': 1.559, 'grad_time_ms': 7.477, 'update_time_ms': 0.004, 'opt_peak_throughput': 4279.957, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 62.27416, 'min_q': 28.81485, 'max_q': 123.52252, 'mean_td_error': -2.5753338, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 9000, 'episodes_total': 18, 'training_iteration': 9, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-26_23-58-33', 'timestamp': 1587945513, 'time_this_iter_s': 10.074602842330933, 'time_total_s': 89.39020657539368, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': ...
# 4.5833333581693605
# Done
# 6.325130258003868
# Done
# {'episode_reward_max': 3000.0383218201155, 'episode_reward_min': 995.0551388276447, 'episode_reward_mean': 1968.7445051087827, 'episode_len_mean': 500.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [2394.163220643002, 2813.2968897100754, 995.0551388276447, 1220.6364578783957, 1020.3877749055112, 1324.6056988892224, 1797.2964553807344, 1551.946733631124, 1943.8815260727872, 1527.4274277430457, 1433.8976366027543, 2190.9933876867344, 1916.6015491819448, 2317.97631823629, 2271.865335424306, 2588.939062069611, 2671.5634551555586, 2317.2146045454956, 2077.1031077713005, 3000.0383218201155], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 5.5190270373522115, 'mean_processing_ms': 0.2613114013840424, 'mean_inference_ms': 1.7874055838610243}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.24}], 'num_target_updates': 19, 'num_steps_trained': 72000, 'num_steps_sampled': 10000, 'sample_time_ms': 29.658, 'replay_time_ms': 1.566, 'grad_time_ms': 8.037, 'update_time_ms': 0.004, 'opt_peak_throughput': 3981.576, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 64.96925, 'min_q': 31.728573, 'max_q': 144.00468, 'mean_td_error': -1.554243, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 10000, 'episodes_total': 20, 'training_iteration': 10, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-26_23-58-43', 'timestamp': 1587945523, 'time_this_iter_s': 9.984692096710205, 'time_total_s': 99.37489867210388, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0 ...
# 6.716673136642203
# Done
# 6.582477239845314
# Done
# {'episode_reward_max': 3000.0383218201155, 'episode_reward_min': 995.0551388276447, 'episode_reward_mean': 2054.1326270537397, 'episode_len_mean': 500.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [2889.8680784762014, 2926.159614530422, 995.0551388276447, 1220.6364578783957, 1020.3877749055112, 1324.6056988892224, 1797.2964553807344, 1551.946733631124, 1943.8815260727872, 1527.4274277430457, 1433.8976366027543, 2190.9933876867344, 1916.6015491819448, 2317.97631823629, 2271.865335424306, 2588.939062069611, 2671.5634551555586, 2317.2146045454956, 2077.1031077713005, 3000.0383218201155, 2394.163220643002, 2813.2968897100754], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 5.5168217705186215, 'mean_processing_ms': 0.25816768494725617, 'mean_inference_ms': 1.7836710840782457}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.145}], 'num_target_updates': 21, 'num_steps_trained': 80000, 'num_steps_sampled': 11000, 'sample_time_ms': 30.464, 'replay_time_ms': 1.582, 'grad_time_ms': 7.943, 'update_time_ms': 0.004, 'opt_peak_throughput': 4028.711, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 76.839645, 'min_q': 37.167156, 'max_q': 153.82141, 'mean_td_error': -0.39209044, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 11000, 'episodes_total': 22, 'training_iteration': 11, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-26_23-58-53', 'timestamp': 1587945533, 'time_this_iter_s': 10.067631959915161, 'time_total_s': 109.44253063201904, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'r ...
# 5.579809658415615
# Done
# 5.233886776193683
# Done
# ...
# 5.292073573383579
# Done
# 5.345943164398581
# Done
# {'episode_reward_max': 3543.5674428633847, 'episode_reward_min': 3014.400475445748, 'episode_reward_mean': 3308.031856119828, 'episode_len_mean': 500.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3415.6281486493767, 3438.5806380234267, 3249.0352677104975, 3468.6414673922927, 3397.265938690417, 3351.6358310136725, 3375.6654047130064, 3326.8921506448573, 3428.453809471031, 3267.5023497566585, 3247.2757967837815, 3344.1320081399604, 3446.6199019324317, 3191.5969976952933, 3401.1577149886944, 3354.516688740746, 3387.71611935055, 3302.8197165054403, 3366.415545365479, 3347.4649701391427, 3398.6507518753197, 3424.0775410562196, 3454.5813804799736, 3079.8995350565738, 3266.766012289913, 3338.743112165638, 3322.2883232369077, 3317.0855121201125, 3193.641217220575, 3019.04736142576, 3194.959223585522, 3132.973540536701, 3428.311819441882, 3315.655034961987, 3368.900208264033, 3113.12408311143, 3203.7386836051346, 3529.0687139791744, 3472.878135459173, 3116.533100980061, 3141.842788346857, 3256.0387552682905, 3097.722991398474, 3116.437732842328, 3149.044363554566, 3212.401884358159, 3461.6256365832805, 3298.906432717881, 3227.068041190048, 3433.042031077704, 3250.3024947792414, 3446.361026241485, 3424.7235832188517, 3442.9337626452516, 3334.7380139677284, 3308.565077257741, 3543.5674428633847, 3256.9516420408922, 3035.049031177164, 3214.443491166736, 3175.244938563708, 3264.122965289278, 3201.5263268046147, 3175.2267993565347, 3264.7680969404955, 3112.404001102104, 3014.400475445748, 3388.1517463836526, 3353.6925452377914, 3275.155953797531, 3134.5852965186677, 3119.3952460746964, 3322.7642218742717, 3160.9069490173365, 3417.6277850634606, 3224.4749545017908, 3293.568975620286, 3463.277827882535, 3358.9512992338277, 3530.3653398693455, 3107.9013387052933, 3060.603002109776, 3440.0498050342835, 3457.1634986104355, 3415.2234300423374, 3350.5641988926145, 3236.0905857872685, 3398.1768492515694, 3408.9122777216103, 3440.4639978422674, 3478.02525887031, 3434.8137886646205, 3496.582854152319, 3407.051935581113, 3470.802166908227, 3438.5278669594504, 3169.583668193608, 3310.0076265137122, 3232.0744868047937, 3348.249251504605], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 5.461396162289625, 'mean_processing_ms': 0.20992132815608977, 'mean_inference_ms': 1.6092272575604665}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 144, 'num_steps_trained': 576000, 'num_steps_sampled': 73000, 'sample_time_ms': 27.564, 'replay_time_ms': 1.631, 'grad_time_ms': 7.775, 'update_time_ms': 0.003, 'opt_peak_throughput': 4115.884, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 478.6756, 'min_q': 436.7161, 'max_q': 526.63434, 'mean_td_error': 11.988134, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 73000, 'episodes_total': 146, 'training_iteration': 73, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-09-07', 'timestamp': 1587946147, 'time_this_iter_s': 9.47797179222107, 'time_total_s': 723.060714006424, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv ...
# 6.790430386861163
# Done
# 5.6754069012359025
# Done
# {'episode_reward_max': 3543.5674428633847, 'episode_reward_min': 3014.400475445748, 'episode_reward_mean': 3306.2085694049038, 'episode_len_mean': 500.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3483.8704476739304, 3051.4776159364183, 3397.265938690417, 3351.6358310136725, 3375.6654047130064, 3326.8921506448573, 3428.453809471031, 3267.5023497566585, 3247.2757967837815, 3344.1320081399604, 3446.6199019324317, 3191.5969976952933, 3401.1577149886944, 3354.516688740746, 3387.71611935055, 3302.8197165054403, 3366.415545365479, 3347.4649701391427, 3398.6507518753197, 3424.0775410562196, 3454.5813804799736, 3079.8995350565738, 3266.766012289913, 3338.743112165638, 3322.2883232369077, 3317.0855121201125, 3193.641217220575, 3019.04736142576, 3194.959223585522, 3132.973540536701, 3428.311819441882, 3315.655034961987, 3368.900208264033, 3113.12408311143, 3203.7386836051346, 3529.0687139791744, 3472.878135459173, 3116.533100980061, 3141.842788346857, 3256.0387552682905, 3097.722991398474, 3116.437732842328, 3149.044363554566, 3212.401884358159, 3461.6256365832805, 3298.906432717881, 3227.068041190048, 3433.042031077704, 3250.3024947792414, 3446.361026241485, 3424.7235832188517, 3442.9337626452516, 3334.7380139677284, 3308.565077257741, 3543.5674428633847, 3256.9516420408922, 3035.049031177164, 3214.443491166736, 3175.244938563708, 3264.122965289278, 3201.5263268046147, 3175.2267993565347, 3264.7680969404955, 3112.404001102104, 3014.400475445748, 3388.1517463836526, 3353.6925452377914, 3275.155953797531, 3134.5852965186677, 3119.3952460746964, 3322.7642218742717, 3160.9069490173365, 3417.6277850634606, 3224.4749545017908, 3293.568975620286, 3463.277827882535, 3358.9512992338277, 3530.3653398693455, 3107.9013387052933, 3060.603002109776, 3440.0498050342835, 3457.1634986104355, 3415.2234300423374, 3350.5641988926145, 3236.0905857872685, 3398.1768492515694, 3408.9122777216103, 3440.4639978422674, 3478.02525887031, 3434.8137886646205, 3496.582854152319, 3407.051935581113, 3470.802166908227, 3438.5278669594504, 3169.583668193608, 3310.0076265137122, 3232.0744868047937, 3348.249251504605, 3415.6281486493767, 3438.5806380234267], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 5.461266407751165, 'mean_processing_ms': 0.2097988714908252, 'mean_inference_ms': 1.608438842999}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 146, 'num_steps_trained': 584000, 'num_steps_sampled': 74000, 'sample_time_ms': 28.829, 'replay_time_ms': 1.651, 'grad_time_ms': 7.6, 'update_time_ms': 0.003, 'opt_peak_throughput': 4210.501, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 476.38116, 'min_q': 446.69662, 'max_q': 531.4564, 'mean_td_error': 11.202473, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 74000, 'episodes_total': 148, 'training_iteration': 74, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-09-17', 'timestamp': 1587946157, 'time_this_iter_s': 9.64392876625061, 'time_total_s': 732.7046427726746, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_act ...
# 4.440104531042741
# Done
# 6.056252195010892
# Done
# {'episode_reward_max': 3543.5674428633847, 'episode_reward_min': 3001.7923759965374, 'episode_reward_mean': 3302.801566060975, 'episode_len_mean': 500.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3001.7923759965374, 3406.4090593146393, 3375.6654047130064, 3326.8921506448573, 3428.453809471031, 3267.5023497566585, 3247.2757967837815, 3344.1320081399604, 3446.6199019324317, 3191.5969976952933, 3401.1577149886944, 3354.516688740746, 3387.71611935055, 3302.8197165054403, 3366.415545365479, 3347.4649701391427, 3398.6507518753197, 3424.0775410562196, 3454.5813804799736, 3079.8995350565738, 3266.766012289913, 3338.743112165638, 3322.2883232369077, 3317.0855121201125, 3193.641217220575, 3019.04736142576, 3194.959223585522, 3132.973540536701, 3428.311819441882, 3315.655034961987, 3368.900208264033, 3113.12408311143, 3203.7386836051346, 3529.0687139791744, 3472.878135459173, 3116.533100980061, 3141.842788346857, 3256.0387552682905, 3097.722991398474, 3116.437732842328, 3149.044363554566, 3212.401884358159, 3461.6256365832805, 3298.906432717881, 3227.068041190048, 3433.042031077704, 3250.3024947792414, 3446.361026241485, 3424.7235832188517, 3442.9337626452516, 3334.7380139677284, 3308.565077257741, 3543.5674428633847, 3256.9516420408922, 3035.049031177164, 3214.443491166736, 3175.244938563708, 3264.122965289278, 3201.5263268046147, 3175.2267993565347, 3264.7680969404955, 3112.404001102104, 3014.400475445748, 3388.1517463836526, 3353.6925452377914, 3275.155953797531, 3134.5852965186677, 3119.3952460746964, 3322.7642218742717, 3160.9069490173365, 3417.6277850634606, 3224.4749545017908, 3293.568975620286, 3463.277827882535, 3358.9512992338277, 3530.3653398693455, 3107.9013387052933, 3060.603002109776, 3440.0498050342835, 3457.1634986104355, 3415.2234300423374, 3350.5641988926145, 3236.0905857872685, 3398.1768492515694, 3408.9122777216103, 3440.4639978422674, 3478.02525887031, 3434.8137886646205, 3496.582854152319, 3407.051935581113, 3470.802166908227, 3438.5278669594504, 3169.583668193608, 3310.0076265137122, 3232.0744868047937, 3348.249251504605, 3415.6281486493767, 3438.5806380234267, 3483.8704476739304, 3051.4776159364183], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 5.461132242021379, 'mean_processing_ms': 0.2096700693912002, 'mean_inference_ms': 1.6075692772531907}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 148, 'num_steps_trained': 592000, 'num_steps_sampled': 75000, 'sample_time_ms': 27.784, 'replay_time_ms': 1.632, 'grad_time_ms': 7.312, 'update_time_ms': 0.003, 'opt_peak_throughput': 4376.175, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 485.54044, 'min_q': 452.3596, 'max_q': 533.1213, 'mean_td_error': 11.120093, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 75000, 'episodes_total': 150, 'training_iteration': 75, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-09-27', 'timestamp': 1587946167, 'time_this_iter_s': 9.499295473098755, 'time_total_s': 742.2039382457733, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'c ...
# Install gputil for GPU system monitoring.
# ---------------------------------------------------------------------------
# RayConnectionError                        Traceback (most recent call last)
# <ipython-input-8-211eca013188> in <module>()
#      63         "epsilon_timesteps": 10000,  # Timesteps over which to anneal epsilon.
#      64     },})
# ---> 65 trainer2.restore(check_point)
#      66
#      67 print(len(final_rewards))
#
# /usr/local/lib/python3.6/dist-packages/ray/tune/trainable.py in restore(self, checkpoint_path)
#     415             self._restore(checkpoint_dict)
#     416         else:
# --> 417             self._restore(checkpoint_path)
#     418         self._time_since_restore = 0.0
#     419         self._timesteps_since_restore = 0
#
# /usr/local/lib/python3.6/dist-packages/ray/rllib/agents/trainer.py in _restore(self, checkpoint_path)
#     636     def _restore(self, checkpoint_path):
#     637         extra_data = pickle.load(open(checkpoint_path, "rb"))
# --> 638         self.__setstate__(extra_data)
#     639
#     640     @DeveloperAPI
#
# /usr/local/lib/python3.6/dist-packages/ray/rllib/agents/trainer_template.py in __setstate__(self, state)
#     191
#     192         def __setstate__(self, state):
# --> 193             Trainer.__setstate__(self, state)
#     194             self.state = state["trainer_state"].copy()
#     195             if self.train_exec_impl:
#
# /usr/local/lib/python3.6/dist-packages/ray/rllib/agents/trainer.py in __setstate__(self, state)
#    1061         if "worker" in state:
#    1062             self.workers.local_worker().restore(state["worker"])
# -> 1063             remote_state = ray.put(state["worker"])
#    1064             for r in self.workers.remote_workers():
#    1065                 r.restore.remote(remote_state)
#
# /usr/local/lib/python3.6/dist-packages/ray/worker.py in put(value, weakref)
#    1539     """
#    1540     worker = global_worker
# -> 1541     worker.check_connected()
#    1542     with profiling.profile("ray.put"):
#    1543         if worker.mode == LOCAL_MODE:
#
# /usr/local/lib/python3.6/dist-packages/ray/worker.py in check_connected(self)
#     209         """
#     210         if not self.connected:
# --> 211             raise RayConnectionError("Ray has not been started yet. You can "
#     212                                      "start Ray with 'ray.init()'.")
#     213
#
# RayConnectionError: Ray has not been started yet. You can start Ray with 'ray.init()'.

# %%
ray.init()

trainer2.restore(check_point)

print(len(final_rewards))
print(num_episodes)
plt.style.use('seaborn-darkgrid')
plt.plot(final_rewards, label="reward")
plt.plot(moving_average, label="avg last 10 episodes")
plt.legend(loc='lower right')
plt.xlabel('Episode Count')
plt.ylabel('Reward (Average Velocity)')
plt.title('2 Agent Circle Track PPO Training')
plt.show()


num_episodes = 0
cur_reward = 0
final_rewards2 = []


i = 0
while i < 75:
    t_dict = trainer2.train()
    print(t_dict)
    rewards = t_dict['hist_stats']['episode_reward']
    ep_lens = t_dict['hist_stats']['episode_lengths']
    ep_total = t_dict['episodes_this_iter']
    for j in range(ep_total):
      num_episodes += 1
    for j in range(ep_total):
      final_rewards2.append(rewards[j] / 1000)

    i += 1



moving_average2 = []
curr_total = 0
for i in range(len(final_rewards2)):
  if i < 9:
    moving_average2.append(0)
    curr_total += final_rewards2[i]
  else:
    curr_total += final_rewards2[i]
    moving_average2.append(curr_total/10)
    curr_total -= final_rewards2[i-9]
# Out:
# 2020-04-27 00:29:15,109	INFO resource_spec.py:212 -- Starting Ray with 7.08 GiB memory available for workers and up to 3.56 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-04-27 00:29:15,615	INFO services.py:1148 -- View the Ray dashboard at localhost:8265
# 2020-04-27 00:29:15,998	INFO trainable.py:217 -- Getting current IP.
# 2020-04-27 00:29:16,000	INFO trainable.py:423 -- Restored on 172.28.0.2 from checkpoint: /root/ray_results/DQN_multienv_2020-04-26_23-57-02837q2vl0/checkpoint_75/checkpoint-75
# 2020-04-27 00:29:16,002	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 75, '_timesteps_total': 75000, '_time_total': 742.2039382457733, '_episodes_total': 150}
# 150
# 150
# 2020-04-27 00:29:19,532	WARNING worker.py:1072 -- The dashboard on node 613341d236f8 failed with the following error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1062, in create_server
#     sock.bind(sa)
# OSError: [Errno 99] Cannot assign requested address
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ray/dashboard/dashboard.py", line 1142, in <module>
#     dashboard.run()
#   File "/usr/local/lib/python3.6/dist-packages/ray/dashboard/dashboard.py", line 570, in run
#     aiohttp.web.run_app(self.app, host=self.host, port=self.port)
#   File "/usr/local/lib/python3.6/dist-packages/aiohttp/web.py", line 433, in run_app
#     reuse_port=reuse_port))
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 484, in run_until_complete
#     return future.result()
#   File "/usr/local/lib/python3.6/dist-packages/aiohttp/web.py", line 359, in _run_app
#     await site.start()
#   File "/usr/local/lib/python3.6/dist-packages/aiohttp/web_runner.py", line 104, in start
#     reuse_port=self._reuse_port)
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1066, in create_server
#     % (sa, err.strerror.lower()))
# OSError: [Errno 99] error while attempting to bind on address ('::1', 8265, 0, 0): cannot assign requested address
# 3.3481464767669173
# Done
# 4.090390625137481
# Done
# {'episode_reward_max': 3764.052916285179, 'episode_reward_min': 3478.9228106906694, 'episode_reward_mean': 3621.487863487924, 'episode_len_mean': 1000.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3764.052916285179, 3478.9228106906694], 'episode_lengths': [1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 5.946045217366293, 'mean_processing_ms': 0.2434619482251062, 'mean_inference_ms': 2.023404863463349}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 1.0}], 'num_target_updates': 152, 'num_steps_trained': 608000, 'num_steps_sampled': 77000, 'sample_time_ms': 29.06, 'replay_time_ms': 1.648, 'grad_time_ms': 28.431, 'update_time_ms': 0.004, 'opt_peak_throughput': 1125.515, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 481.20312, 'min_q': 458.01862, 'max_q': 502.96204, 'mean_td_error': 31.216, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 77000, 'episodes_total': 152, 'training_iteration': 76, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-29-41', 'timestamp': 1587947381, 'time_this_iter_s': 23.70830726623535, 'time_total_s': 765.9122455120087, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shuffle_buffer_size': 0, 'output': None, 'output_compress_columns': ['obs' ...
# 9.360000000007277
# Done
# 7.266960754394532
# Done
# {'episode_reward_max': 3897.2712310443726, 'episode_reward_min': 3478.9228106906694, 'episode_reward_mean': 3695.8475589576874, 'episode_len_mean': 1000.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3643.1432778105286, 3897.2712310443726, 3764.052916285179, 3478.9228106906694], 'episode_lengths': [1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 5.758613459105154, 'mean_processing_ms': 0.23815852487294953, 'mean_inference_ms': 1.9498811792143746}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 156, 'num_steps_trained': 624000, 'num_steps_sampled': 79000, 'sample_time_ms': 30.636, 'replay_time_ms': 1.697, 'grad_time_ms': 8.444, 'update_time_ms': 0.005, 'opt_peak_throughput': 3789.77, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 476.83426, 'min_q': 453.17627, 'max_q': 497.71594, 'mean_td_error': 13.232587, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 79000, 'episodes_total': 154, 'training_iteration': 77, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-30-00', 'timestamp': 1587947400, 'time_this_iter_s': 19.702136993408203, 'time_total_s': 785.6143825054169, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shuffle_buffer ...
# 4.172031250001187
# Done
# 4.105175781426864
# Done
# {'episode_reward_max': 3897.2712310443726, 'episode_reward_min': 3476.6732735392884, 'episode_reward_mean': 3624.6863981990177, 'episode_len_mean': 1000.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3476.6732735392884, 3488.05487982407, 3764.052916285179, 3478.9228106906694, 3643.1432778105286, 3897.2712310443726], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 5.654020551835497, 'mean_processing_ms': 0.2352723869862832, 'mean_inference_ms': 1.919348769005724}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 160, 'num_steps_trained': 640000, 'num_steps_sampled': 81000, 'sample_time_ms': 28.731, 'replay_time_ms': 1.688, 'grad_time_ms': 8.65, 'update_time_ms': 0.004, 'opt_peak_throughput': 3699.456, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 467.74033, 'min_q': 443.56216, 'max_q': 484.29654, 'mean_td_error': -1.1348047, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 81000, 'episodes_total': 156, 'training_iteration': 78, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-30-20', 'timestamp': 1587947420, 'time_this_iter_s': 19.91144347190857, 'time_total_s': 805.5258259773254, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis ...
# 6.264615181140254
# Done
# 3.9467968791929593
# Done
# {'episode_reward_max': 3897.2712310443726, 'episode_reward_min': 3376.5704143779985, 'episode_reward_mean': 3575.411997001981, 'episode_len_mean': 1000.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3376.5704143779985, 3478.607172443744, 3764.052916285179, 3478.9228106906694, 3643.1432778105286, 3897.2712310443726, 3476.6732735392884, 3488.05487982407], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 5.585035436575583, 'mean_processing_ms': 0.23333275816950622, 'mean_inference_ms': 1.8966089966856807}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 164, 'num_steps_trained': 656000, 'num_steps_sampled': 83000, 'sample_time_ms': 28.651, 'replay_time_ms': 1.836, 'grad_time_ms': 8.185, 'update_time_ms': 0.004, 'opt_peak_throughput': 3909.805, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 469.94128, 'min_q': 432.34897, 'max_q': 510.828, 'mean_td_error': 1.7680569, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 83000, 'episodes_total': 158, 'training_iteration': 79, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-30-40', 'timestamp': 1587947440, 'time_this_iter_s': 19.948708534240723, 'time_total_s': 825.4745345115662, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0,  ...
# 3.7257812500329033
# Done
# 3.965312500528987
# Done
# {'episode_reward_max': 3897.2712310443726, 'episode_reward_min': 3376.5704143779985, 'episode_reward_mean': 3555.202100286464, 'episode_len_mean': 1000.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3477.4401546125355, 3471.284872236255, 3764.052916285179, 3478.9228106906694, 3643.1432778105286, 3897.2712310443726, 3476.6732735392884, 3488.05487982407, 3376.5704143779985, 3478.607172443744], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 5.535373301624361, 'mean_processing_ms': 0.23198303925510402, 'mean_inference_ms': 1.8785919329638503}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 168, 'num_steps_trained': 672000, 'num_steps_sampled': 85000, 'sample_time_ms': 30.512, 'replay_time_ms': 1.745, 'grad_time_ms': 7.945, 'update_time_ms': 0.004, 'opt_peak_throughput': 4027.587, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 456.84363, 'min_q': 427.6857, 'max_q': 488.10724, 'mean_td_error': 15.631988, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 85000, 'episodes_total': 160, 'training_iteration': 80, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-31-00', 'timestamp': 1587947460, 'time_this_iter_s': 19.87371277809143, 'time_total_s': 845.3482472896576, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_pe ...
# 2.2583816590380357
# Done
# 2.5850195322499236
# Done
# {'episode_reward_max': 4166.6725887547855, 'episode_reward_min': 3376.5704143779985, 'episode_reward_mean': 3595.0282373398463, 'episode_len_mean': 1000.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3421.645256458728, 4166.6725887547855, 3764.052916285179, 3478.9228106906694, 3643.1432778105286, 3897.2712310443726, 3476.6732735392884, 3488.05487982407, 3376.5704143779985, 3478.607172443744, 3477.4401546125355, 3471.284872236255], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 5.498011489815764, 'mean_processing_ms': 0.23097950424150113, 'mean_inference_ms': 1.8655505721397294}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 172, 'num_steps_trained': 688000, 'num_steps_sampled': 87000, 'sample_time_ms': 29.915, 'replay_time_ms': 2.009, 'grad_time_ms': 8.084, 'update_time_ms': 0.004, 'opt_peak_throughput': 3958.419, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 448.0597, 'min_q': 415.69897, 'max_q': 488.61102, 'mean_td_error': 15.744692, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 87000, 'episodes_total': 162, 'training_iteration': 81, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-31-20', 'timestamp': 1587947480, 'time_this_iter_s': 19.86886763572693, 'time_total_s': 865.2171149253845, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver':  ...
# 2.2751667070398165
# Done
# 3.190006812679349
# Done
# {'episode_reward_max': 4166.6725887547855, 'episode_reward_min': 3376.5704143779985, 'episode_reward_mean': 3610.6221117045125, 'episode_len_mean': 1000.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3743.1827540824065, 3665.1879617026034, 3764.052916285179, 3478.9228106906694, 3643.1432778105286, 3897.2712310443726, 3476.6732735392884, 3488.05487982407, 3376.5704143779985, 3478.607172443744, 3477.4401546125355, 3471.284872236255, 3421.645256458728, 4166.6725887547855], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 5.468582551682105, 'mean_processing_ms': 0.23017126358449408, 'mean_inference_ms': 1.8548646535573172}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 176, 'num_steps_trained': 704000, 'num_steps_sampled': 89000, 'sample_time_ms': 29.404, 'replay_time_ms': 1.946, 'grad_time_ms': 8.238, 'update_time_ms': 0.004, 'opt_peak_throughput': 3884.593, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 458.525, 'min_q': 416.778, 'max_q': 530.9749, 'mean_td_error': 13.84053, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 89000, 'episodes_total': 164, 'training_iteration': 82, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-31-40', 'timestamp': 1587947500, 'time_this_iter_s': 19.902193546295166, 'time_total_s': 885.1193084716797, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_re ...
# 1.2200000158543405
# Done
# 3.229224747568562
# Done
# {'episode_reward_max': 4166.6725887547855, 'episode_reward_min': 3376.5704143779985, 'episode_reward_mean': 3646.467191257411, 'episode_len_mean': 1000.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [4009.754720732701, 3785.010775522705, 3764.052916285179, 3478.9228106906694, 3643.1432778105286, 3897.2712310443726, 3476.6732735392884, 3488.05487982407, 3376.5704143779985, 3478.607172443744, 3477.4401546125355, 3471.284872236255, 3421.645256458728, 4166.6725887547855, 3743.1827540824065, 3665.1879617026034], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 5.44455362207194, 'mean_processing_ms': 0.22953804398192518, 'mean_inference_ms': 1.8477632623814184}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 180, 'num_steps_trained': 720000, 'num_steps_sampled': 91000, 'sample_time_ms': 30.445, 'replay_time_ms': 1.676, 'grad_time_ms': 8.52, 'update_time_ms': 0.004, 'opt_peak_throughput': 3755.96, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 460.43903, 'min_q': 429.34888, 'max_q': 512.7829, 'mean_td_error': -1.727251, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 91000, 'episodes_total': 166, 'training_iteration': 83, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-32-00', 'timestamp': 1587947520, 'time_this_iter_s': 19.972267389297485, 'time_total_s': 905.0915758609772, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_p ...
# 2.203516597747817
# Done
# 3.1200036263842224
# Done
# {'episode_reward_max': 4166.6725887547855, 'episode_reward_min': 3222.3423948615, 'episode_reward_mean': 3612.6494958424705, 'episode_len_mean': 1000.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3222.3423948615, 3461.873470184399, 3764.052916285179, 3478.9228106906694, 3643.1432778105286, 3897.2712310443726, 3476.6732735392884, 3488.05487982407, 3376.5704143779985, 3478.607172443744, 3477.4401546125355, 3471.284872236255, 3421.645256458728, 4166.6725887547855, 3743.1827540824065, 3665.1879617026034, 4009.754720732701, 3785.010775522705], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 5.42465472975483, 'mean_processing_ms': 0.22899937625192013, 'mean_inference_ms': 1.8427998778184391}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 184, 'num_steps_trained': 736000, 'num_steps_sampled': 93000, 'sample_time_ms': 29.609, 'replay_time_ms': 1.694, 'grad_time_ms': 7.943, 'update_time_ms': 0.004, 'opt_peak_throughput': 4028.784, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 451.80035, 'min_q': 420.00757, 'max_q': 521.1957, 'mean_td_error': 11.1899395, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 93000, 'episodes_total': 168, 'training_iteration': 84, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-32-20', 'timestamp': 1587947540, 'time_this_iter_s': 20.012521505355835, 'time_total_s': 925.104097366333, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps ...
# 3.836406250511908
# Done
# 6.100073242260843
# Done
# {'episode_reward_max': 4166.6725887547855, 'episode_reward_min': 3222.3423948615, 'episode_reward_mean': 3622.0931774682804, 'episode_len_mean': 1000.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3477.210765767733, 3936.961858433404, 3764.052916285179, 3478.9228106906694, 3643.1432778105286, 3897.2712310443726, 3476.6732735392884, 3488.05487982407, 3376.5704143779985, 3478.607172443744, 3477.4401546125355, 3471.284872236255, 3421.645256458728, 4166.6725887547855, 3743.1827540824065, 3665.1879617026034, 4009.754720732701, 3785.010775522705, 3222.3423948615, 3461.873470184399], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 5.4077258099230034, 'mean_processing_ms': 0.22852211414669968, 'mean_inference_ms': 1.8381020516755835}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 188, 'num_steps_trained': 752000, 'num_steps_sampled': 95000, 'sample_time_ms': 29.213, 'replay_time_ms': 1.917, 'grad_time_ms': 8.36, 'update_time_ms': 0.004, 'opt_peak_throughput': 3827.978, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 441.7091, 'min_q': 421.33173, 'max_q': 481.81586, 'mean_td_error': 14.38187, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 95000, 'episodes_total': 170, 'training_iteration': 85, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-32-40', 'timestamp': 1587947560, 'time_this_iter_s': 19.93337893486023, 'time_total_s': 945.0374763011932, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_ba ...
# 2.5249315358467497
# Done
# 3.3062500000023283
# Done
# {'episode_reward_max': 4166.6725887547855, 'episode_reward_min': 3222.3423948615, 'episode_reward_mean': 3606.257302853685, 'episode_len_mean': 1000.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3434.5170183587175, 3461.280095056749, 3764.052916285179, 3478.9228106906694, 3643.1432778105286, 3897.2712310443726, 3476.6732735392884, 3488.05487982407, 3376.5704143779985, 3478.607172443744, 3477.4401546125355, 3471.284872236255, 3421.645256458728, 4166.6725887547855, 3743.1827540824065, 3665.1879617026034, 4009.754720732701, 3785.010775522705, 3222.3423948615, 3461.873470184399, 3477.210765767733, 3936.961858433404], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 5.392985981764332, 'mean_processing_ms': 0.22806526257634321, 'mean_inference_ms': 1.8334242524861168}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 192, 'num_steps_trained': 768000, 'num_steps_sampled': 97000, 'sample_time_ms': 29.591, 'replay_time_ms': 1.732, 'grad_time_ms': 9.103, 'update_time_ms': 0.004, 'opt_peak_throughput': 3515.265, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 461.97336, 'min_q': 405.82532, 'max_q': 552.8707, 'mean_td_error': 0.029241562, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 97000, 'episodes_total': 172, 'training_iteration': 86, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-33-00', 'timestamp': 1587947580, 'time_this_iter_s': 19.84223437309265, 'time_total_s': 964.8797106742859, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episod ...
# 3.2000030816128855
# Done
# 4.1191174319260675
# Done
# ...
# 3.260980407057796
# Done
# 3.0009842515583225
# Done
# {'episode_reward_max': 4444.492678202481, 'episode_reward_min': 3423.943295224581, 'episode_reward_mean': 3842.5729029489844, 'episode_len_mean': 1000.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [4184.885771558392, 4316.037149615279, 4161.309573147254, 3908.464672240786, 3465.0201140175955, 3423.943295224581, 3738.503503828324, 3481.4801571926987, 3687.5503459874, 3920.978751260288, 3426.548697298608, 3476.8319867200466, 3476.522012882289, 4112.772595026091, 3474.650757392024, 3426.86275862221, 3475.688864374894, 3461.5107090891424, 3472.9372811351377, 4026.0429956529524, 4035.0365835644234, 3436.769037032719, 3480.9787871823883, 3475.0663317745752, 4114.315717267572, 4025.337633776234, 3429.2545412518357, 3476.9935134918524, 3466.6018924697173, 3471.2956704517746, 3458.269350625622, 4155.00484574174, 3476.07320287429, 3475.651261312608, 3588.9057357272727, 3620.475352134872, 3479.142784149563, 3477.0164499203624, 3470.0901876992148, 3472.2973413554987, 4312.634363243951, 4252.629961495765, 3470.3883241448857, 3501.973212452726, 3476.41636859303, 3456.012237793315, 3473.2112500575427, 3475.4637167974074, 4294.354883202888, 3480.16703619311, 3867.248976440605, 3438.1897924044047, 4327.507776862472, 4019.9757446296676, 4239.527911511119, 3668.090349812444, 4296.728767114285, 3473.130889781773, 3503.7450256645493, 4278.6709733015605, 4433.699035460603, 4155.422560756762, 4289.426728233162, 4444.492678202481, 4196.786588122059, 4206.440827441097, 4161.567587930762, 4161.3931142904985, 4128.519451340561, 4141.637058647118, 4142.865817117089, 3802.2143119030343, 4216.770408788774, 4119.323280625856, 3938.8594784734278, 4358.104066149771, 4257.165233645552, 4251.240732525158, 4128.955639055797, 3729.4975211490737, 4203.7480216548665, 4215.659779494126, 4004.015891644502, 3566.1954492083337, 3891.3252552366475, 4167.971480839727, 4084.60171477043, 4262.493554544204, 4165.069674932845, 4308.741033633777, 4196.585834659786, 3798.948230956821, 3431.339817503953, 4321.601169538811, 4195.05325084096, 3427.6303615617508, 3681.07176781812, 3463.7290011713494, 3473.561750637229, 3624.3793608238857], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 5.219608485109401, 'mean_processing_ms': 0.21869732768927932, 'mean_inference_ms': 1.7646018375441108}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 438, 'num_steps_trained': 1760000, 'num_steps_sampled': 221000, 'sample_time_ms': 30.338, 'replay_time_ms': 2.009, 'grad_time_ms': 8.894, 'update_time_ms': 0.004, 'opt_peak_throughput': 3598.041, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 372.2663, 'min_q': 300.43893, 'max_q': 517.097, 'mean_td_error': 8.538738, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 221000, 'episodes_total': 296, 'training_iteration': 148, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-53-36', 'timestamp': 1587948816, 'time_this_iter_s': 20.162155151367188, 'time_total_s': 2200.7108056545258, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes' ...
# 3.321953292722906
# Done
# 2.76531427919036
# Done
# {'episode_reward_max': 4444.492678202481, 'episode_reward_min': 3423.943295224581, 'episode_reward_mean': 3846.7360074593307, 'episode_len_mean': 1000.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [4308.288959826987, 4177.795736595658, 3465.0201140175955, 3423.943295224581, 3738.503503828324, 3481.4801571926987, 3687.5503459874, 3920.978751260288, 3426.548697298608, 3476.8319867200466, 3476.522012882289, 4112.772595026091, 3474.650757392024, 3426.86275862221, 3475.688864374894, 3461.5107090891424, 3472.9372811351377, 4026.0429956529524, 4035.0365835644234, 3436.769037032719, 3480.9787871823883, 3475.0663317745752, 4114.315717267572, 4025.337633776234, 3429.2545412518357, 3476.9935134918524, 3466.6018924697173, 3471.2956704517746, 3458.269350625622, 4155.00484574174, 3476.07320287429, 3475.651261312608, 3588.9057357272727, 3620.475352134872, 3479.142784149563, 3477.0164499203624, 3470.0901876992148, 3472.2973413554987, 4312.634363243951, 4252.629961495765, 3470.3883241448857, 3501.973212452726, 3476.41636859303, 3456.012237793315, 3473.2112500575427, 3475.4637167974074, 4294.354883202888, 3480.16703619311, 3867.248976440605, 3438.1897924044047, 4327.507776862472, 4019.9757446296676, 4239.527911511119, 3668.090349812444, 4296.728767114285, 3473.130889781773, 3503.7450256645493, 4278.6709733015605, 4433.699035460603, 4155.422560756762, 4289.426728233162, 4444.492678202481, 4196.786588122059, 4206.440827441097, 4161.567587930762, 4161.3931142904985, 4128.519451340561, 4141.637058647118, 4142.865817117089, 3802.2143119030343, 4216.770408788774, 4119.323280625856, 3938.8594784734278, 4358.104066149771, 4257.165233645552, 4251.240732525158, 4128.955639055797, 3729.4975211490737, 4203.7480216548665, 4215.659779494126, 4004.015891644502, 3566.1954492083337, 3891.3252552366475, 4167.971480839727, 4084.60171477043, 4262.493554544204, 4165.069674932845, 4308.741033633777, 4196.585834659786, 3798.948230956821, 3431.339817503953, 4321.601169538811, 4195.05325084096, 3427.6303615617508, 3681.07176781812, 3463.7290011713494, 3473.561750637229, 3624.3793608238857, 4184.885771558392, 4316.037149615279], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 5.2184734968266095, 'mean_processing_ms': 0.21864592575404018, 'mean_inference_ms': 1.764191093590602}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 442, 'num_steps_trained': 1776000, 'num_steps_sampled': 223000, 'sample_time_ms': 30.128, 'replay_time_ms': 1.938, 'grad_time_ms': 8.095, 'update_time_ms': 0.004, 'opt_peak_throughput': 3953.196, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 357.12927, 'min_q': 288.34683, 'max_q': 457.51468, 'mean_td_error': -9.828798, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 223000, 'episodes_total': 298, 'training_iteration': 149, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-53-56', 'timestamp': 1587948836, 'time_this_iter_s': 20.050405025482178, 'time_total_s': 2220.761210680008, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episod ...
# 3.081253246222615
# Done
# 5.690000000002057
# Done
# {'episode_reward_max': 4444.492678202481, 'episode_reward_min': 3426.548697298608, 'episode_reward_mean': 3851.558170397143, 'episode_len_mean': 1000.0, 'episodes_this_iter': 2, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3464.117167423542, 3907.062535599956, 3738.503503828324, 3481.4801571926987, 3687.5503459874, 3920.978751260288, 3426.548697298608, 3476.8319867200466, 3476.522012882289, 4112.772595026091, 3474.650757392024, 3426.86275862221, 3475.688864374894, 3461.5107090891424, 3472.9372811351377, 4026.0429956529524, 4035.0365835644234, 3436.769037032719, 3480.9787871823883, 3475.0663317745752, 4114.315717267572, 4025.337633776234, 3429.2545412518357, 3476.9935134918524, 3466.6018924697173, 3471.2956704517746, 3458.269350625622, 4155.00484574174, 3476.07320287429, 3475.651261312608, 3588.9057357272727, 3620.475352134872, 3479.142784149563, 3477.0164499203624, 3470.0901876992148, 3472.2973413554987, 4312.634363243951, 4252.629961495765, 3470.3883241448857, 3501.973212452726, 3476.41636859303, 3456.012237793315, 3473.2112500575427, 3475.4637167974074, 4294.354883202888, 3480.16703619311, 3867.248976440605, 3438.1897924044047, 4327.507776862472, 4019.9757446296676, 4239.527911511119, 3668.090349812444, 4296.728767114285, 3473.130889781773, 3503.7450256645493, 4278.6709733015605, 4433.699035460603, 4155.422560756762, 4289.426728233162, 4444.492678202481, 4196.786588122059, 4206.440827441097, 4161.567587930762, 4161.3931142904985, 4128.519451340561, 4141.637058647118, 4142.865817117089, 3802.2143119030343, 4216.770408788774, 4119.323280625856, 3938.8594784734278, 4358.104066149771, 4257.165233645552, 4251.240732525158, 4128.955639055797, 3729.4975211490737, 4203.7480216548665, 4215.659779494126, 4004.015891644502, 3566.1954492083337, 3891.3252552366475, 4167.971480839727, 4084.60171477043, 4262.493554544204, 4165.069674932845, 4308.741033633777, 4196.585834659786, 3798.948230956821, 3431.339817503953, 4321.601169538811, 4195.05325084096, 3427.6303615617508, 3681.07176781812, 3463.7290011713494, 3473.561750637229, 3624.3793608238857, 4184.885771558392, 4316.037149615279, 4308.288959826987, 4177.795736595658], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 5.217435251509512, 'mean_processing_ms': 0.21860436072171477, 'mean_inference_ms': 1.7637978185273167}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 446, 'num_steps_trained': 1792000, 'num_steps_sampled': 225000, 'sample_time_ms': 33.12, 'replay_time_ms': 2.461, 'grad_time_ms': 8.55, 'update_time_ms': 0.004, 'opt_peak_throughput': 3742.586, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 376.41376, 'min_q': 293.79398, 'max_q': 480.57236, 'mean_td_error': 0.3230753, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 225000, 'episodes_total': 300, 'training_iteration': 150, 'experiment_id': 'a46c8aa6512a458e812838a8a4ae0acf', 'date': '2020-04-27_00-54-16', 'timestamp': 1587948856, 'time_this_iter_s': 20.232999086380005, 'time_total_s': 2240.994209766388, 'pid': 124, 'hostname': '613341d236f8', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', ...

# %%
print(len(final_rewards))
print(num_episodes)
plt.style.use('seaborn-darkgrid')
plt.plot(final_rewards, label="reward")
plt.plot(moving_average, label="avg last 10 episodes")
plt.legend(loc='lower right')
plt.xlabel('Episode Count')
plt.ylabel('Reward (Average Velocity)')
plt.title('2 Agent Circle Track PPO Training')
plt.show()
# Out:
# 150
# 150

# %%
print(len(final_rewards2))
print(num_episodes)
plt.style.use('seaborn-darkgrid')
plt.plot(final_rewards2, label="reward")
plt.plot(moving_average2, label="avg last 10 episodes")
plt.plot(np.zeros(150) + 3.5, label="baseline")
plt.legend(loc='lower right')
plt.xlabel('Episode Count')
plt.ylabel('Reward (Average Velocity)')
plt.title('Single Agent on Figure 8 Track using Circle Track DQN Model')
plt.show()
# Out:
# 150
# 150
