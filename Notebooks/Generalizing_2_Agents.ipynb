# %%
# !pip install pygame==2.0.0.dev4
# !python --version
# !pip install -U ray 
# !pip install ray[rllib]
# !pip install ray[tune]
import os
os.environ['SDL_VIDEODRIVER']='dummy'
# Out:
# Requirement already satisfied: pygame==2.0.0.dev4 in /usr/local/lib/python3.6/dist-packages (2.0.0.dev4)
# Python 3.6.9
# Requirement already up-to-date: ray in /usr/local/lib/python3.6/dist-packages (0.8.4)
# Requirement already satisfied, skipping upgrade: redis>=3.3.2 in /usr/local/lib/python3.6/dist-packages (from ray) (3.4.1)
# Requirement already satisfied, skipping upgrade: google in /usr/local/lib/python3.6/dist-packages (from ray) (2.0.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.16 in /usr/local/lib/python3.6/dist-packages (from ray) (1.18.3)
# Requirement already satisfied, skipping upgrade: jsonschema in /usr/local/lib/python3.6/dist-packages (from ray) (2.6.0)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from ray) (3.13)
# Requirement already satisfied, skipping upgrade: colorama in /usr/local/lib/python3.6/dist-packages (from ray) (0.4.3)
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.6/dist-packages (from ray) (3.0.12)
# Requirement already satisfied, skipping upgrade: click in /usr/local/lib/python3.6/dist-packages (from ray) (7.1.1)
# Requirement already satisfied, skipping upgrade: py-spy>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from ray) (0.3.3)
# Requirement already satisfied, skipping upgrade: grpcio in /usr/local/lib/python3.6/dist-packages (from ray) (1.28.1)
# Requirement already satisfied, skipping upgrade: aiohttp in /usr/local/lib/python3.6/dist-packages (from ray) (3.6.2)
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from ray) (3.10.0)
# Requirement already satisfied, skipping upgrade: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from google->ray) (4.6.3)
# Requirement already satisfied, skipping upgrade: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from grpcio->ray) (1.12.0)
# Requirement already satisfied, skipping upgrade: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (3.0.1)
# Requirement already satisfied, skipping upgrade: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (19.3.0)
# Requirement already satisfied, skipping upgrade: multidict<5.0,>=4.5 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (4.7.5)
# Requirement already satisfied, skipping upgrade: yarl<2.0,>=1.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (1.4.2)
# Requirement already satisfied, skipping upgrade: chardet<4.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna-ssl>=1.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (1.1.0)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.5; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (3.6.6)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->ray) (46.1.3)
# Requirement already satisfied, skipping upgrade: idna>=2.0 in /usr/local/lib/python3.6/dist-packages (from yarl<2.0,>=1.0->aiohttp->ray) (2.8)
# Requirement already satisfied: ray[rllib] in /usr/local/lib/python3.6/dist-packages (0.8.4)
# Requirement already satisfied: redis>=3.3.2 in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.4.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (0.4.3)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.10.0)
# Requirement already satisfied: google in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (2.0.3)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (0.3.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.0.12)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (7.1.1)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (1.28.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.6.2)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (1.18.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (2.6.0)
# Requirement already satisfied: atari-py; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (0.2.6)
# Requirement already satisfied: opencv-python-headless; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (4.2.0.34)
# Requirement already satisfied: pandas; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (1.0.3)
# Requirement already satisfied: tabulate; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (0.8.7)
# Requirement already satisfied: scipy; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (1.4.1)
# Requirement already satisfied: tensorboardX; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (2.0)
# Requirement already satisfied: dm-tree; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (0.1.4)
# Requirement already satisfied: gym[atari]; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (0.17.1)
# Requirement already satisfied: lz4; extra == "rllib" in /usr/local/lib/python3.6/dist-packages (from ray[rllib]) (3.0.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->ray[rllib]) (1.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->ray[rllib]) (46.1.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from google->ray[rllib]) (4.6.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[rllib]) (1.4.2)
# Requirement already satisfied: idna-ssl>=1.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[rllib]) (1.1.0)
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[rllib]) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.6.5; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[rllib]) (3.6.6)
# Requirement already satisfied: multidict<5.0,>=4.5 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[rllib]) (4.7.5)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[rllib]) (19.3.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[rllib]) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas; extra == "rllib"->ray[rllib]) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas; extra == "rllib"->ray[rllib]) (2018.9)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (1.5.0)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (1.3.0)
# Requirement already satisfied: Pillow; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (7.0.0)
# Requirement already satisfied: opencv-python; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (4.1.2.30)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.6/dist-packages (from yarl<2.0,>=1.0->aiohttp->ray[rllib]) (2.8)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[atari]; extra == "rllib"->ray[rllib]) (0.16.0)
# Requirement already satisfied: ray[tune] in /usr/local/lib/python3.6/dist-packages (0.8.4)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (0.3.3)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (3.10.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (7.1.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (3.13)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (3.6.2)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (1.18.3)
# Requirement already satisfied: google in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (2.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (3.0.12)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (1.28.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (2.6.0)
# Requirement already satisfied: redis>=3.3.2 in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (3.4.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (0.4.3)
# Requirement already satisfied: tensorboardX; extra == "tune" in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (2.0)
# Requirement already satisfied: pandas; extra == "tune" in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (1.0.3)
# Requirement already satisfied: tabulate; extra == "tune" in /usr/local/lib/python3.6/dist-packages (from ray[tune]) (0.8.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->ray[tune]) (46.1.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->ray[tune]) (1.12.0)
# Requirement already satisfied: multidict<5.0,>=4.5 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[tune]) (4.7.5)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[tune]) (19.3.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[tune]) (1.4.2)
# Requirement already satisfied: typing-extensions>=3.6.5; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[tune]) (3.6.6)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[tune]) (3.0.1)
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[tune]) (3.0.4)
# Requirement already satisfied: idna-ssl>=1.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray[tune]) (1.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from google->ray[tune]) (4.6.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas; extra == "tune"->ray[tune]) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas; extra == "tune"->ray[tune]) (2018.9)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.6/dist-packages (from yarl<2.0,>=1.0->aiohttp->ray[tune]) (2.8)

# %%
import gym, ray
from ray.tune.registry import register_env
from ray.rllib.env.multi_agent_env import MultiAgentEnv
import gym
import numpy as np
from gym import spaces
from gym.envs.registration import EnvSpec
import pygame, math, sys, time
from pygame.locals import *
import pygame.camera
import matplotlib.pyplot as plt
# environment for all agents in the multiagent world
# currently code assumes that no agents will be created/destroyed at runtime!
class MultiCarEnv3(gym.Env, MultiAgentEnv):
    metadata = {
        'render.modes' : ['human', 'console']
    }

    UP = 0
    DOWN = 1




    def __init__(self):
        super(MultiCarEnv3, self).__init__()

        pygame.init()
        self.screen = pygame.display.set_mode((1024, 800))
        self.screen.fill([128, 128, 128])
        pygame.display.update()


        def drawCirclePad(xc, yc, x, y, pads):
            pads.append(PadSprite((xc + x, yc + y),'pad_sq.png'))
            pads.append(PadSprite((xc - x, yc + y),'pad_sq.png'))
            pads.append(PadSprite((xc + x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc - x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc + y, yc + x),'pad_sq.png'))
            pads.append(PadSprite((xc - y, yc + x),'pad_sq.png'))
            pads.append(PadSprite((xc + y, yc - x),'pad_sq.png'))
            pads.append(PadSprite((xc - y, yc - x),'pad_sq.png'))


        def circleBres(xc, yc, r, pad):

            x = 0
            y = r; 
            d = 3 - 2 * r 
            drawCirclePad(xc, yc, x, y, pad)
            while y >= x:
                  
                x += 1

                if d > 0:
                    y -= 1
                    d = d + 4 * (x - y) + 10; 
                
                else:
                    d = d + 4 * x + 6; 
                drawCirclePad(xc, yc, x, y, pad)

        pads1 = []
        pads2 = []  

        circleBres(400, 400, 375, pads1)
        circleBres(400, 400, 300, pads2)

        self.pad_group1 = pygame.sprite.RenderPlain(*pads1)
        self.pad_group2 = pygame.sprite.RenderPlain(*pads2)

        car = CarSprite('car.png', (60, 400))
        car2 = CarSprite('car.png', (110, 230))
        car3 = CarSprite('car.png', (215, 115))
        car4 = CarSprite('car.png', (380, 55))
        car5 = CarSprite('car.png', (565, 115))
        car6 = CarSprite('car.png', (690, 240))
        car7 = CarSprite('car.png', (740, 390))
        car8 = CarSprite('car.png', (690, 540))
        car9 = CarSprite('car.png', (565, 665))
        car10 = CarSprite('car.png', (390, 740))
        car11 = CarSprite('car.png', (215, 665))
        car12 = CarSprite('car.png', (115, 540))

        self.cars = [car, car2, car3, car4, car5, car6, car7, car8, car9, car10, car11, car12]

        self.car_group = pygame.sprite.RenderPlain(*self.cars)
        def addSensor(car, sensors):
            sensors.append(SensorSprite(0, -250, car))
            sensors.append(SensorSprite(200, -230, car))
            sensors.append(SensorSprite(-200, -230, car))
            sensors.append(SensorSprite(150, 0, car))
            sensors.append(SensorSprite(-150, 0, car))
            sensors.append(SensorSprite(0, 150, car))
            sensors.append(SensorSprite(100, 130, car))
            sensors.append(SensorSprite(-100, 130, car))

        self.sensors = []

        for c in self.cars:
            curr = []
            addSensor(c, curr)
            self.sensors.append(curr)

        self.sensor_group = []
        for sensor in self.sensors:
          self.sensor_group.append(pygame.sprite.RenderPlain(*sensor))

        self.checkpoints = [CheckPointSprite(25, 350, 150, 150, 1), 
               CheckPointSprite(75, 200, 150, 150, 2),
               CheckPointSprite(175, 75, 150, 150, 3),
               CheckPointSprite(350, 25, 150, 150, 4),
               CheckPointSprite(525, 75, 150, 150, 5), 
               CheckPointSprite(650, 200, 150, 150, 6),
               CheckPointSprite(700, 350, 150, 150, 7),
               CheckPointSprite(350, 25, 150, 150, 8),

               CheckPointSprite(75, 500, 150, 150, 13),
               CheckPointSprite(175, 625, 150, 150, 12),
               CheckPointSprite(350, 700, 150, 150, 11),

               CheckPointSprite(525, 625, 150, 150, 9), 
               CheckPointSprite(650, 500, 150, 150, 10),

               ]
        self.check_group = pygame.sprite.RenderPlain(*self.checkpoints)
    
        self.time = 0

        #accelerate, decelerate, nothing
        self.action_space = spaces.Discrete(3)
        #distance to another object, average velocity of other cars, own velocity
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf,
                                        shape=(10,), dtype=np.float32)

        self.wait = 3
        self.step_count = 0

        

    def step(self, action_n):
        self.step_count += 1

        obs_d = {}
        reward_d = {}
        done_d =  {
            "car_0": False,
            "car_1": False,
   
            "__all__": False,  # the env is not done
        }

        info_d = {
            "car_0":{},
            "car_1":{},  
 
        }




        obs_n = []
        reward_n = []

        '''if self.step_count == 1:
          speed = named_actors.get_actor("global_counter")
          speed.reset.remote()'''


        clock = pygame.time.Clock()
        #deltat = clock.tick(30)
        deltat = 30
        self.time += deltat
        # set and perform action for each agent
        i = 0
        idx = [0, 6]
        for key, val in action_n.items():
            cur_action = val
            if cur_action == self.DOWN:
                self.cars[idx[i]].k_down = -1
            else:
                self.cars[idx[i]].k_down = 0
            if cur_action == self.UP:
                self.cars[idx[i]].k_up = 0.5
            else: 
                self.cars[idx[i]].k_up = 0
            i += 1

        i = 0
        for car in self.cars:
            

            if self.step_count >= 20 and self.step_count < 60 and i == 5:
                car.k_up = 0
                car.k_down = 0
                car.speed -= 0.25

            other_cars = self.cars[:]
            other_cars.remove(car)
            other_cars_g = pygame.sprite.Group(other_cars)


            # find the cars in range
            car_near = pygame.sprite.groupcollide(self.sensor_group[i].sprites()[0:3], other_cars_g, False, False, collided = None)
        

            rect_list = []
            car_list = []

            # find the nearest car
            for key, value in car_near.items():
                for val in value:
                    car_list.append(val)
                    newrect = val.rect.clip(key.rect)
                    rect_list.append(newrect)
            # find nearest distance to other car
            mindist = 1000
            minCar = None
            k = 0
            for rec in rect_list:
                dist = math.sqrt((rec.centerx - car.rect.centerx) ** 2 + (rec.centery - car.rect.centery) ** 2)
                if dist < mindist:
                    mindist = dist
                    minCar = car_list[k]
                k += 1

            accel = 0
            
            if i != 0 and i != 6:
                
                if mindist < 75:
                    accel = -(car.speed/2)
                else:
                    if minCar == None  or car.speed < minCar.speed:
                        
                        accel = 0.1
                car.speed += accel
            else: 
                if mindist < 75:         
                  accel = -(car.speed/2)
                  car.k_down = 0
                  car.k_up = 0
                car.speed += accel
              


            collisions_pad1 = pygame.sprite.spritecollide(car, self.pad_group1, False, collided = None)
            collisions_pad2 = pygame.sprite.spritecollide(car, self.pad_group2, False, collided = None)

            x = car.rect.centerx
            y = car.rect.centery

            theta = (400 - x)/(math.sqrt((x - 400)**2 + (y-400)**2))
            if y > 400:
                #print("here")
                car.direction = (math.degrees(math.acos(theta)) % 360)
            else: 
                car.direction = -math.degrees(math.acos(theta) % 360)

            if len(collisions_pad1) != 0:
                car.direction -= 10
            elif len(collisions_pad2) != 0: 
                car.direction += 10

            i += 1
        
        self.car_group.update(deltat)
        for s in self.sensor_group:
          s.update()

        
        

        avg_speed = 0
        for c in self.cars:
            avg_speed += c.speed
        avg_speed /= len(self.cars)
        #print(str(avg_speed) + " " + str(self.cars[0].position))

        # record observation for each agent
        j = 0
        for car in self.cars:
            j += 1
            if j != 1 and j != 7: 
               continue
            current_obs = np.zeros(10)
            current_reward = 0
            closest_obj = 1000

            other_cars = self.cars[:]
            other_cars.remove(car)
            other_car_group = pygame.sprite.Group(other_cars)
            #print(other_cars)

            if car.steps == 500:
              done_d['__all__'] = True

            for i in range(0, len(self.sensors[j - 1])):
                cur_sensor = self.sensors[j - 1][i - 1]
                
                pad_near = pygame.sprite.spritecollide(cur_sensor, self.pad_group1, False, collided = None)
                pad_near2 = pygame.sprite.spritecollide(cur_sensor, self.pad_group2, False, collided = None)
                car_near = pygame.sprite.spritecollide(cur_sensor, other_car_group, False, collided = None)
                nearest_dist = 400
                rect_list = []
                # use clip rect function
                for pad in pad_near:
                    newrect = pad.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for pad in pad_near2:
                    newrect = pad.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for other_car in car_near:
                    newrect = other_car.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for rec in rect_list:
                    cur_dist = math.sqrt((rec.centerx - car.rect.centerx) ** 2 + (rec.centery - car.rect.centery) ** 2)
                    if  cur_dist < nearest_dist:
                        nearest_dist = cur_dist
                current_obs[i] = nearest_dist
                if nearest_dist < closest_obj:
                    closest_obj = nearest_dist
            
            
            current_obs[8] = car.speed
            current_obs[9] = avg_speed

            car_collide = pygame.sprite.spritecollide(car, other_car_group, False, collided = None)
            if len(car_collide) != 0:
                print(car_collide)
                print(car.position)
                for s in self.sensors[2]:
                  print(str(s.xnew) + " " + str(s.ynew))
                print("here " + str(self.step_count) + " " + str(avg_speed))
                done_d['__all__'] = True

            current_reward += avg_speed

            obs_n.append(current_obs)
            reward_n.append(current_reward)

        #speed = named_actors.get_actor("global_counter")
        #speed.update.remote(avg_speed)
       
        obs_d = {
            "car_0": obs_n[0],
            "car_1": obs_n[1],

        }
        reward_d = {
            "car_0": reward_n[0],
            "car_1": reward_n[1],

        }

        if done_d["__all__"] == True:
            print(avg_speed)
            
            print('Done')


        return obs_d, reward_d, done_d, info_d

    def reset(self):
       
        # record observations for each agent
        obs_n = []

        self.step_count = 0

        

        

        car = CarSprite('car.png', (60, 400))
        car2 = CarSprite('car.png', (110, 230))
        car3 = CarSprite('car.png', (215, 115))
        car4 = CarSprite('car.png', (380, 55))
        car5 = CarSprite('car.png', (565, 115))
        car6 = CarSprite('car.png', (690, 240))
        car7 = CarSprite('car.png', (740, 390))
        car8 = CarSprite('car.png', (690, 540))
        car9 = CarSprite('car.png', (565, 665))
        car10 = CarSprite('car.png', (390, 740))
        car11 = CarSprite('car.png', (215, 665))
        car12 = CarSprite('car.png', (115, 540))

        self.cars = [car, car2, car3, car4, car5, car6, car7, car8, car9, car10, car11, car12]

        self.car_group = pygame.sprite.RenderPlain(*self.cars)
        def addSensor(car, sensors):
            sensors.append(SensorSprite(0, -250, car))
            sensors.append(SensorSprite(200, -230, car))
            sensors.append(SensorSprite(-200, -230, car))
            sensors.append(SensorSprite(150, 0, car))
            sensors.append(SensorSprite(-150, 0, car))
            sensors.append(SensorSprite(0, 150, car))
            sensors.append(SensorSprite(100, 130, car))
            sensors.append(SensorSprite(-100, 130, car))

        self.sensors = []

        for c in self.cars:
            curr = []
            addSensor(c, curr)
            self.sensors.append(curr)

        self.sensor_group = []
        for sensor in self.sensors:
          self.sensor_group.append(pygame.sprite.RenderPlain(*sensor))

        for c in self.cars:
          c.speed = 10
         # record observation for each agent
        j = 0
        for car in self.cars:
            j += 1
            
            if j != 1 and j != 7:
              continue
            current_obs = np.zeros(10)
            current_reward = 0
            closest_obj = 500

            other_cars = self.cars[:]
            other_cars.remove(car)
            other_car_group = pygame.sprite.Group(other_cars)

            for i in range(0, len(self.sensors[j - 1])):
                cur_sensor = self.sensors[j - 1][i - 1]
                
                pad_near = pygame.sprite.spritecollide(cur_sensor, self.pad_group1, False, collided = None)
                pad_near2 = pygame.sprite.spritecollide(cur_sensor, self.pad_group2, False, collided = None)
                car_near = pygame.sprite.spritecollide(cur_sensor, other_car_group, False, collided = None)
                nearest_dist = 400
                rect_list = []
                # use clip rect function
                for pad in pad_near:
                    newrect = pad.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for pad in pad_near2:
                    newrect = pad.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for other_car in car_near:
                    newrect = other_car.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for rec in rect_list:
                    cur_dist = math.sqrt((rec.centerx - car.rect.centerx) ** 2 + (rec.centery - car.rect.centery) ** 2)
                    if  cur_dist < nearest_dist:
                        nearest_dist = cur_dist
                current_obs[i] = nearest_dist
                if nearest_dist < closest_obj:
                    closest_obj = nearest_dist
            
            current_obs[8] = 10
            current_obs[9] = 10

            obs_n.append(current_obs)
            

        obs_d = {
            "car_0": obs_n[0],
            "car_1": obs_n[1],

        }

        return obs_d


    # render environment
    def render(self, mode='human'):

        self.screen.fill([128, 128, 128])
        self.pad_group.draw(self.screen)
        self.car_group.draw(self.screen)
        pygame.display.update()
        file_num = file_num + 1
        image = cam.get_image()
        # Save every frame
        filename = "Snaps/%04d.png" % file_num
        pygame.image.save(image, filename)
        #pygame.display.flip()

# %%
class CarSprite(pygame.sprite.Sprite):
    MAX_FORWARD_SPEED = 10
    MAX_REVERSE_SPEED = 0
    ACCELERATION = 2
    TURN_SPEED = 10
    checkpoint = 0
    cur_policy = 1
    ready = False

    def __init__(self, image, position):
        pygame.sprite.Sprite.__init__(self)
        self.src_image = pygame.image.load(image)
        self.image = pygame.image.load(image)
        self.position = position
        self.speed = self.direction = 0
        self.k_left = self.k_right = self.k_down = self.k_up = 0
        x, y = (self.position)
        self.rect = self.image.get_rect()
        self.rect.center = self.position
        self.steps = 0
        

    
    def update(self, deltat):
        self.speed += (self.k_up + self.k_down)
        if self.speed > self.MAX_FORWARD_SPEED:
            self.speed = self.MAX_FORWARD_SPEED
        if self.speed < -self.MAX_REVERSE_SPEED:
            self.speed = -self.MAX_REVERSE_SPEED
        self.direction += (self.k_right + self.k_left)
        x, y = (self.position)
        rad = self.direction * math.pi / 180
        velocity_x = -self.speed*math.sin(rad)
        velocity_y = -self.speed*math.cos(rad)
        self.steps += 1
        x += velocity_x
        y += velocity_y
        x_c = x
        y_c = y
        self.position = (x, y)

        self.image = pygame.transform.rotate(self.src_image, self.direction)
        self.rect = self.image.get_rect()
        self.rect.center = self.position
        #pygame.draw.rect(screen, (255, 255, 0), self.rect, width=2)



class SensorSprite(pygame.sprite.Sprite):
    xpos = 0
    ypos = 0
    xnew = 0
    ynew = 0
    obj = None

    def __init__(self, x_pos, y_pos, obj):
        self.xpos = x_pos
        self.ypos = y_pos
        self.xnew = obj.rect.centerx + x_pos
        self.ynew = obj.rect.centery + y_pos
        self.obj = obj
        pygame.sprite.Sprite.__init__(self)
        if obj.rect.centerx < self.xnew and y_pos > 0:
            #left, top, width, height
            self.rect = pygame.Rect(obj.rect.centerx, obj.rect.centery, x_pos, y_pos)

        elif obj.rect.centerx > self.xnew and y_pos > 0:
             self.rect = pygame.Rect(self.xnew, obj.rect.centery, abs(x_pos), y_pos)

        elif obj.rect.centerx < self.xnew and y_pos < 0:
            self.rect = pygame.Rect(obj.rect.centerx, self.ynew, x_pos, abs(y_pos))

        else:
            self.rect = pygame.Rect(self.xnew, self.ynew, abs(x_pos), abs(y_pos))
      
    def update(self):

        rad = -self.obj.direction * math.pi / 180
        s = math.sin(rad);
        c = math.cos(rad);
        x = self.obj.rect.centerx
        y = self.obj.rect.centery

        xnew = c*(self.xpos) - s *(self.ypos) + x
        ynew = s*(self.xpos) + c *(self.ypos) + y

        

        if x < xnew and y < ynew:
            #left, top, width, height
            if x - xnew == 0:
                self.rect = pygame.Rect(x , y, 1, abs(y - ynew))
            elif y - ynew == 0:
                self.rect = pygame.Rect(x , y, abs(x - xnew), 1)
            else:
                self.rect = pygame.Rect(x , y, abs(x - xnew), abs(y - ynew))

        elif x > xnew and y < ynew:
            if x - xnew == 0:
                self.rect = pygame.Rect(xnew , y, 1, abs(y - ynew))
            elif y - ynew == 0:
                self.rect = pygame.Rect(xnew, y, abs(x - xnew), 1)
            else:
                self.rect = pygame.Rect(xnew , y, abs(x - xnew), abs(y - ynew))

        elif x < xnew and y > ynew:
            if x - xnew == 0:
                self.rect = pygame.Rect(x, ynew, 1, abs(y - ynew))
            elif y - ynew == 0:
                self.rect = pygame.Rect(x, ynew, abs(x - xnew), 1)
            else:
                self.rect = pygame.Rect(x , ynew, abs(x - xnew), abs(y - ynew))

        else:
            if x - xnew == 0:
                self.rect = pygame.Rect(xnew , ynew, 1, abs(y - ynew))
            elif y - ynew == 0:
                self.rect = pygame.Rect(xnew, ynew, abs(x - xnew), 1)
            else:
                self.rect = pygame.Rect(xnew , ynew, abs(x - xnew), abs(y - ynew))

        #self.rect = pygame.draw.line(screen,(255, 0, 0),(x, y),(xnew, ynew), width=2)




class PadSprite(pygame.sprite.Sprite):
    normal = None
    #hit = pygame.image.load('collision.png')
    def __init__(self, position, image):
        self.image = pygame.image.load(image)
  
        super(PadSprite, self).__init__()
        if image.startswith('pad_vert'):
          self.rect = pygame.Rect(0, 0, 15, 50)
        else:
          self.rect = pygame.Rect(0, 0, 50, 15)
        self.rect.center = position
    def update(self, hit_list):
        if self in hit_list: 
            #self.image = self.hit
            self.position = (50, 50)
        else: self.image = self.normal


class CheckPointSprite(pygame.sprite.Sprite):
    def __init__(self, left, top, width, height, val):
        super(CheckPointSprite, self).__init__()
        self.rect = pygame.Rect(left, top, width, height)
        self.val = val




# environment for all agents in the multiagent world
# currently code assumes that no agents will be created/destroyed at runtime!
class MultiCarEnv(gym.Env, MultiAgentEnv):
    metadata = {
        'render.modes' : ['human', 'console']
    }

    UP = 0
    DOWN = 1




    def __init__(self):
        super(MultiCarEnv, self).__init__()

        pygame.init()
        self.screen = pygame.display.set_mode((1024, 800))
        self.screen.fill([128, 128, 128])
        pygame.display.update()


        def drawCirclePad(xc, yc, x, y, pads):
            pads.append(PadSprite((xc + x, yc + y),'pad_sq.png'))
            #pads.append(PadSprite((xc - x, yc + y),'pad_sq.png'))
            pads.append(PadSprite((xc + x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc - x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc + y, yc + x),'pad_sq.png'))
            #pads.append(PadSprite((xc - y, yc + x),'pad_sq.png'))
            pads.append(PadSprite((xc + y, yc - x),'pad_sq.png'))
            pads.append(PadSprite((xc - y, yc - x),'pad_sq.png'))

        def drawCirclePad2(xc, yc, x, y, pads):
            pads.append(PadSprite((xc + x, yc + y),'pad_sq.png'))
            pads.append(PadSprite((xc - x, yc + y),'pad_sq.png'))
            #pads.append(PadSprite((xc + x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc - x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc + y, yc + x),'pad_sq.png'))
            pads.append(PadSprite((xc - y, yc + x),'pad_sq.png'))
            #pads.append(PadSprite((xc + y, yc - x),'pad_sq.png'))
            pads.append(PadSprite((xc - y, yc - x),'pad_sq.png'))

        def drawCirclePad3(xc, yc, x, y, pads):
            pads.append(PadSprite((xc + x, yc + y),'pad_sq.png'))
            pads.append(PadSprite((xc - x, yc + y),'pad_sq.png'))
            pads.append(PadSprite((xc + x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc - x, yc - y),'pad_sq.png'))
            pads.append(PadSprite((xc + y, yc + x),'pad_sq.png'))
            pads.append(PadSprite((xc - y, yc + x),'pad_sq.png'))
            pads.append(PadSprite((xc + y, yc - x),'pad_sq.png'))
            pads.append(PadSprite((xc - y, yc - x),'pad_sq.png'))


        def circleBres(xc, yc, r, pad, flag):

            x = 0
            y = r; 
            d = 3 - 2 * r 
            if flag == 1:
                drawCirclePad(xc, yc, x, y, pad)
            elif flag == 2:
                drawCirclePad2(xc, yc, x, y, pad)
            else:
                drawCirclePad3(xc, yc, x, y, pad)

            while y >= x:
                  
                x += 1

                if d > 0:
                    y -= 1
                    d = d + 4 * (x - y) + 10; 
                
                else:
                    d = d + 4 * x + 6; 
                if flag == 1:
                    drawCirclePad(xc, yc, x, y, pad)
                elif flag == 2:
                    drawCirclePad2(xc, yc, x, y, pad)
                else:
                    drawCirclePad3(xc, yc, x, y, pad)




        pads1 = []
        pads2 = []  

        circleBres(700, 220, 200, pads1, 1)
        circleBres(370, 550, 200, pads1, 2)
        circleBres(700, 220, 130, pads2, 1)
        circleBres(370, 550, 130, pads2, 2)


        #left horiz
        for i in range(370, 490):
            pads1.append(PadSprite((i, 350), 'pad_sq.png'))

        for i in range(370, 490):
            pads1.append(PadSprite((i, 420), 'pad_sq.png'))
        #right horiz
        for i in range(580, 700):
            pads1.append(PadSprite((i, 350), 'pad_sq.png'))

        for i in range(580, 700):
            pads1.append(PadSprite((i, 420), 'pad_sq.png'))
        #top vert
        for i in range(220, 350):
            pads1.append(PadSprite((500, i), 'pad_sq.png'))
        #bot vert
        for i in range(420, 550):
            pads1.append(PadSprite((570, i), 'pad_sq.png'))

        for i in range(420, 550):
            pads1.append(PadSprite((500, i), 'pad_sq.png'))

        for i in range(220, 350):
            pads1.append(PadSprite((570, i), 'pad_sq.png'))


        self.pad_group1 = pygame.sprite.RenderPlain(*pads1)
        self.pad_group2 = pygame.sprite.RenderPlain(*pads2)



        self.checkpoints = [CheckPointSprite(500, 200, 75, 30, 1), 
                      CheckPointSprite(650, 350, 30, 75, 2),
                      CheckPointSprite(340, 350, 30, 75, 3),
                      CheckPointSprite(500, 490, 75, 30, 4),
                      CheckPointSprite(500, 350, 100, 100, 5)
                      ]
        self.check_group = pygame.sprite.RenderPlain(*self.checkpoints)


        car10 = CarSprite('car.png', (530, 200))
        car2 = CarSprite('car.png', (590, 100))
        car3 = CarSprite('car.png', (700, 50))
        car4 = CarSprite('car.png', (810, 100))
        car5 = CarSprite('car.png', (865, 200))
        car6 = CarSprite('car.png', (830, 320))
        car7 = CarSprite('car.png', (700, 385))
        car7.cur_policy = 2
        car7.direction = 90
        car8 = CarSprite('car.png', (550, 385))
        car8.cur_policy = 2
        car8.direction = 90
        car9 = CarSprite('car.png', (400, 385))
        car9.cur_policy = 2
        car9.direction = 90
        car = CarSprite('car.png', (250, 450))
        car.cur_policy = 3
        #car = CarSprite('car.png', (200, 560))
        #car.cur_policy = 3
        self.cars = [car, car2, car3, car4, car5, car6, car7, car8, car9, car10]
        self.car_group = pygame.sprite.RenderPlain(*self.cars)


        def addSensor(car, sensors):
            sensors.append(SensorSprite(0, -250, car))
            sensors.append(SensorSprite(200, -230, car))
            sensors.append(SensorSprite(-200, -230, car))
            sensors.append(SensorSprite(250, 0, car))
            sensors.append(SensorSprite(-250, 0, car))
            sensors.append(SensorSprite(0, 250, car))
            sensors.append(SensorSprite(200, 230, car))
            sensors.append(SensorSprite(-200, 230, car))
            

        self.sensors = []
        


        for c in self.cars:
            curr = []
            addSensor(c, curr)
            self.sensors.append(curr)

        self.sensor_group = []
        for sensor in self.sensors:
            self.sensor_group.append(pygame.sprite.RenderPlain(*sensor))
    
        self.time = 0

        #accelerate, decelerate, nothing
        self.action_space = spaces.Discrete(3)
        #distance to another object, average velocity of other cars, own velocity
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf,
                                        shape=(10,), dtype=np.float32)

        self.wait = 3
        self.step_count = 0

        self.q = []
        self.delay = 0

        

    def step(self, action_n):
        self.step_count += 1
        self.delay += 1

        obs_d = {}
        reward_d = {}
        done_d =  {
            "car_0": False,    
            "car_1": False,    
            "__all__": False,  # the env is not done
        }

        info_d = {
            "car_0":{},
            "car_1":{}
        }




        obs_n = []
        reward_n = []


        clock = pygame.time.Clock()
        #deltat = clock.tick(30)
        deltat = 30
        self.time += deltat
        # set and perform action for each agent
        i = 0
        idx = [0,1]
        for key, val in action_n.items():
            cur_action = val
            if cur_action == self.DOWN:
                self.cars[idx[i]].k_down = -1
            else:
                self.cars[idx[i]].k_down = 0
            if cur_action == self.UP:
                self.cars[idx[i]].k_up = 0.5
            else: 
                self.cars[idx[i]].k_up = 0
            i += 1

        if len(self.q) > 0 and (self.delay >= 35):
            temp = self.q.pop(0)
            temp.ready = True
            self.delay = 0

        i = 0
        for car in self.cars:

            other_cars = self.cars[:]
            other_cars.remove(car)
            other_cars_g = pygame.sprite.Group(other_cars)

            collisions_pad1 = pygame.sprite.spritecollide(car, self.pad_group1, False, collided = None)
            collisions_pad2 = pygame.sprite.spritecollide(car, self.pad_group2, False, collided = None)

            checks = pygame.sprite.spritecollide(car, self.check_group, False, collided = None)
            if len(checks) != 0 and checks[0].val != 5:
                car.cur_policy = checks[0].val


            #find the cars in range
            car_near = pygame.sprite.groupcollide(self.sensor_group[i].sprites()[0:3], other_cars_g, False, False, collided = None)
            #print(car_near)
            rect_list = []
            car_list = []
            #find the nearest car
            for key, value in car_near.items():
                for val in value:
                    car_list.append(val)
                    newrect = val.rect.clip(key.rect)
                    rect_list.append(newrect)
            #find nearest distance to other car
            mindist = 1000
            minCar = None
            k = 0
            for rec in rect_list:
                dist = math.sqrt((rec.centerx - car.rect.centerx) ** 2 + (rec.centery - car.rect.centery) ** 2)
                if dist < mindist:
                    mindist = dist
                    minCar = car_list[k]
                k += 1
            accel = 0


            #find car in front 
            car_front = pygame.sprite.spritecollide(self.sensor_group[i].sprites()[0], other_cars_g, False, collided = None)
            minFrontDist = 1000 
            minFrontCar = None
            front_rec_list = []
            for f in car_front:
                newrect = f.rect.clip(self.sensor_group[i].sprites()[0].rect)
                front_rec_list.append(newrect)
            k = 0
            for rec in front_rec_list:
                dist = math.sqrt((rec.centerx - car.rect.centerx) ** 2 + (rec.centery - car.rect.centery) ** 2)
                if dist < minFrontDist:
                    minFrontDist = dist
                    minFrontCar = car_front[k]
                k += 1





            if i != 0 and i != 1:
              if car.ready == True and (minFrontCar == None or car.speed < minFrontCar.speed):
                  if minFrontCar != None and 0.2 > minFrontCar.speed - car.speed:
                      accel = minFrontCar.speed - car.speed
                  else:
                      accel = 0.2
                  if len(checks) == 0:
                      car.ready = False
              elif mindist < 75:
                  if len(checks) > 0 and checks[0].val == 5 and car not in self.q: 
                      # queue to go
                      self.q.append(car)
                  accel = -(car.speed/2)
              else:
                  if minCar == None  or car.speed < minCar.speed:
                      #print("here" + " " + str(i) + str(minCar))
                      if minCar != None and 0.2 > minCar.speed - car.speed:
                          accel = minCar.speed - car.speed
                      else:
                          accel = 0.2
              car.speed += accel
            else:
               if car.ready == True and (minFrontCar == None or car.speed < minFrontCar.speed):
                  if len(checks) == 0:
                      car.ready = False
               elif mindist < 75:
                  if len(checks) > 0 and checks[0].val == 5 and car not in self.q: 
                      # queue to go
                      self.q.append(car)
                  accel = -(car.speed/2)
                  car.k_down = 0
                  car.k_up = 0  
                  car.speed += accel    


            x = car.rect.centerx
            y = car.rect.centery

            if car.cur_policy == 1:
                theta = (700 - x)/(math.sqrt((x - 700)**2 + (y-220)**2))
                if y > 220:
                    car.direction = (math.degrees(math.acos(theta)) % 360)
                else: 
                    car.direction = -math.degrees(math.acos(theta) % 360)
                if len(collisions_pad1) != 0:
                    car.direction -= 10
                elif len(collisions_pad2) != 0: 
                    car.direction += 10
            elif car.cur_policy == 3:
                theta = (370 - x)/(math.sqrt((x - 370)**2 + (y-550)**2))
                if y > 550:
                    car.direction = (math.degrees(math.acos(theta)) % 360) + 180 
                else: 
                    car.direction = -math.degrees(math.acos(theta) % 360) + 180
                if len(collisions_pad1) != 0:
                    car.direction += 10
                elif len(collisions_pad2) != 0: 
                    car.direction -= 10
            elif car.cur_policy == 2:
                car.direction = 90
            elif car.cur_policy == 4:
                car.direction = 0


            i += 1
        
        self.car_group.update(deltat)
        for s in self.sensor_group:
          s.update()

        if self.step_count == 1000:
          done_d['__all__'] = True
        

        avg_speed = 0
        for c in self.cars:
            avg_speed += c.speed
        avg_speed /= len(self.cars)
        #print(str(avg_speed) + " " + str(self.cars[0].cur_policy) + " " + str(self.cars[0].position))

        # record observation for each agent
        j = 0
        for car in self.cars:
            if j != 0 and j != 1: 
              continue
            current_obs = np.zeros(10)
            current_reward = 0
            closest_obj = 1000

            other_cars = self.cars[:]
            other_cars.remove(car)
            other_car_group = pygame.sprite.Group(other_cars)
            #print(other_cars)

            for i in range(0, len(self.sensors[j])):
                cur_sensor = self.sensors[j][i]
                
                pad_near = pygame.sprite.spritecollide(cur_sensor, self.pad_group1, False, collided = None)
                pad_near2 = pygame.sprite.spritecollide(cur_sensor, self.pad_group2, False, collided = None)
                car_near = pygame.sprite.spritecollide(cur_sensor, other_car_group, False, collided = None)
                nearest_dist = 400
                rect_list = []
                # use clip rect function
                for pad in pad_near:
                    newrect = pad.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for pad in pad_near2:
                    newrect = pad.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for other_car in car_near:
                    newrect = other_car.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for rec in rect_list:
                    cur_dist = math.sqrt((rec.centerx - car.rect.centerx) ** 2 + (rec.centery - car.rect.centery) ** 2)
                    if  cur_dist < nearest_dist:
                        nearest_dist = cur_dist
                current_obs[i] = nearest_dist
            
            
            current_obs[8] = car.speed
            current_obs[9] = avg_speed

            car_collide = pygame.sprite.spritecollide(car, other_car_group, False, collided = None)
            #if len(car_collide) != 0:
               # print(car_collide)
               # print(car.position)
                #print("here " + str(self.step_count) + " " + str(avg_speed))
                #done_d['__all__'] = True

            current_reward += avg_speed

            obs_n.append(current_obs)
            reward_n.append(current_reward)
            j += 1
       
        obs_d = {
            "car_0": obs_n[0],
            "car_1": obs_n[1]
        }
        reward_d = {
            "car_0": reward_n[0],
            "car_1": reward_n[1]
        }
        

        if done_d["__all__"] == True:
            print(avg_speed)
            print('Done')


        return obs_d, reward_d, done_d, info_d

    def reset(self):

        self.delay = 0
        self.q = []
       
        # record observations for each agent
        obs_n = []

        self.step_count = 0


        car10 = CarSprite('car.png', (530, 200))
        car2 = CarSprite('car.png', (590, 100))
        car3 = CarSprite('car.png', (700, 50))
        car4 = CarSprite('car.png', (810, 100))
        car5 = CarSprite('car.png', (865, 200))
        car6 = CarSprite('car.png', (830, 320))
        car7 = CarSprite('car.png', (700, 385))
        car7.cur_policy = 2
        car7.direction = 90
        car8 = CarSprite('car.png', (550, 385))
        car8.cur_policy = 2
        car8.direction = 90
        car9 = CarSprite('car.png', (400, 385))
        car9.cur_policy = 2
        car9.direction = 90
        car = CarSprite('car.png', (250, 450))
        car.cur_policy = 3
        #car = CarSprite('car.png', (200, 560))
        #car.cur_policy = 3
        self.cars = [car, car2, car3, car4, car5, car6, car7, car8, car9, car10]
        self.car_group = pygame.sprite.RenderPlain(*self.cars)


        def addSensor(car, sensors):
            sensors.append(SensorSprite(0, -250, car))
            sensors.append(SensorSprite(200, -230, car))
            sensors.append(SensorSprite(-200, -230, car))
            sensors.append(SensorSprite(250, 0, car))
            sensors.append(SensorSprite(-250, 0, car))
            sensors.append(SensorSprite(0, 250, car))
            sensors.append(SensorSprite(200, 230, car))
            sensors.append(SensorSprite(-200, 230, car))
            

        self.sensors = []
        


        for c in self.cars:
            curr = []
            addSensor(c, curr)
            self.sensors.append(curr)

        self.sensor_group = []
        for sensor in self.sensors:
            self.sensor_group.append(pygame.sprite.RenderPlain(*sensor))
        
        for c in self.cars:
          c.speed = 0

        self.car_group.update(30)   
        for s in self.sensor_group:     
            s.update() 


         # record observation for each agent
        j = 0
        for car in self.cars:
            if j != 0 and j != 1:
              continue
            current_obs = np.zeros(10)
            current_reward = 0
            closest_obj = 500

            other_cars = self.cars[:]
            other_cars.remove(car)
            other_car_group = pygame.sprite.Group(other_cars)
            #print(other_cars)

            for i in range(0, len(self.sensors[j])):
                cur_sensor = self.sensors[j][i]
                
                pad_near = pygame.sprite.spritecollide(cur_sensor, self.pad_group1, False, collided = None)
                pad_near2 = pygame.sprite.spritecollide(cur_sensor, self.pad_group2, False, collided = None)
                car_near = pygame.sprite.spritecollide(cur_sensor, other_car_group, False, collided = None)
                nearest_dist = 400
                rect_list = []
                # use clip rect function
                for pad in pad_near:
                    newrect = pad.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for pad in pad_near2:
                    newrect = pad.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for other_car in car_near:
                    newrect = other_car.rect.clip(cur_sensor.rect)
                    rect_list.append(newrect)
                for rec in rect_list:
                    cur_dist = math.sqrt((rec.centerx - car.rect.centerx) ** 2 + (rec.centery - car.rect.centery) ** 2)
                    if  cur_dist < nearest_dist:
                        nearest_dist = cur_dist
                current_obs[i] = nearest_dist
            
            current_obs[8] = 0
            current_obs[9] = 0
            


   

            obs_n.append(current_obs)
            j += 1

        obs_d = {
            "car_0": obs_n[0],
            "car_1": obs_n[1]

        }

        return obs_d


    # render environment
    def render(self, mode='human'):

        self.screen.fill([128, 128, 128])
        self.pad_group.draw(self.screen)
        self.car_group.draw(self.screen)
        pygame.display.update()
        file_num = file_num + 1
        image = cam.get_image()
        # Save every frame
        filename = "Snaps/%04d.png" % file_num
        pygame.image.save(image, filename)
        #pygame.display.flip()

# %%
import random
from ray.rllib.agents.pg.pg import PGTrainer
from ray.rllib.agents.ppo.ppo import PPOTrainer
from ray.rllib.agents.dqn.dqn import DQNTrainer
from ray import tune

#ray.init()

num_episodes = 0
cur_reward = 0
final_rewards = []
final_checkpoints =[]


register_env("multienv", lambda config: MultiCarEnv3())
register_env("multienv2", lambda config: MultiCarEnv())


trainer = DQNTrainer(env="multienv", config={"timesteps_per_iteration": 1000, "gamma":.99,  "exploration_config": {
        # The Exploration class to use.
        "type": "EpsilonGreedy",
        # Config for the Exploration class' constructor:
        "initial_epsilon": 1.0,
        "final_epsilon": 0.05,
        "epsilon_timesteps": 40000,  # Timesteps over which to anneal epsilon.
    },})
i = 0
while i < 75:
    t_dict = trainer.train()
    print(t_dict)
    rewards = t_dict['hist_stats']['episode_reward']
    ep_lens = t_dict['hist_stats']['episode_lengths']
    ep_total = t_dict['episodes_this_iter']
    for j in range(ep_total):
      num_episodes += 1
    for j in range(ep_total):
      final_rewards.append(rewards[j] / 1000)

    i += 1

moving_average = []
curr_total = 0
for i in range(len(final_rewards)):
  if i < 9:
    moving_average.append(0)
    curr_total += final_rewards[i]
  else:
    curr_total += final_rewards[i]
    moving_average.append(curr_total/10)
    curr_total -= final_rewards[i-9]
  
  

print(len(final_rewards))
print(num_episodes)
fig = plt.figure()
ax = plt.subplot(111)
plt.style.use('seaborn-darkgrid')
ax.plot(final_rewards, label="reward")
ax.plot(moving_average, label="avg last 10 episodes")
ax.legend(loc='upper right')
plt.xlabel('Episode Count')
plt.ylabel('Reward (Average Velocity)')
plt.ylim(0, 10)
plt.title('Single Agent Figure 8 Track DQN Training')
plt.show()



#tune.run("PG", config={"env": "multienv", "train_batch_size": 1000})
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# 2020-04-27 06:38:39,972	INFO trainable.py:217 -- Getting current IP.
# 2020-04-27 06:38:39,978	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# 0.3843540135038912
# Done
# {'episode_reward_max': 1753.2723441240505, 'episode_reward_min': 1753.2723441240505, 'episode_reward_mean': 1753.2723441240505, 'episode_len_mean': 500.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [1753.2723441240505], 'episode_lengths': [500]}, 'sampler_perf': {'mean_env_wait_ms': 16.362879804508413, 'mean_processing_ms': 0.3888064515804816, 'mean_inference_ms': 2.0587915431953476}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 1.0}], 'num_target_updates': 1, 'num_steps_trained': 0, 'num_steps_sampled': 1000, 'sample_time_ms': 76.401, 'replay_time_ms': 0.0, 'grad_time_ms': 0.0, 'update_time_ms': 0.004, 'opt_peak_throughput': 0.0, 'opt_samples': 0.0, 'learner': {}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 1000, 'episodes_total': 1, 'training_iteration': 1, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-38-49', 'timestamp': 1587969529, 'time_this_iter_s': 9.6842942237854, 'time_total_s': 9.6842942237854, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 40000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shuffle_buffer_size': 0, 'output': None, 'output_compress_columns': ['obs', 'new_obs'], 'output_max_file_size': 67108864, 'multiagent': {'policies': {}, 'policy_mapping_fn': None, 'policies_to_train': None}, 'num_atoms': 1, 'v_min': -10.0, 'v_max': 10.0, 'noisy': False, 'si ...
# 0.5274874592473072
# Done
# {'episode_reward_max': 2023.4557817947784, 'episode_reward_min': 1753.2723441240505, 'episode_reward_mean': 1888.3640629594145, 'episode_len_mean': 500.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [2023.4557817947784, 1753.2723441240505], 'episode_lengths': [500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 16.31591645246791, 'mean_processing_ms': 0.3871772705549853, 'mean_inference_ms': 2.0408574163372117}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 1.0}], 'num_target_updates': 3, 'num_steps_trained': 4000, 'num_steps_sampled': 2000, 'sample_time_ms': 76.9, 'replay_time_ms': 1.706, 'grad_time_ms': 7.476, 'update_time_ms': 0.004, 'opt_peak_throughput': 4280.148, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 6.818659, 'min_q': 2.4001057, 'max_q': 17.116413, 'mean_td_error': 0.007708788, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 2000, 'episodes_total': 2, 'training_iteration': 2, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-39-00', 'timestamp': 1587969540, 'time_this_iter_s': 10.797608852386475, 'time_total_s': 20.481903076171875, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 40000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shuffle_buffer_size': 0, 'output': None, 'output_compress_columns': ['obs', 'ne ...
# 0.9914439556196238
# Done
# {'episode_reward_max': 2023.4557817947784, 'episode_reward_min': 1753.2723441240505, 'episode_reward_mean': 1896.3770033471483, 'episode_len_mean': 500.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [1912.402884122616, 1753.2723441240505, 2023.4557817947784], 'episode_lengths': [500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 16.33230028421627, 'mean_processing_ms': 0.3864114136869932, 'mean_inference_ms': 2.0400326874724732}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.97625}], 'num_target_updates': 5, 'num_steps_trained': 8000, 'num_steps_sampled': 3000, 'sample_time_ms': 77.08, 'replay_time_ms': 1.731, 'grad_time_ms': 8.083, 'update_time_ms': 0.004, 'opt_peak_throughput': 3958.98, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 8.7898655, 'min_q': 2.9753351, 'max_q': 32.57658, 'mean_td_error': 0.32705244, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 3000, 'episodes_total': 3, 'training_iteration': 3, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-39-11', 'timestamp': 1587969551, 'time_this_iter_s': 10.8802490234375, 'time_total_s': 31.362152099609375, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 40000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shuffle_buffer_size': 0, 'output': None, 'output_compr ...
# 0.5053084668221123
# Done
# {'episode_reward_max': 2172.0856408172053, 'episode_reward_min': 1753.2723441240505, 'episode_reward_mean': 1965.3041627146627, 'episode_len_mean': 500.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [2172.0856408172053, 1753.2723441240505, 2023.4557817947784, 1912.402884122616], 'episode_lengths': [500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 16.33190356168821, 'mean_processing_ms': 0.38720412856195296, 'mean_inference_ms': 2.0421759811466087}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.9525}], 'num_target_updates': 7, 'num_steps_trained': 12000, 'num_steps_sampled': 4000, 'sample_time_ms': 78.379, 'replay_time_ms': 1.588, 'grad_time_ms': 8.011, 'update_time_ms': 0.004, 'opt_peak_throughput': 3994.611, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 16.904957, 'min_q': 4.9036655, 'max_q': 54.967957, 'mean_td_error': -0.74912274, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 4000, 'episodes_total': 4, 'training_iteration': 4, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-39-22', 'timestamp': 1587969562, 'time_this_iter_s': 10.734975814819336, 'time_total_s': 42.09712791442871, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 40000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shuffle_buffer_size': 0 ...
# 1.2002829699783601
# Done
# {'episode_reward_max': 2319.905093865328, 'episode_reward_min': 1753.2723441240505, 'episode_reward_mean': 2036.2243489447956, 'episode_len_mean': 500.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [2319.905093865328, 1753.2723441240505, 2023.4557817947784, 1912.402884122616, 2172.0856408172053], 'episode_lengths': [500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 16.350869953947452, 'mean_processing_ms': 0.3882511948021563, 'mean_inference_ms': 2.045381338809255}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.92875}], 'num_target_updates': 9, 'num_steps_trained': 16000, 'num_steps_sampled': 5000, 'sample_time_ms': 75.978, 'replay_time_ms': 1.692, 'grad_time_ms': 7.66, 'update_time_ms': 0.004, 'opt_peak_throughput': 4177.49, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 17.84441, 'min_q': 7.2071137, 'max_q': 79.79235, 'mean_td_error': -0.40096435, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 5000, 'episodes_total': 5, 'training_iteration': 5, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-39-33', 'timestamp': 1587969573, 'time_this_iter_s': 11.078291177749634, 'time_total_s': 53.175419092178345, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 40000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shu ...
# 1.7454481697062425
# Done
# {'episode_reward_max': 2861.4484159193976, 'episode_reward_min': 1753.2723441240505, 'episode_reward_mean': 2173.761693440563, 'episode_len_mean': 500.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [2861.4484159193976, 1753.2723441240505, 2023.4557817947784, 1912.402884122616, 2172.0856408172053, 2319.905093865328], 'episode_lengths': [500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 16.36822213820031, 'mean_processing_ms': 0.38891784178140476, 'mean_inference_ms': 2.0567222384503148}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.905}], 'num_target_updates': 11, 'num_steps_trained': 20000, 'num_steps_sampled': 6000, 'sample_time_ms': 77.078, 'replay_time_ms': 1.851, 'grad_time_ms': 7.654, 'update_time_ms': 0.004, 'opt_peak_throughput': 4180.717, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 28.661985, 'min_q': 6.2006493, 'max_q': 82.85599, 'mean_td_error': 1.024857, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 6000, 'episodes_total': 6, 'training_iteration': 6, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-39-44', 'timestamp': 1587969584, 'time_this_iter_s': 11.070576190948486, 'time_total_s': 64.24599528312683, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 40000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postproc ...
# 2.417704706748229
# Done
# {'episode_reward_max': 2861.4484159193976, 'episode_reward_min': 1753.2723441240505, 'episode_reward_mean': 2132.413217520387, 'episode_len_mean': 500.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [1884.322361999335, 1753.2723441240505, 2023.4557817947784, 1912.402884122616, 2172.0856408172053, 2319.905093865328, 2861.4484159193976], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 16.375997112781643, 'mean_processing_ms': 0.3893009240437884, 'mean_inference_ms': 2.0618802439050414}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.88125}], 'num_target_updates': 13, 'num_steps_trained': 24000, 'num_steps_sampled': 7000, 'sample_time_ms': 77.208, 'replay_time_ms': 1.931, 'grad_time_ms': 7.809, 'update_time_ms': 0.004, 'opt_peak_throughput': 4097.626, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 31.034729, 'min_q': 8.566168, 'max_q': 105.431145, 'mean_td_error': -2.2744048, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 7000, 'episodes_total': 7, 'training_iteration': 7, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-39-54', 'timestamp': 1587969594, 'time_this_iter_s': 10.678272485733032, 'time_total_s': 74.92426776885986, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 40000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluati ...
# 0.45620013074353705
# Done
# {'episode_reward_max': 3280.6414400641975, 'episode_reward_min': 1753.2723441240505, 'episode_reward_mean': 2275.9417453383635, 'episode_len_mean': 500.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3280.6414400641975, 1753.2723441240505, 2023.4557817947784, 1912.402884122616, 2172.0856408172053, 2319.905093865328, 2861.4484159193976, 1884.322361999335], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 16.38310289453665, 'mean_processing_ms': 0.38956108887247476, 'mean_inference_ms': 2.064517936617565}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.8575}], 'num_target_updates': 15, 'num_steps_trained': 28000, 'num_steps_sampled': 8000, 'sample_time_ms': 78.625, 'replay_time_ms': 1.753, 'grad_time_ms': 8.445, 'update_time_ms': 0.004, 'opt_peak_throughput': 3789.235, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 46.409096, 'min_q': 12.234527, 'max_q': 126.36359, 'mean_td_error': 1.9339252, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 8000, 'episodes_total': 8, 'training_iteration': 8, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-40-05', 'timestamp': 1587969605, 'time_this_iter_s': 10.830729961395264, 'time_total_s': 85.75499773025513, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 40000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sa ...
# 2.369915875067543
# Done
# {'episode_reward_max': 3736.2421391567254, 'episode_reward_min': 1753.2723441240505, 'episode_reward_mean': 2438.197344651515, 'episode_len_mean': 500.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3736.2421391567254, 1753.2723441240505, 2023.4557817947784, 1912.402884122616, 2172.0856408172053, 2319.905093865328, 2861.4484159193976, 1884.322361999335, 3280.6414400641975], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 16.389478452256, 'mean_processing_ms': 0.389744928863418, 'mean_inference_ms': 2.0658957634413926}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.83375}], 'num_target_updates': 17, 'num_steps_trained': 32000, 'num_steps_sampled': 9000, 'sample_time_ms': 76.755, 'replay_time_ms': 1.956, 'grad_time_ms': 7.752, 'update_time_ms': 0.004, 'opt_peak_throughput': 4127.744, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 44.5402, 'min_q': 12.755854, 'max_q': 142.20662, 'mean_td_error': -9.887618, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 9000, 'episodes_total': 9, 'training_iteration': 9, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-40-16', 'timestamp': 1587969616, 'time_this_iter_s': 10.840085506439209, 'time_total_s': 96.59508323669434, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 40000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_work ...
# 3.1830089164028306
# Done
# {'episode_reward_max': 4072.3271903790874, 'episode_reward_min': 1753.2723441240505, 'episode_reward_mean': 2601.6103292242724, 'episode_len_mean': 500.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [4072.3271903790874, 1753.2723441240505, 2023.4557817947784, 1912.402884122616, 2172.0856408172053, 2319.905093865328, 2861.4484159193976, 1884.322361999335, 3280.6414400641975, 3736.2421391567254], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 16.398792358641256, 'mean_processing_ms': 0.3899425036402648, 'mean_inference_ms': 2.066484433187843}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.81}], 'num_target_updates': 19, 'num_steps_trained': 36000, 'num_steps_sampled': 10000, 'sample_time_ms': 77.584, 'replay_time_ms': 1.875, 'grad_time_ms': 7.897, 'update_time_ms': 0.004, 'opt_peak_throughput': 4052.26, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 69.03244, 'min_q': 16.420206, 'max_q': 170.10483, 'mean_td_error': 2.1442604, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 10000, 'episodes_total': 10, 'training_iteration': 10, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-40-27', 'timestamp': 1587969627, 'time_this_iter_s': 11.027436971664429, 'time_total_s': 107.62252020835876, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 40000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0 ...
# 7.693884278634755
# Done
# {'episode_reward_max': 5582.721971718359, 'episode_reward_min': 1753.2723441240505, 'episode_reward_mean': 2872.620478541917, 'episode_len_mean': 500.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [5582.721971718359, 1753.2723441240505, 2023.4557817947784, 1912.402884122616, 2172.0856408172053, 2319.905093865328, 2861.4484159193976, 1884.322361999335, 3280.6414400641975, 3736.2421391567254, 4072.3271903790874], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 16.406659507303342, 'mean_processing_ms': 0.3901766738102191, 'mean_inference_ms': 2.0664115335237305}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.78625}], 'num_target_updates': 21, 'num_steps_trained': 40000, 'num_steps_sampled': 11000, 'sample_time_ms': 77.648, 'replay_time_ms': 1.862, 'grad_time_ms': 7.54, 'update_time_ms': 0.004, 'opt_peak_throughput': 4244.052, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 92.70807, 'min_q': 22.906065, 'max_q': 166.69014, 'mean_td_error': -3.5990875, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 11000, 'episodes_total': 11, 'training_iteration': 11, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-40-38', 'timestamp': 1587969638, 'time_this_iter_s': 10.864487886428833, 'time_total_s': 118.4870080947876, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 40000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 1000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': ...
# 4.996408455285851
# Done
# ...
# 5.619262895595458
# Done
# {'episode_reward_max': 7076.359882834302, 'episode_reward_min': 1753.2723441240505, 'episode_reward_mean': 6062.083787557526, 'episode_len_mean': 493.1917808219178, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6777.801483271213, 1753.2723441240505, 2023.4557817947784, 1912.402884122616, 2172.0856408172053, 2319.905093865328, 2861.4484159193976, 1884.322361999335, 3280.6414400641975, 3736.2421391567254, 4072.3271903790874, 5582.721971718359, 6032.93635299395, 5151.180407971869, 6090.066211790252, 5726.262457597166, 6583.827358778424, 6114.767511690319, 6019.897580554863, 6398.301994957127, 6715.58500669501, 6623.290320731216, 6051.666297093701, 6636.527159191395, 6868.622374918207, 6313.221594778702, 7011.409965395844, 6759.6766393178805, 6366.349333085126, 6908.1845431741585, 6887.267162521885, 6757.36441536881, 6283.66804940032, 6884.715655007517, 6508.240287625887, 6933.518085295426, 6932.799705214109, 6885.864685938706, 6810.057319248115, 6918.6406416488435, 6872.306714578797, 6937.745946861637, 6932.43498409817, 6990.965067677255, 6921.313815218092, 6979.902423604334, 7056.274713448301, 6875.08767401967, 6969.851564820545, 6930.20295662167, 6901.892084264245, 6961.099201861205, 6835.3916752819905, 6942.374951288863, 4776.631736394801, 7061.660560984353, 6892.976449988109, 6954.854084110106, 6935.93842225287, 7008.254705024324, 7051.324481775976, 6928.081291761958, 6298.944958640548, 7024.4067813003, 4755.534159795912, 6796.512553302302, 4798.361802795397, 6777.288582497691, 6915.811981726132, 7076.359882834302, 6908.5224362624285, 6936.349839663806, 6976.922141726195], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 334, 500, 500, 500, 500, 500, 500, 500, 500, 500, 333, 500, 336, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 16.496081931075015, 'mean_processing_ms': 0.40340211914416235, 'mean_inference_ms': 2.0713763473914497}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 144, 'num_steps_trained': 288000, 'num_steps_sampled': 73000, 'sample_time_ms': 75.542, 'replay_time_ms': 1.933, 'grad_time_ms': 8.655, 'update_time_ms': 0.004, 'opt_peak_throughput': 3697.417, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 522.89246, 'min_q': 482.2319, 'max_q': 585.6246, 'mean_td_error': 15.641295, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 73000, 'episodes_total': 73, 'training_iteration': 73, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-51-56', 'timestamp': 1587970316, 'time_this_iter_s': 10.826672315597534, 'time_total_s': 795.6155099868774, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind',  ...
# 6.141538111139863
# Done
# {'episode_reward_max': 7076.359882834302, 'episode_reward_min': 1753.2723441240505, 'episode_reward_mean': 6072.766346846311, 'episode_len_mean': 493.2837837837838, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6852.593174927597, 1753.2723441240505, 2023.4557817947784, 1912.402884122616, 2172.0856408172053, 2319.905093865328, 2861.4484159193976, 1884.322361999335, 3280.6414400641975, 3736.2421391567254, 4072.3271903790874, 5582.721971718359, 6032.93635299395, 5151.180407971869, 6090.066211790252, 5726.262457597166, 6583.827358778424, 6114.767511690319, 6019.897580554863, 6398.301994957127, 6715.58500669501, 6623.290320731216, 6051.666297093701, 6636.527159191395, 6868.622374918207, 6313.221594778702, 7011.409965395844, 6759.6766393178805, 6366.349333085126, 6908.1845431741585, 6887.267162521885, 6757.36441536881, 6283.66804940032, 6884.715655007517, 6508.240287625887, 6933.518085295426, 6932.799705214109, 6885.864685938706, 6810.057319248115, 6918.6406416488435, 6872.306714578797, 6937.745946861637, 6932.43498409817, 6990.965067677255, 6921.313815218092, 6979.902423604334, 7056.274713448301, 6875.08767401967, 6969.851564820545, 6930.20295662167, 6901.892084264245, 6961.099201861205, 6835.3916752819905, 6942.374951288863, 4776.631736394801, 7061.660560984353, 6892.976449988109, 6954.854084110106, 6935.93842225287, 7008.254705024324, 7051.324481775976, 6928.081291761958, 6298.944958640548, 7024.4067813003, 4755.534159795912, 6796.512553302302, 4798.361802795397, 6777.288582497691, 6915.811981726132, 7076.359882834302, 6908.5224362624285, 6936.349839663806, 6976.922141726195, 6777.801483271213], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 334, 500, 500, 500, 500, 500, 500, 500, 500, 500, 333, 500, 336, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 16.49656587449855, 'mean_processing_ms': 0.4033506078858423, 'mean_inference_ms': 2.0711535246354726}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 146, 'num_steps_trained': 292000, 'num_steps_sampled': 74000, 'sample_time_ms': 77.454, 'replay_time_ms': 2.095, 'grad_time_ms': 8.307, 'update_time_ms': 0.004, 'opt_peak_throughput': 3852.182, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 531.1653, 'min_q': 479.65637, 'max_q': 576.36444, 'mean_td_error': 68.54056, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 74000, 'episodes_total': 74, 'training_iteration': 74, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-52-07', 'timestamp': 1587970327, 'time_this_iter_s': 11.107446432113647, 'time_total_s': 806.7229564189911, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocess ...
# 5.182084101016219
# Done
# {'episode_reward_max': 7076.359882834302, 'episode_reward_min': 1753.2723441240505, 'episode_reward_mean': 6082.173506110886, 'episode_len_mean': 493.37333333333333, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6778.303291689449, 1753.2723441240505, 2023.4557817947784, 1912.402884122616, 2172.0856408172053, 2319.905093865328, 2861.4484159193976, 1884.322361999335, 3280.6414400641975, 3736.2421391567254, 4072.3271903790874, 5582.721971718359, 6032.93635299395, 5151.180407971869, 6090.066211790252, 5726.262457597166, 6583.827358778424, 6114.767511690319, 6019.897580554863, 6398.301994957127, 6715.58500669501, 6623.290320731216, 6051.666297093701, 6636.527159191395, 6868.622374918207, 6313.221594778702, 7011.409965395844, 6759.6766393178805, 6366.349333085126, 6908.1845431741585, 6887.267162521885, 6757.36441536881, 6283.66804940032, 6884.715655007517, 6508.240287625887, 6933.518085295426, 6932.799705214109, 6885.864685938706, 6810.057319248115, 6918.6406416488435, 6872.306714578797, 6937.745946861637, 6932.43498409817, 6990.965067677255, 6921.313815218092, 6979.902423604334, 7056.274713448301, 6875.08767401967, 6969.851564820545, 6930.20295662167, 6901.892084264245, 6961.099201861205, 6835.3916752819905, 6942.374951288863, 4776.631736394801, 7061.660560984353, 6892.976449988109, 6954.854084110106, 6935.93842225287, 7008.254705024324, 7051.324481775976, 6928.081291761958, 6298.944958640548, 7024.4067813003, 4755.534159795912, 6796.512553302302, 4798.361802795397, 6777.288582497691, 6915.811981726132, 7076.359882834302, 6908.5224362624285, 6936.349839663806, 6976.922141726195, 6777.801483271213, 6852.593174927597], 'episode_lengths': [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 334, 500, 500, 500, 500, 500, 500, 500, 500, 500, 333, 500, 336, 500, 500, 500, 500, 500, 500, 500, 500]}, 'sampler_perf': {'mean_env_wait_ms': 16.49704515906947, 'mean_processing_ms': 0.4033007434227787, 'mean_inference_ms': 2.0709237396063265}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 148, 'num_steps_trained': 296000, 'num_steps_sampled': 75000, 'sample_time_ms': 78.71, 'replay_time_ms': 1.789, 'grad_time_ms': 8.056, 'update_time_ms': 0.004, 'opt_peak_throughput': 3972.067, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 535.27155, 'min_q': 501.96823, 'max_q': 617.64355, 'mean_td_error': 0.041089058, 'model': {}}}}, 'timesteps_this_iter': 1000, 'done': False, 'timesteps_total': 75000, 'episodes_total': 75, 'training_iteration': 75, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-52-18', 'timestamp': 1587970338, 'time_this_iter_s': 10.909542083740234, 'time_total_s': 817.6324985027313, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv', 'normalize_actions': False, 'clip_rewards': None, 'clip ...
# 75
# 75

# %%
check_point = trainer.save()

trainer2 = DQNTrainer(env="multienv2", config={"timesteps_per_iteration": 2000, "gamma":.99,  "exploration_config": {
        # The Exploration class to use.
        "type": "EpsilonGreedy",
        # Config for the Exploration class' constructor:
        "initial_epsilon": 1.0,
        "final_epsilon": 0.05,
        "epsilon_timesteps": 10000,  # Timesteps over which to anneal epsilon.
    },})
trainer2.restore(check_point)

print(len(final_rewards))
print(num_episodes)
plt.style.use('seaborn-darkgrid')
plt.plot(final_rewards, label="reward")
plt.plot(moving_average, label="avg last 10 episodes")
plt.legend(loc='lower right')
plt.xlabel('Episode Count')
plt.ylabel('Reward (Average Velocity)')
plt.title('2 Agent Circle Track PPO Training')
plt.show()


num_episodes = 0
cur_reward = 0
final_rewards2 = []


i = 0
while i < 75:
    t_dict = trainer2.train()
    print(t_dict)
    rewards = t_dict['hist_stats']['episode_reward']
    ep_lens = t_dict['hist_stats']['episode_lengths']
    ep_total = t_dict['episodes_this_iter']
    for j in range(ep_total):
      num_episodes += 1
    for j in range(ep_total):
      final_rewards2.append(rewards[j] / 2000)

    i += 1



moving_average2 = []
curr_total = 0
for i in range(len(final_rewards2)):
  if i < 9:
    moving_average2.append(0)
    curr_total += final_rewards2[i]
  else:
    curr_total += final_rewards2[i]
    moving_average2.append(curr_total/10)
    curr_total -= final_rewards2[i-9]
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# 2020-04-27 06:53:25,270	INFO trainable.py:217 -- Getting current IP.
# 2020-04-27 06:53:25,275	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# 2020-04-27 06:53:25,324	INFO trainable.py:217 -- Getting current IP.
# 2020-04-27 06:53:25,325	INFO trainable.py:423 -- Restored on 172.28.0.2 from checkpoint: /root/ray_results/DQN_multienv_2020-04-27_06-38-38i4oy9vsw/checkpoint_75/checkpoint-75
# 2020-04-27 06:53:25,332	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 75, '_timesteps_total': 75000, '_time_total': 817.6324985027313, '_episodes_total': 75}
# 75
# 75
# 2.1022180337599226
# Done
# {'episode_reward_max': 6824.003258698014, 'episode_reward_min': 6824.003258698014, 'episode_reward_mean': 6824.003258698014, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6824.003258698014], 'episode_lengths': [1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.306955735762042, 'mean_processing_ms': 0.37421213163362516, 'mean_inference_ms': 2.164517487441148}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 1.0}], 'num_target_updates': 152, 'num_steps_trained': 304000, 'num_steps_sampled': 77000, 'sample_time_ms': 73.672, 'replay_time_ms': 1.64, 'grad_time_ms': 7.833, 'update_time_ms': 0.004, 'opt_peak_throughput': 4085.216, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 459.61142, 'min_q': 300.8104, 'max_q': 604.63696, 'mean_td_error': 13.68887, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 77000, 'episodes_total': 76, 'training_iteration': 76, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-53-47', 'timestamp': 1587970427, 'time_this_iter_s': 21.89604139328003, 'time_total_s': 839.5285398960114, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shuffle_buffer_size': 0, 'output': None, 'output_compress_columns': ['obs', 'new_obs'], 'output_max_ ...
# 3.544628906543821
# Done
# {'episode_reward_max': 6824.003258698014, 'episode_reward_min': 6570.110303374103, 'episode_reward_mean': 6697.056781036059, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6570.110303374103, 6824.003258698014], 'episode_lengths': [1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.311166387169656, 'mean_processing_ms': 0.3730795277743409, 'mean_inference_ms': 2.1009528211356017}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 156, 'num_steps_trained': 312000, 'num_steps_sampled': 79000, 'sample_time_ms': 77.369, 'replay_time_ms': 1.694, 'grad_time_ms': 7.836, 'update_time_ms': 0.004, 'opt_peak_throughput': 4083.749, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 434.388, 'min_q': 310.6192, 'max_q': 519.9415, 'mean_td_error': 3.444642, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 79000, 'episodes_total': 77, 'training_iteration': 77, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-54-08', 'timestamp': 1587970448, 'time_this_iter_s': 21.342232942581177, 'time_total_s': 860.8707728385925, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shuffle_buffer_size': 0, 'output': None, 'output_compress_columns': ['obs', ...
# 2.152216836617159
# Done
# {'episode_reward_max': 6824.003258698014, 'episode_reward_min': 6570.110303374103, 'episode_reward_mean': 6670.89333464091, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6618.566441850614, 6824.003258698014, 6570.110303374103], 'episode_lengths': [1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.309331778116473, 'mean_processing_ms': 0.37351421396992907, 'mean_inference_ms': 2.093286444333532}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 160, 'num_steps_trained': 320000, 'num_steps_sampled': 81000, 'sample_time_ms': 76.437, 'replay_time_ms': 1.856, 'grad_time_ms': 8.314, 'update_time_ms': 0.004, 'opt_peak_throughput': 3848.78, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 458.49115, 'min_q': 327.71753, 'max_q': 554.62775, 'mean_td_error': 24.352299, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 81000, 'episodes_total': 78, 'training_iteration': 78, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-54-30', 'timestamp': 1587970470, 'time_this_iter_s': 21.614909648895264, 'time_total_s': 882.4856824874878, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shuffle_buffer_size': 0, 'output': None, 'outpu ...
# 2.3198613867739856e-243
# Done
# {'episode_reward_max': 6824.003258698014, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 5422.1756259810245, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [1676.0225000013666, 6824.003258698014, 6570.110303374103, 6618.566441850614], 'episode_lengths': [1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.32451857751078, 'mean_processing_ms': 0.3742889659134856, 'mean_inference_ms': 2.084026097692492}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 164, 'num_steps_trained': 328000, 'num_steps_sampled': 83000, 'sample_time_ms': 77.627, 'replay_time_ms': 1.636, 'grad_time_ms': 8.163, 'update_time_ms': 0.004, 'opt_peak_throughput': 3919.968, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 432.66357, 'min_q': 315.6556, 'max_q': 515.3328, 'mean_td_error': 12.270762, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 83000, 'episodes_total': 79, 'training_iteration': 79, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-54-52', 'timestamp': 1587970492, 'time_this_iter_s': 21.790937900543213, 'time_total_s': 904.276620388031, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shuffle_buffer_size':  ...
# 2.2948264080753997
# Done
# {'episode_reward_max': 7138.801930882989, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 5765.500886961417, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [7138.801930882989, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666], 'episode_lengths': [1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.338134677988666, 'mean_processing_ms': 0.3747259530233872, 'mean_inference_ms': 2.0747844860531415}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 168, 'num_steps_trained': 336000, 'num_steps_sampled': 85000, 'sample_time_ms': 77.356, 'replay_time_ms': 1.883, 'grad_time_ms': 8.818, 'update_time_ms': 0.004, 'opt_peak_throughput': 3629.105, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 435.89606, 'min_q': 317.58572, 'max_q': 555.97516, 'mean_td_error': -2.4297695, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 85000, 'episodes_total': 80, 'training_iteration': 80, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-55-13', 'timestamp': 1587970513, 'time_this_iter_s': 21.640718936920166, 'time_total_s': 925.9173393249512, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'], 'postprocess_inputs':  ...
# 3.8295433808214554
# Done
# {'episode_reward_max': 7138.801930882989, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 5975.673519408706, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [7026.536681645156, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.345356829416573, 'mean_processing_ms': 0.3752632715534297, 'mean_inference_ms': 2.0729109177505984}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 172, 'num_steps_trained': 344000, 'num_steps_sampled': 87000, 'sample_time_ms': 75.907, 'replay_time_ms': 2.007, 'grad_time_ms': 7.661, 'update_time_ms': 0.004, 'opt_peak_throughput': 4176.814, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 452.05695, 'min_q': 328.73627, 'max_q': 592.371, 'mean_td_error': 18.388882, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 87000, 'episodes_total': 81, 'training_iteration': 81, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-55-35', 'timestamp': 1587970535, 'time_this_iter_s': 21.737430095672607, 'time_total_s': 947.6547694206238, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_evaluation': ['is', 'wis'],  ...
# 3.062344024183722
# Done
# {'episode_reward_max': 7871.612903815616, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6246.522002895408, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [7871.612903815616, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.35119377610652, 'mean_processing_ms': 0.37553625756818165, 'mean_inference_ms': 2.0681374705421547}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 176, 'num_steps_trained': 352000, 'num_steps_sampled': 89000, 'sample_time_ms': 79.917, 'replay_time_ms': 1.747, 'grad_time_ms': 8.232, 'update_time_ms': 0.005, 'opt_peak_throughput': 3887.237, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 410.46814, 'min_q': 316.67755, 'max_q': 495.09766, 'mean_td_error': -1.0097237, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 89000, 'episodes_total': 82, 'training_iteration': 82, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-55-57', 'timestamp': 1587970557, 'time_this_iter_s': 21.469709873199463, 'time_total_s': 969.1244792938232, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'input': 'sampler', 'input_ ...
# 5.374302151848743e-138
# Done
# {'episode_reward_max': 7871.612903815616, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 5917.6233408828675, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [3615.3327067950795, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.35450636865461, 'mean_processing_ms': 0.37569548663003094, 'mean_inference_ms': 2.0632817759607716}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 180, 'num_steps_trained': 360000, 'num_steps_sampled': 91000, 'sample_time_ms': 79.226, 'replay_time_ms': 1.74, 'grad_time_ms': 8.413, 'update_time_ms': 0.004, 'opt_peak_throughput': 3803.829, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 415.9058, 'min_q': 313.8163, 'max_q': 559.84045, 'mean_td_error': -1.5232439, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 91000, 'episodes_total': 83, 'training_iteration': 83, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-56-18', 'timestamp': 1587970578, 'time_this_iter_s': 21.653788328170776, 'time_total_s': 990.778267621994, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_memory_per_worker': 0, 'inp ...
# 1.379156757501121
# Done
# {'episode_reward_max': 7871.612903815616, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 5960.114636615606, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6300.045002477511, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.357165432027923, 'mean_processing_ms': 0.37598153794356537, 'mean_inference_ms': 2.058586561068358}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 184, 'num_steps_trained': 368000, 'num_steps_sampled': 93000, 'sample_time_ms': 77.662, 'replay_time_ms': 1.778, 'grad_time_ms': 7.824, 'update_time_ms': 0.004, 'opt_peak_throughput': 4089.971, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 405.10437, 'min_q': 302.82132, 'max_q': 528.00037, 'mean_td_error': 2.2123518, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 93000, 'episodes_total': 84, 'training_iteration': 84, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-56-40', 'timestamp': 1587970600, 'time_this_iter_s': 21.57392954826355, 'time_total_s': 1012.3521971702576, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker': 0, 'object_store_ ...
# 2.754708767081561
# Done
# {'episode_reward_max': 7871.612903815616, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6150.100773044581, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [7859.976000905357, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.35735951651236, 'mean_processing_ms': 0.3762829078336201, 'mean_inference_ms': 2.0540354104528857}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 188, 'num_steps_trained': 376000, 'num_steps_sampled': 95000, 'sample_time_ms': 79.54, 'replay_time_ms': 1.995, 'grad_time_ms': 8.56, 'update_time_ms': 0.004, 'opt_peak_throughput': 3738.301, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 422.7207, 'min_q': 311.14523, 'max_q': 522.9533, 'mean_td_error': -11.688994, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 95000, 'episodes_total': 85, 'training_iteration': 85, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-57-01', 'timestamp': 1587970621, 'time_this_iter_s': 21.34917688369751, 'time_total_s': 1033.701374053955, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_memory': 0, 'memory_per_worker ...
# 2.962928581297385
# Done
# {'episode_reward_max': 7871.612903815616, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6228.164296642519, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [7008.799532621892, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.35840956882006, 'mean_processing_ms': 0.37648005379074656, 'mean_inference_ms': 2.0498419722793937}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 192, 'num_steps_trained': 384000, 'num_steps_sampled': 97000, 'sample_time_ms': 76.621, 'replay_time_ms': 1.673, 'grad_time_ms': 8.26, 'update_time_ms': 0.004, 'opt_peak_throughput': 3874.265, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 414.57654, 'min_q': 284.66937, 'max_q': 590.72064, 'mean_td_error': -4.4471035, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 97000, 'episodes_total': 86, 'training_iteration': 86, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_06-57-23', 'timestamp': 1587970643, 'time_this_iter_s': 21.595722436904907, 'time_total_s': 1055.29709649086, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_rewards': None, 'clip_actions': True, 'preprocessor_pref': 'deepmind', 'lr': 0.0005, 'monitor': False, 'log_level': 'WARN', 'callbacks': {'on_episode_start': None, 'on_episode_step': None, 'on_episode_end': None, 'on_sample_end': None, 'on_train_result': None, 'on_postprocess_traj': None}, 'ignore_worker_failures': False, 'log_sys_usage': True, 'use_pytorch': False, 'eager': False, 'eager_tracing': False, 'no_eager_on_workers': False, 'explore': True, 'exploration_config': {'type': 'EpsilonGreedy', 'initial_epsilon': 1.0, 'final_epsilon': 0.05, 'epsilon_timesteps': 10000}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'in_evaluation': False, 'evaluation_config': {'explore': False}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'use_exec_api': False, 'sample_async': False, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 1, 'timesteps_per_iteration': 2000, 'seed': None, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'memory': 0, 'object_store_m ...
# 2.7762564563875154
# Done
# ...
# 2.3716479039192224
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6648.682806828709, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6758.374687069949, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357, 7008.799532621892, 7212.050320480788, 7156.741574064152, 6870.500197580292, 6527.961876430954, 6826.406301365392, 6946.459693154826, 6632.313283205862, 6755.246706102064, 6933.5065215625145, 6698.354368893961, 2955.2432251543523, 6742.2320642180775, 6874.005832856677, 6741.866132728801, 6741.683533888937, 6754.846357425081, 7472.339123365727, 7718.205284884017, 6736.030926278237, 6558.260866427156, 6807.23029138255, 7019.150132028008, 6852.536535333066, 6836.54299643397, 7050.426266236445, 6675.4688521120415, 6738.26422405803, 7026.2240832086245, 6938.291972269912, 6828.577338818448, 6859.79264959928, 2520.0274120170025, 6683.912929562914, 6954.469495133986, 6763.154744101562, 6522.244453809546, 6817.348821946897, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.313634940221014, 'mean_processing_ms': 0.3731719848250985, 'mean_inference_ms': 1.9735162658435261}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 438, 'num_steps_trained': 880000, 'num_steps_sampled': 221000, 'sample_time_ms': 75.858, 'replay_time_ms': 1.899, 'grad_time_ms': 7.978, 'update_time_ms': 0.004, 'opt_peak_throughput': 4010.929, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 370.8759, 'min_q': 305.84006, 'max_q': 686.4455, 'mean_td_error': 9.42218, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 221000, 'episodes_total': 148, 'training_iteration': 148, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-19-30', 'timestamp': 1587971970, 'time_this_iter_s': 21.501338005065918, 'time_total_s': 2382.1872923374176, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_actions': False, 'clip_reward ...
# 2.7215102566583784
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6653.352554331624, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6994.244122044417, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357, 7008.799532621892, 7212.050320480788, 7156.741574064152, 6870.500197580292, 6527.961876430954, 6826.406301365392, 6946.459693154826, 6632.313283205862, 6755.246706102064, 6933.5065215625145, 6698.354368893961, 2955.2432251543523, 6742.2320642180775, 6874.005832856677, 6741.866132728801, 6741.683533888937, 6754.846357425081, 7472.339123365727, 7718.205284884017, 6736.030926278237, 6558.260866427156, 6807.23029138255, 7019.150132028008, 6852.536535333066, 6836.54299643397, 7050.426266236445, 6675.4688521120415, 6738.26422405803, 7026.2240832086245, 6938.291972269912, 6828.577338818448, 6859.79264959928, 2520.0274120170025, 6683.912929562914, 6954.469495133986, 6763.154744101562, 6522.244453809546, 6817.348821946897, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.313093463618458, 'mean_processing_ms': 0.37314729653188644, 'mean_inference_ms': 1.9732761857170091}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 442, 'num_steps_trained': 888000, 'num_steps_sampled': 223000, 'sample_time_ms': 73.989, 'replay_time_ms': 1.863, 'grad_time_ms': 8.463, 'update_time_ms': 0.004, 'opt_peak_throughput': 3781.292, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 369.98056, 'min_q': 297.1507, 'max_q': 685.9848, 'mean_td_error': -7.6166134, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 223000, 'episodes_total': 149, 'training_iteration': 149, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-19-52', 'timestamp': 1587971992, 'time_this_iter_s': 21.403362274169922, 'time_total_s': 2403.5906546115875, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': 'multienv2', 'normalize_ ...
# 3.0129882813834894
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6659.158347214012, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [7088.787020510739, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357, 7008.799532621892, 7212.050320480788, 7156.741574064152, 6870.500197580292, 6527.961876430954, 6826.406301365392, 6946.459693154826, 6632.313283205862, 6755.246706102064, 6933.5065215625145, 6698.354368893961, 2955.2432251543523, 6742.2320642180775, 6874.005832856677, 6741.866132728801, 6741.683533888937, 6754.846357425081, 7472.339123365727, 7718.205284884017, 6736.030926278237, 6558.260866427156, 6807.23029138255, 7019.150132028008, 6852.536535333066, 6836.54299643397, 7050.426266236445, 6675.4688521120415, 6738.26422405803, 7026.2240832086245, 6938.291972269912, 6828.577338818448, 6859.79264959928, 2520.0274120170025, 6683.912929562914, 6954.469495133986, 6763.154744101562, 6522.244453809546, 6817.348821946897, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.312558809111458, 'mean_processing_ms': 0.37312422444945953, 'mean_inference_ms': 1.9730304011220547}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 446, 'num_steps_trained': 896000, 'num_steps_sampled': 225000, 'sample_time_ms': 76.919, 'replay_time_ms': 2.016, 'grad_time_ms': 7.713, 'update_time_ms': 0.004, 'opt_peak_throughput': 4148.938, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 361.84283, 'min_q': 271.47076, 'max_q': 529.6578, 'mean_td_error': -2.3008041, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 225000, 'episodes_total': 150, 'training_iteration': 150, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-20-13', 'timestamp': 1587972013, 'time_this_iter_s': 21.263963222503662, 'time_total_s': 2424.854617834091, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env_config': {}, 'env': ...

# %%
c = trainer2.save()

trainer2.restore(c)

i = 0
while i < 75:
    t_dict = trainer2.train()
    print(t_dict)
    rewards = t_dict['hist_stats']['episode_reward']
    ep_lens = t_dict['hist_stats']['episode_lengths']
    ep_total = t_dict['episodes_this_iter']
    for j in range(ep_total):
      num_episodes += 1
    for j in range(ep_total):
      final_rewards2.append(rewards[j] / 2000)

    i += 1



moving_average2 = []
curr_total = 0
for i in range(len(final_rewards2)):
  if i < 9:
    moving_average2.append(0)
    curr_total += final_rewards2[i]
  else:
    curr_total += final_rewards2[i]
    moving_average2.append(curr_total/10)
    curr_total -= final_rewards2[i-9]




print(len(final_rewards2))
print(num_episodes)
plt.style.use('seaborn-darkgrid')
plt.plot(final_rewards2, label="reward")
plt.plot(moving_average2, label="avg last 10 episodes")
plt.plot(np.zeros(150) + 3.5, label="baseline")
plt.legend(loc='lower right')
plt.xlabel('Episode Count')
plt.ylabel('Reward (Average Velocity)')
plt.title('Two Agent on Figure 8 Track using Circle Track DQN Model')
plt.show()
# Out:
# 2020-04-27 07:29:30,670	INFO trainable.py:217 -- Getting current IP.
# 2020-04-27 07:29:30,678	INFO trainable.py:423 -- Restored on 172.28.0.2 from checkpoint: /root/ray_results/DQN_multienv2_2020-04-27_06-53-23m8ve0hkb/checkpoint_150/checkpoint-150
# 2020-04-27 07:29:30,681	INFO trainable.py:430 -- Current state after restoring: {'_iteration': 150, '_timesteps_total': 225000, '_time_total': 2424.854617834091, '_episodes_total': 150}
# 2.364357019772118
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6661.895552027017, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6867.1859130024095, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357, 7008.799532621892, 7212.050320480788, 7156.741574064152, 6870.500197580292, 6527.961876430954, 6826.406301365392, 6946.459693154826, 6632.313283205862, 6755.246706102064, 6933.5065215625145, 6698.354368893961, 2955.2432251543523, 6742.2320642180775, 6874.005832856677, 6741.866132728801, 6741.683533888937, 6754.846357425081, 7472.339123365727, 7718.205284884017, 6736.030926278237, 6558.260866427156, 6807.23029138255, 7019.150132028008, 6852.536535333066, 6836.54299643397, 7050.426266236445, 6675.4688521120415, 6738.26422405803, 7026.2240832086245, 6938.291972269912, 6828.577338818448, 6859.79264959928, 2520.0274120170025, 6683.912929562914, 6954.469495133986, 6763.154744101562, 6522.244453809546, 6817.348821946897, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417, 7088.787020510739], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.3120153222378, 'mean_processing_ms': 0.37310038144172214, 'mean_inference_ms': 1.9728070415343053}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 450, 'num_steps_trained': 904000, 'num_steps_sampled': 227000, 'sample_time_ms': 76.863, 'replay_time_ms': 1.822, 'grad_time_ms': 8.325, 'update_time_ms': 0.004, 'opt_peak_throughput': 3843.809, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 368.135, 'min_q': 292.18243, 'max_q': 541.5377, 'mean_td_error': 6.2819014, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 227000, 'episodes_total': 151, 'training_iteration': 151, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-29-52', 'timestamp': 1587972592, 'time_this_iter_s': 21.32487678527832, 'time_total_s': 2446.1794946193695, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'en ...
# 1.9601697312224906
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6661.433984108925, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6626.354822333846, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357, 7008.799532621892, 7212.050320480788, 7156.741574064152, 6870.500197580292, 6527.961876430954, 6826.406301365392, 6946.459693154826, 6632.313283205862, 6755.246706102064, 6933.5065215625145, 6698.354368893961, 2955.2432251543523, 6742.2320642180775, 6874.005832856677, 6741.866132728801, 6741.683533888937, 6754.846357425081, 7472.339123365727, 7718.205284884017, 6736.030926278237, 6558.260866427156, 6807.23029138255, 7019.150132028008, 6852.536535333066, 6836.54299643397, 7050.426266236445, 6675.4688521120415, 6738.26422405803, 7026.2240832086245, 6938.291972269912, 6828.577338818448, 6859.79264959928, 2520.0274120170025, 6683.912929562914, 6954.469495133986, 6763.154744101562, 6522.244453809546, 6817.348821946897, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417, 7088.787020510739, 6867.1859130024095], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.31149010091772, 'mean_processing_ms': 0.3730769409086795, 'mean_inference_ms': 1.9725758243815705}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 454, 'num_steps_trained': 912000, 'num_steps_sampled': 229000, 'sample_time_ms': 74.41, 'replay_time_ms': 1.648, 'grad_time_ms': 8.639, 'update_time_ms': 0.007, 'opt_peak_throughput': 3704.029, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 344.338, 'min_q': 300.68866, 'max_q': 434.22122, 'mean_td_error': 7.7935762, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 229000, 'episodes_total': 152, 'training_iteration': 152, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-30-13', 'timestamp': 1587972613, 'time_this_iter_s': 21.359325408935547, 'time_total_s': 2467.538820028305, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, 'soft_horizon': False, 'no ...
# 2.279357813578591
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6664.021526558867, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6863.262295204399, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357, 7008.799532621892, 7212.050320480788, 7156.741574064152, 6870.500197580292, 6527.961876430954, 6826.406301365392, 6946.459693154826, 6632.313283205862, 6755.246706102064, 6933.5065215625145, 6698.354368893961, 2955.2432251543523, 6742.2320642180775, 6874.005832856677, 6741.866132728801, 6741.683533888937, 6754.846357425081, 7472.339123365727, 7718.205284884017, 6736.030926278237, 6558.260866427156, 6807.23029138255, 7019.150132028008, 6852.536535333066, 6836.54299643397, 7050.426266236445, 6675.4688521120415, 6738.26422405803, 7026.2240832086245, 6938.291972269912, 6828.577338818448, 6859.79264959928, 2520.0274120170025, 6683.912929562914, 6954.469495133986, 6763.154744101562, 6522.244453809546, 6817.348821946897, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417, 7088.787020510739, 6867.1859130024095, 6626.354822333846], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.310984970487286, 'mean_processing_ms': 0.3730543458639512, 'mean_inference_ms': 1.9723400603546675}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 458, 'num_steps_trained': 920000, 'num_steps_sampled': 231000, 'sample_time_ms': 80.975, 'replay_time_ms': 2.004, 'grad_time_ms': 33.801, 'update_time_ms': 0.004, 'opt_peak_throughput': 946.716, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 363.02756, 'min_q': 302.0979, 'max_q': 655.90576, 'mean_td_error': 1.2649031, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 231000, 'episodes_total': 153, 'training_iteration': 153, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-30-35', 'timestamp': 1587972635, 'time_this_iter_s': 21.67790937423706, 'time_total_s': 2489.216729402542, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma': 0.99, 'horizon': None, ...
# 4.670960059165961
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6666.566875216784, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6865.10407053436, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357, 7008.799532621892, 7212.050320480788, 7156.741574064152, 6870.500197580292, 6527.961876430954, 6826.406301365392, 6946.459693154826, 6632.313283205862, 6755.246706102064, 6933.5065215625145, 6698.354368893961, 2955.2432251543523, 6742.2320642180775, 6874.005832856677, 6741.866132728801, 6741.683533888937, 6754.846357425081, 7472.339123365727, 7718.205284884017, 6736.030926278237, 6558.260866427156, 6807.23029138255, 7019.150132028008, 6852.536535333066, 6836.54299643397, 7050.426266236445, 6675.4688521120415, 6738.26422405803, 7026.2240832086245, 6938.291972269912, 6828.577338818448, 6859.79264959928, 2520.0274120170025, 6683.912929562914, 6954.469495133986, 6763.154744101562, 6522.244453809546, 6817.348821946897, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417, 7088.787020510739, 6867.1859130024095, 6626.354822333846, 6863.262295204399], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.31048591743106, 'mean_processing_ms': 0.3730312166827483, 'mean_inference_ms': 1.9720877944519415}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 462, 'num_steps_trained': 928000, 'num_steps_sampled': 233000, 'sample_time_ms': 75.281, 'replay_time_ms': 1.768, 'grad_time_ms': 7.912, 'update_time_ms': 0.004, 'opt_peak_throughput': 4044.408, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 364.88507, 'min_q': 317.43295, 'max_q': 569.633, 'mean_td_error': 1.3622665, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 233000, 'episodes_total': 154, 'training_iteration': 154, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-30-56', 'timestamp': 1587972656, 'time_this_iter_s': 21.23492121696472, 'time_total_s': 2510.451650619507, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, 'optimizer': {}, 'gamma':  ...
# 3.069021451650626
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6670.465199899171, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6978.432849807797, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357, 7008.799532621892, 7212.050320480788, 7156.741574064152, 6870.500197580292, 6527.961876430954, 6826.406301365392, 6946.459693154826, 6632.313283205862, 6755.246706102064, 6933.5065215625145, 6698.354368893961, 2955.2432251543523, 6742.2320642180775, 6874.005832856677, 6741.866132728801, 6741.683533888937, 6754.846357425081, 7472.339123365727, 7718.205284884017, 6736.030926278237, 6558.260866427156, 6807.23029138255, 7019.150132028008, 6852.536535333066, 6836.54299643397, 7050.426266236445, 6675.4688521120415, 6738.26422405803, 7026.2240832086245, 6938.291972269912, 6828.577338818448, 6859.79264959928, 2520.0274120170025, 6683.912929562914, 6954.469495133986, 6763.154744101562, 6522.244453809546, 6817.348821946897, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417, 7088.787020510739, 6867.1859130024095, 6626.354822333846, 6863.262295204399, 6865.10407053436], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.310002363354048, 'mean_processing_ms': 0.3730082905811313, 'mean_inference_ms': 1.971829808079994}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 466, 'num_steps_trained': 936000, 'num_steps_sampled': 235000, 'sample_time_ms': 75.567, 'replay_time_ms': 1.921, 'grad_time_ms': 7.947, 'update_time_ms': 0.009, 'opt_peak_throughput': 4026.524, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 343.80328, 'min_q': 275.4377, 'max_q': 521.1939, 'mean_td_error': 9.592725, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 235000, 'episodes_total': 155, 'training_iteration': 155, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-31-17', 'timestamp': 1587972677, 'time_this_iter_s': 21.35223388671875, 'time_total_s': 2531.8038845062256, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, 'custom_preprocessor': None}, ' ...
# 2.5209376365697294
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6659.679230061074, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [5796.8016430133775, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357, 7008.799532621892, 7212.050320480788, 7156.741574064152, 6870.500197580292, 6527.961876430954, 6826.406301365392, 6946.459693154826, 6632.313283205862, 6755.246706102064, 6933.5065215625145, 6698.354368893961, 2955.2432251543523, 6742.2320642180775, 6874.005832856677, 6741.866132728801, 6741.683533888937, 6754.846357425081, 7472.339123365727, 7718.205284884017, 6736.030926278237, 6558.260866427156, 6807.23029138255, 7019.150132028008, 6852.536535333066, 6836.54299643397, 7050.426266236445, 6675.4688521120415, 6738.26422405803, 7026.2240832086245, 6938.291972269912, 6828.577338818448, 6859.79264959928, 2520.0274120170025, 6683.912929562914, 6954.469495133986, 6763.154744101562, 6522.244453809546, 6817.348821946897, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417, 7088.787020510739, 6867.1859130024095, 6626.354822333846, 6863.262295204399, 6865.10407053436, 6978.432849807797], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.309530690070265, 'mean_processing_ms': 0.37298506273913307, 'mean_inference_ms': 1.9715968658214529}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 470, 'num_steps_trained': 944000, 'num_steps_sampled': 237000, 'sample_time_ms': 77.512, 'replay_time_ms': 1.723, 'grad_time_ms': 8.417, 'update_time_ms': 0.004, 'opt_peak_throughput': 3801.976, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 360.202, 'min_q': 304.51855, 'max_q': 657.32135, 'mean_td_error': 10.774293, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 237000, 'episodes_total': 156, 'training_iteration': 156, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-31-39', 'timestamp': 1587972699, 'time_this_iter_s': 21.522647857666016, 'time_total_s': 2553.3265323638916, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': None, 'custom_options': {}, ' ...
# 2.8342212703429004
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6657.6429163564635, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6492.7015062828705, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357, 7008.799532621892, 7212.050320480788, 7156.741574064152, 6870.500197580292, 6527.961876430954, 6826.406301365392, 6946.459693154826, 6632.313283205862, 6755.246706102064, 6933.5065215625145, 6698.354368893961, 2955.2432251543523, 6742.2320642180775, 6874.005832856677, 6741.866132728801, 6741.683533888937, 6754.846357425081, 7472.339123365727, 7718.205284884017, 6736.030926278237, 6558.260866427156, 6807.23029138255, 7019.150132028008, 6852.536535333066, 6836.54299643397, 7050.426266236445, 6675.4688521120415, 6738.26422405803, 7026.2240832086245, 6938.291972269912, 6828.577338818448, 6859.79264959928, 2520.0274120170025, 6683.912929562914, 6954.469495133986, 6763.154744101562, 6522.244453809546, 6817.348821946897, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417, 7088.787020510739, 6867.1859130024095, 6626.354822333846, 6863.262295204399, 6865.10407053436, 6978.432849807797, 5796.8016430133775], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.309062850172346, 'mean_processing_ms': 0.37296110000898497, 'mean_inference_ms': 1.9713477083475826}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 474, 'num_steps_trained': 952000, 'num_steps_sampled': 239000, 'sample_time_ms': 75.008, 'replay_time_ms': 1.828, 'grad_time_ms': 7.751, 'update_time_ms': 0.004, 'opt_peak_throughput': 4128.29, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 354.66394, 'min_q': 291.61575, 'max_q': 653.90717, 'mean_td_error': 11.432535, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 239000, 'episodes_total': 157, 'training_iteration': 157, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-32-00', 'timestamp': 1587972720, 'time_this_iter_s': 21.17678213119507, 'time_total_s': 2574.5033144950867, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_action_dist': No ...
# 2.00011476572678
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6660.273605793176, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6875.990139603653, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357, 7008.799532621892, 7212.050320480788, 7156.741574064152, 6870.500197580292, 6527.961876430954, 6826.406301365392, 6946.459693154826, 6632.313283205862, 6755.246706102064, 6933.5065215625145, 6698.354368893961, 2955.2432251543523, 6742.2320642180775, 6874.005832856677, 6741.866132728801, 6741.683533888937, 6754.846357425081, 7472.339123365727, 7718.205284884017, 6736.030926278237, 6558.260866427156, 6807.23029138255, 7019.150132028008, 6852.536535333066, 6836.54299643397, 7050.426266236445, 6675.4688521120415, 6738.26422405803, 7026.2240832086245, 6938.291972269912, 6828.577338818448, 6859.79264959928, 2520.0274120170025, 6683.912929562914, 6954.469495133986, 6763.154744101562, 6522.244453809546, 6817.348821946897, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417, 7088.787020510739, 6867.1859130024095, 6626.354822333846, 6863.262295204399, 6865.10407053436, 6978.432849807797, 5796.8016430133775, 6492.7015062828705], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.30859161421854, 'mean_processing_ms': 0.37293687543997944, 'mean_inference_ms': 1.9711161395064765}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 478, 'num_steps_trained': 960000, 'num_steps_sampled': 241000, 'sample_time_ms': 79.302, 'replay_time_ms': 1.846, 'grad_time_ms': 8.059, 'update_time_ms': 0.004, 'opt_peak_throughput': 3970.598, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 344.09906, 'min_q': 296.7032, 'max_q': 656.7705, 'mean_td_error': 8.236018, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 241000, 'episodes_total': 158, 'training_iteration': 158, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-32-21', 'timestamp': 1587972741, 'time_this_iter_s': 21.36720848083496, 'time_total_s': 2595.8705229759216, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'cu ...
# 1.1911985069856229e-125
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6639.553208872878, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [4919.760264488183, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357, 7008.799532621892, 7212.050320480788, 7156.741574064152, 6870.500197580292, 6527.961876430954, 6826.406301365392, 6946.459693154826, 6632.313283205862, 6755.246706102064, 6933.5065215625145, 6698.354368893961, 2955.2432251543523, 6742.2320642180775, 6874.005832856677, 6741.866132728801, 6741.683533888937, 6754.846357425081, 7472.339123365727, 7718.205284884017, 6736.030926278237, 6558.260866427156, 6807.23029138255, 7019.150132028008, 6852.536535333066, 6836.54299643397, 7050.426266236445, 6675.4688521120415, 6738.26422405803, 7026.2240832086245, 6938.291972269912, 6828.577338818448, 6859.79264959928, 2520.0274120170025, 6683.912929562914, 6954.469495133986, 6763.154744101562, 6522.244453809546, 6817.348821946897, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417, 7088.787020510739, 6867.1859130024095, 6626.354822333846, 6863.262295204399, 6865.10407053436, 6978.432849807797, 5796.8016430133775, 6492.7015062828705, 6875.990139603653], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.30817177164375, 'mean_processing_ms': 0.37291423341210017, 'mean_inference_ms': 1.9708764249686885}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 482, 'num_steps_trained': 968000, 'num_steps_sampled': 243000, 'sample_time_ms': 79.261, 'replay_time_ms': 2.01, 'grad_time_ms': 8.034, 'update_time_ms': 0.004, 'opt_peak_throughput': 3983.207, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 335.70184, 'min_q': 223.43524, 'max_q': 588.7861, 'mean_td_error': 8.442488, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 243000, 'episodes_total': 159, 'training_iteration': 159, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-32-43', 'timestamp': 1587972763, 'time_this_iter_s': 21.61333417892456, 'time_total_s': 2617.483857154846, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, ' ...
# 2.623675690567687
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6633.177531720342, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6097.620650907398, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357, 7008.799532621892, 7212.050320480788, 7156.741574064152, 6870.500197580292, 6527.961876430954, 6826.406301365392, 6946.459693154826, 6632.313283205862, 6755.246706102064, 6933.5065215625145, 6698.354368893961, 2955.2432251543523, 6742.2320642180775, 6874.005832856677, 6741.866132728801, 6741.683533888937, 6754.846357425081, 7472.339123365727, 7718.205284884017, 6736.030926278237, 6558.260866427156, 6807.23029138255, 7019.150132028008, 6852.536535333066, 6836.54299643397, 7050.426266236445, 6675.4688521120415, 6738.26422405803, 7026.2240832086245, 6938.291972269912, 6828.577338818448, 6859.79264959928, 2520.0274120170025, 6683.912929562914, 6954.469495133986, 6763.154744101562, 6522.244453809546, 6817.348821946897, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417, 7088.787020510739, 6867.1859130024095, 6626.354822333846, 6863.262295204399, 6865.10407053436, 6978.432849807797, 5796.8016430133775, 6492.7015062828705, 6875.990139603653, 4919.760264488183], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.307716567377188, 'mean_processing_ms': 0.3728922033890573, 'mean_inference_ms': 1.9706308757734352}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 486, 'num_steps_trained': 976000, 'num_steps_sampled': 245000, 'sample_time_ms': 76.394, 'replay_time_ms': 1.918, 'grad_time_ms': 8.302, 'update_time_ms': 0.004, 'opt_peak_throughput': 3854.527, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 339.32535, 'min_q': 266.082, 'max_q': 470.65628, 'mean_td_error': 14.411964, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 245000, 'episodes_total': 160, 'training_iteration': 160, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-33-04', 'timestamp': 1587972784, 'time_this_iter_s': 21.002195596694946, 'time_total_s': 2638.486052751541, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': True, 'dim': 84, 'grayscale':  ...
# 2.0733844954348957
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 1676.0225000013666, 'episode_reward_mean': 6635.504302626953, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6833.279829688769, 6824.003258698014, 6570.110303374103, 6618.566441850614, 1676.0225000013666, 7138.801930882989, 7026.536681645156, 7871.612903815616, 3615.3327067950795, 6300.045002477511, 7859.976000905357, 7008.799532621892, 7212.050320480788, 7156.741574064152, 6870.500197580292, 6527.961876430954, 6826.406301365392, 6946.459693154826, 6632.313283205862, 6755.246706102064, 6933.5065215625145, 6698.354368893961, 2955.2432251543523, 6742.2320642180775, 6874.005832856677, 6741.866132728801, 6741.683533888937, 6754.846357425081, 7472.339123365727, 7718.205284884017, 6736.030926278237, 6558.260866427156, 6807.23029138255, 7019.150132028008, 6852.536535333066, 6836.54299643397, 7050.426266236445, 6675.4688521120415, 6738.26422405803, 7026.2240832086245, 6938.291972269912, 6828.577338818448, 6859.79264959928, 2520.0274120170025, 6683.912929562914, 6954.469495133986, 6763.154744101562, 6522.244453809546, 6817.348821946897, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417, 7088.787020510739, 6867.1859130024095, 6626.354822333846, 6863.262295204399, 6865.10407053436, 6978.432849807797, 5796.8016430133775, 6492.7015062828705, 6875.990139603653, 4919.760264488183, 6097.620650907398], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.307253295232183, 'mean_processing_ms': 0.37287086596721114, 'mean_inference_ms': 1.9704115004346043}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 490, 'num_steps_trained': 984000, 'num_steps_sampled': 247000, 'sample_time_ms': 75.569, 'replay_time_ms': 1.777, 'grad_time_ms': 7.884, 'update_time_ms': 0.004, 'opt_peak_throughput': 4058.828, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 320.4051, 'min_q': 269.32285, 'max_q': 426.44418, 'mean_td_error': 12.573814, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 247000, 'episodes_total': 161, 'training_iteration': 161, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-33-25', 'timestamp': 1587972805, 'time_this_iter_s': 21.43177628517151, 'time_total_s': 2659.9178290367126, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'train_batch_size': 32, 'model': {'conv_filters': None, 'conv_activation': 'relu', 'fcnet_activation': 'tanh', 'fcnet_hiddens': [256, 256], 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': True, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action_reward': False, 'state_shape': None, 'framestack': Tru ...
# 2.063636752449878
# Done
# ...
# 4.381513896837051
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 4919.760264488183, 'episode_reward_mean': 6829.395034146326, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6438.109781287745, 6885.8692050079, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417, 7088.787020510739, 6867.1859130024095, 6626.354822333846, 6863.262295204399, 6865.10407053436, 6978.432849807797, 5796.8016430133775, 6492.7015062828705, 6875.990139603653, 4919.760264488183, 6097.620650907398, 6833.279829688769, 6871.945006000055, 6842.454058402442, 6932.311947892892, 6877.681515727265, 7019.025569388451, 6692.6379476529555, 7094.271183263468, 7055.421312326856, 6874.250329180732, 6999.46470322955, 7201.797173324244, 6908.309472936985, 6676.205608087184, 6621.69461303101, 6987.543413158731, 6330.209378915405, 6863.467807841005, 7236.85561009181, 6607.486064433604, 7322.537418375474, 7202.687689982929, 6508.892031952516, 7444.327954516753, 7088.680289444594, 7576.279145941081, 7189.262725523784, 6739.761475215555, 7079.636066689452, 6920.929816602633, 6782.257288400649, 6489.022561936024, 7228.28461644378, 6349.0177204332895, 7011.016702517447, 6759.388065113682, 6631.668923374239, 7170.469121916622, 6744.076552102562, 6988.491371572537, 6865.756325082857, 6685.250317087253, 6995.119252416865, 7272.085732033308, 7199.552333826949, 6849.632036032094, 6753.901197006702, 6860.709233607579, 6854.093095332573, 7076.508009039165, 6945.3250221383005, 6084.801895040031, 6028.599568234066, 6712.774362406861, 6937.802621585983, 6891.808735565309, 6761.761877173445, 6711.536492217065, 6873.4923824069865, 6862.560838166171, 7218.8458201123285, 6744.110859162542], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.286528355809878, 'mean_processing_ms': 0.37196148143879926, 'mean_inference_ms': 1.957648474278664}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 736, 'num_steps_trained': 1480000, 'num_steps_sampled': 371000, 'sample_time_ms': 76.742, 'replay_time_ms': 1.793, 'grad_time_ms': 7.767, 'update_time_ms': 0.004, 'opt_peak_throughput': 4119.939, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 365.36374, 'min_q': 278.38705, 'max_q': 615.52405, 'mean_td_error': -0.45272732, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 371000, 'episodes_total': 223, 'training_iteration': 223, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-55-48', 'timestamp': 1587974148, 'time_this_iter_s': 21.39457869529724, 'time_total_s': 4001.7669010162354, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 't ...
# 2.3894128809968675
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 4919.760264488183, 'episode_reward_mean': 6829.172015800506, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6863.567370426077, 6754.767629447317, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417, 7088.787020510739, 6867.1859130024095, 6626.354822333846, 6863.262295204399, 6865.10407053436, 6978.432849807797, 5796.8016430133775, 6492.7015062828705, 6875.990139603653, 4919.760264488183, 6097.620650907398, 6833.279829688769, 6871.945006000055, 6842.454058402442, 6932.311947892892, 6877.681515727265, 7019.025569388451, 6692.6379476529555, 7094.271183263468, 7055.421312326856, 6874.250329180732, 6999.46470322955, 7201.797173324244, 6908.309472936985, 6676.205608087184, 6621.69461303101, 6987.543413158731, 6330.209378915405, 6863.467807841005, 7236.85561009181, 6607.486064433604, 7322.537418375474, 7202.687689982929, 6508.892031952516, 7444.327954516753, 7088.680289444594, 7576.279145941081, 7189.262725523784, 6739.761475215555, 7079.636066689452, 6920.929816602633, 6782.257288400649, 6489.022561936024, 7228.28461644378, 6349.0177204332895, 7011.016702517447, 6759.388065113682, 6631.668923374239, 7170.469121916622, 6744.076552102562, 6988.491371572537, 6865.756325082857, 6685.250317087253, 6995.119252416865, 7272.085732033308, 7199.552333826949, 6849.632036032094, 6753.901197006702, 6860.709233607579, 6854.093095332573, 7076.508009039165, 6945.3250221383005, 6084.801895040031, 6028.599568234066, 6712.774362406861, 6937.802621585983, 6891.808735565309, 6761.761877173445, 6711.536492217065, 6873.4923824069865, 6862.560838166171, 7218.8458201123285, 6744.110859162542, 6438.109781287745], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.286902583426016, 'mean_processing_ms': 0.37198497592984286, 'mean_inference_ms': 1.957746435542376}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 740, 'num_steps_trained': 1488000, 'num_steps_sampled': 373000, 'sample_time_ms': 81.286, 'replay_time_ms': 1.85, 'grad_time_ms': 8.328, 'update_time_ms': 0.004, 'opt_peak_throughput': 3842.411, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 371.81567, 'min_q': 291.276, 'max_q': 619.8477, 'mean_td_error': -0.13254929, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 373000, 'episodes_total': 224, 'training_iteration': 224, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-56-09', 'timestamp': 1587974169, 'time_this_iter_s': 21.468165159225464, 'time_total_s': 4023.235066175461, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'tra ...
# 2.7748590087972484
# Done
# {'episode_reward_max': 8312.776236501357, 'episode_reward_min': 4919.760264488183, 'episode_reward_mean': 6829.442122368735, 'episode_len_mean': 1000.0, 'episodes_this_iter': 1, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [6781.778286270118, 8312.776236501357, 6931.022939354203, 7281.8913618356355, 7445.379619769623, 6367.559840895374, 6465.7490632226545, 7059.044520230783, 6636.47774633359, 6565.469544204199, 7177.120658988342, 6916.863989049741, 5495.332628354686, 8033.727379493588, 7177.927646926168, 6958.293398854737, 6592.560416013417, 6872.217803257852, 6212.315557393416, 6040.97990469594, 6678.438636732613, 6396.289704958355, 7079.670128716447, 6758.374687069949, 6994.244122044417, 7088.787020510739, 6867.1859130024095, 6626.354822333846, 6863.262295204399, 6865.10407053436, 6978.432849807797, 5796.8016430133775, 6492.7015062828705, 6875.990139603653, 4919.760264488183, 6097.620650907398, 6833.279829688769, 6871.945006000055, 6842.454058402442, 6932.311947892892, 6877.681515727265, 7019.025569388451, 6692.6379476529555, 7094.271183263468, 7055.421312326856, 6874.250329180732, 6999.46470322955, 7201.797173324244, 6908.309472936985, 6676.205608087184, 6621.69461303101, 6987.543413158731, 6330.209378915405, 6863.467807841005, 7236.85561009181, 6607.486064433604, 7322.537418375474, 7202.687689982929, 6508.892031952516, 7444.327954516753, 7088.680289444594, 7576.279145941081, 7189.262725523784, 6739.761475215555, 7079.636066689452, 6920.929816602633, 6782.257288400649, 6489.022561936024, 7228.28461644378, 6349.0177204332895, 7011.016702517447, 6759.388065113682, 6631.668923374239, 7170.469121916622, 6744.076552102562, 6988.491371572537, 6865.756325082857, 6685.250317087253, 6995.119252416865, 7272.085732033308, 7199.552333826949, 6849.632036032094, 6753.901197006702, 6860.709233607579, 6854.093095332573, 7076.508009039165, 6945.3250221383005, 6084.801895040031, 6028.599568234066, 6712.774362406861, 6937.802621585983, 6891.808735565309, 6761.761877173445, 6711.536492217065, 6873.4923824069865, 6862.560838166171, 7218.8458201123285, 6744.110859162542, 6438.109781287745, 6863.567370426077], 'episode_lengths': [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]}, 'sampler_perf': {'mean_env_wait_ms': 16.28732712532676, 'mean_processing_ms': 0.3720126503736872, 'mean_inference_ms': 1.957874543636859}, 'off_policy_estimator': {}, 'info': {'exploration_infos': [{'cur_epsilon': 0.05}], 'num_target_updates': 744, 'num_steps_trained': 1496000, 'num_steps_sampled': 375000, 'sample_time_ms': 75.733, 'replay_time_ms': 1.936, 'grad_time_ms': 7.994, 'update_time_ms': 0.004, 'opt_peak_throughput': 4003.165, 'opt_samples': 32.0, 'learner': {'default_policy': {'cur_lr': 0.0005000000237487257, 'mean_q': 360.39334, 'min_q': 299.94363, 'max_q': 626.2194, 'mean_td_error': 6.5344706, 'model': {}}}}, 'timesteps_this_iter': 2000, 'done': False, 'timesteps_total': 375000, 'episodes_total': 225, 'training_iteration': 225, 'experiment_id': 'ef01e7b0d42e4a17b9ef69c3c13c8db3', 'date': '2020-04-27_07-56-31', 'timestamp': 1587974191, 'time_this_iter_s': 21.78547239303589, 'time_total_s': 4045.0205385684967, 'pid': 124, 'hostname': '97faaa98a86e', 'node_ip': '172.28.0.2', 'config': {'num_workers': 0, 'num_envs_per_worker': 1, 'rollout_fragment_length': 4, 'sample_batch_size': -1, 'batch_mode': 'truncate_episodes', 'num_gpus': 0, 'trai ...
# 150
# 150

# %%
print(len(final_rewards2))
print(num_episodes)
plt.style.use('seaborn-darkgrid')
plt.plot(final_rewards2, label="reward")
plt.plot(moving_average2, label="avg last 10 episodes")
plt.plot(np.zeros(150) + 3.5, label="baseline")
plt.legend(loc='lower right')
plt.xlabel('Episode Count')
plt.ylabel('Reward (Average Velocity)')
plt.title('Two Agent on Figure 8 Track using Circle Track DQN Model')
plt.show()
# Out:
# 150
# 150
